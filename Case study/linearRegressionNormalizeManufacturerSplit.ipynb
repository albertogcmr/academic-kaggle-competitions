# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from clean_data import clean_data, prepare_data, prepare_data_no_dummy, yearSplit, manufacturerSplit
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import normalize

# %%
# Read files
train = pd.read_csv('../cars-competition/data/cars_train.csv', index_col='Id')
submission = pd.read_csv('../cars-competition/data/cars_test.csv', index_col='Id')

# %%
# Clean Data
train = clean_data(train)
submission = clean_data(submission)
# Out:
# Cleaning cylinders...
# Cleaning condition...
# Cleaning odometer...
# Cleaning drive...
# Cleaning size...
# Cleaning manufacturer...
# Cleaning fuel...
# Cleaning transmission...
# Cleaning title status...
# Data cleaning complete!
# Cleaning cylinders...
# Cleaning condition...
# Cleaning odometer...
# Cleaning drive...
# Cleaning size...
# Cleaning manufacturer...
# Cleaning fuel...
# Cleaning transmission...
# Cleaning title status...
# Data cleaning complete!

# %%
# Prepare Data
# columns = ['year','manufacturer','condition','cylinders','fuel','odometer','title_status','transmission','drive','size']
columns = ['year','manufacturer','condition','cylinders','odometer','title_status','transmission','size','lat','long']
X, y = prepare_data_no_dummy(train,columns,typ='train')
X_sub, _ = prepare_data_no_dummy(submission,columns,typ='test')
# Out:
# Preparing data...
# Data preparation complete!
# Preparing data...
# Data preparation complete!

# %%
X
# Out:
#            year manufacturer  condition  cylinders       odometer  \
# Id
# 559327   2006.0      unknown          2          4  190000.000000
# 1429566  2018.0        dodge          0          6  113584.991571
# 931606   1997.0         ford          0          6  113584.991571
# 1265412  2003.0          ram          0          8  113584.991571
# 1133731  2000.0        dodge          0          6  113584.991571
# ...         ...          ...        ...        ...            ...
# 1505912  2005.0         ford          0          6  238047.000000
# 1436810  2016.0      hyundai          2          6   40516.000000
# 170772   2016.0          gmc          2          8  151763.000000
# 1649643  2016.0      hyundai          2          4   35028.000000
# 882889   2013.0     chrysler          1          6   76662.000000
#
#         title_status transmission       size        lat        long
# Id
# 559327         clean    automatic   mid-size  39.287000  -76.647600
# 1429566        clean    automatic  full-size  37.720000  -89.215800
# 931606         clean    automatic  full-size  43.483300  -83.383500
# 1265412        clean    automatic  full-size  27.850069  -99.668883
# 1133731        clean    automatic  full-size  29.165000  -81.539900
# ...              ...          ...        ...        ...         ...
# 1505912        clean    automatic  full-size  48.077990 -123.159590
# 1436810        clean    automatic  full-size  42.278560  -88.031417
# 170772         clean    automatic  full-size  34.683630  -86.577461
# 1649643        clean    automatic   mid-size  43.758910  -87.753580
# 882889         clean    automatic  full-size  42.439874  -83.102712
#
# [469992 rows x 10 columns]

# %%
X.shape
# Out:
# (469992, 10)

# %%
# Split data by Manufacturer
def yearSplit(X,y=pd.DataFrame(None)):
    decade = {manu:'' for manu in set(X['manufacturer'])}
    print(decade)
    y_decade = {}
    for i in decade.keys():
        print('Spliting data by manufacturer: {}'.format(i))
        dec = X['manufacturer']==i
        decade[i] = X[dec]
        if any(y != None):
            y_decade[i] = y[dec]
    return decade, y_decade

# %%
X_dec, y_dec = yearSplit(X,y)
X_sub_dec, _ = yearSplit(X_sub)
# Out:
# {'ferrari': '', 'kia': '', 'harley-davidson': '', 'morgan': '', 'mazda': '', 'mini': '', 'volvo': '', 'subaru': '', 'buick': '', 'cadillac': '', 'land rover': '', 'bmw': '', 'dodge': '', 'chrysler': '', 'mitsubishi': '', 'ford': '', 'porche': '', 'ram': '', 'chevrolet': '', 'infiniti': '', 'nissan': '', 'lincoln': '', 'mercedes-benz': '', 'jeep': '', 'gmc': '', 'volkswagen': '', 'hyundai': '', 'alfa-romeo': '', 'acura': '', 'aston-martin': '', 'pontiac': '', 'jaguar': '', 'toyota': '', 'fiat': '', 'honda': '', 'lexus': '', 'mercury': '', 'audi': '', 'saturn': '', 'datsun': '', 'unknown': ''}
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# {'ferrari': '', 'kia': '', 'harley-davidson': '', 'morgan': '', 'mazda': '', 'mini': '', 'volvo': '', 'subaru': '', 'buick': '', 'cadillac': '', 'bmw': '', 'mitsubishi': '', 'dodge': '', 'chrysler': '', 'land rover': '', 'ford': '', 'porche': '', 'ram': '', 'chevrolet': '', 'infiniti': '', 'nissan': '', 'mercedes-benz': '', 'lincoln': '', 'jeep': '', 'gmc': '', 'volkswagen': '', 'hyundai': '', 'alfa-romeo': '', 'acura': '', 'aston-martin': '', 'pontiac': '', 'jaguar': '', 'toyota': '', 'fiat': '', 'lexus': '', 'honda': '', 'mercury': '', 'audi': '', 'saturn': '', 'datsun': '', 'unknown': ''}
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:
# Spliting data by manufacturer:

# %%
shape = []
for i in X_sub_dec.values():
    shape.append(i.shape[0])

# %%
X_sub.shape
# Out:
# (253073, 10)

# %%
sum(shape)
# Out:
# 253073

# %%
X_dec
# Out:
# {'ferrari':                 year manufacturer  condition  cylinders       odometer  \
#  Id
#  1446117  1981.000000      ferrari          1          4   17000.000000
#  723398   2006.000000      ferrari          0          6  113584.991571
#  1321337  1994.000000      ferrari          2          8   40000.000000
#  608244   2010.000000      ferrari          1          8   17585.000000
#  684579   2010.000000      ferrari          0          8   55500.000000
#  162605   2010.000000      ferrari          2          6   17030.000000
#  635380   1997.000000      ferrari          2          6   28305.000000
#  315525   2000.000000      ferrari          2          8   46609.000000
#  212262   1985.000000      ferrari          0          6  113584.991571
#  1190071  2000.000000      ferrari          0          8   25580.000000
#  482666   2005.000000      ferrari          0          8    7926.000000
#  841806   2005.000000      ferrari          0          8    7172.000000
#  642271   1988.000000      ferrari          0          6   39635.000000
#  740451   2006.000000      ferrari          0          8   26937.000000
#  43879    2012.000000      ferrari          1          8    5221.000000
#  1376282  2004.869185      ferrari          2          8  113584.991571
#  1121000  1981.000000      ferrari          2          8   18429.000000
#  1175427  2005.000000      ferrari          2          6   11994.000000
#  988052   2004.000000      ferrari          0          6   19195.000000
#  1500489  1985.000000      ferrari          2          8   44800.000000
#  1174089  2004.000000      ferrari          0          6   19684.000000
#  737730   2018.000000      ferrari          0          6  113584.991571
#  670095   2005.000000      ferrari          0         12   28197.000000
#  631033   2008.000000      ferrari          0          6    7430.000000
#  668606   2017.000000      ferrari          2          6    1000.000000
#  560731   1985.000000      ferrari          2          8   73000.000000
#  632686   2005.000000      ferrari          0          6   29790.000000
#  715026   1997.000000      ferrari          2          6   28305.000000
#  669494   2006.000000      ferrari          2          8   26937.000000
#  660764   2010.000000      ferrari          0          8   55500.000000
#  496613   2005.000000      ferrari          2          8   15339.000000
#  225673   2004.000000      ferrari          0          6   28944.000000
#  583172   2011.000000      ferrari          0          6   18031.000000
#  585996   2011.000000      ferrari          0          6   18031.000000
#  1661060  1985.000000      ferrari          2          4  113584.991571
#  339023   1995.000000      ferrari          2          6   23501.000000
#  322047   2010.000000      ferrari          2          6   17030.000000
#  1499004  2004.000000      ferrari          1          8   29030.000000
#  1450224  2016.000000      ferrari          2          6    3000.000000
#  76395    2008.000000      ferrari          2          6   24000.000000
#  614715   2015.000000      ferrari          2          8   29800.000000
#  1207437  2010.000000      ferrari          0          8  113584.991571
#  680826   2012.000000      ferrari          0          6  113584.991571
#  1473912  2004.000000      ferrari          1          6   29030.000000
#  344248   2008.000000      ferrari          2          8   26000.000000
#  94328    2006.000000      ferrari          2          8   26937.000000
#  1572642  1981.000000      ferrari          2          8   37790.000000
#  781747   1995.000000      ferrari          1          6  113584.991571
#  682339   2017.000000      ferrari          0          6  113584.991571
#  683466   2010.000000      ferrari          0          8   55500.000000
#  1391340  2006.000000      ferrari          0          6  113584.991571
#  611384   2006.000000      ferrari          0          8   26937.000000
#  1483454  2004.000000      ferrari          1          6   29030.000000
#  592246   2010.000000      ferrari          0          6   17822.000000
#  686162   1998.000000      ferrari          2          8   17000.000000
#  177995   1982.000000      ferrari          1          8   55000.000000
#  638012   1978.000000      ferrari          2          8   21465.000000
#  686164   1998.000000      ferrari          2          8   17000.000000
#  1133467  1989.000000      ferrari          0          6  113584.991571
#  228068   1984.000000      ferrari          0          6  113584.991571
#
#          title_status transmission         size        lat        long
#  Id
#  1446117        clean       manual      compact  40.103466  -88.279352
#  723398         clean       manual    full-size  33.708600 -117.870100
#  1321337        clean       manual    full-size  34.357100  -82.929600
#  608244         clean    automatic     mid-size  35.496578 -120.681118
#  684579         clean    automatic    full-size  33.742308 -116.359469
#  162605         clean    automatic    full-size  49.188382 -123.136168
#  635380         clean       manual    full-size  35.283445 -120.658029
#  315525         clean       manual      compact  25.776300  -80.291900
#  212262       rebuilt       manual    full-size  30.390400  -91.002100
#  1190071        clean    automatic    full-size  26.703851  -80.081996
#  482666         clean    automatic    full-size  33.409933 -111.860477
#  841806         clean    automatic    full-size  40.483700 -104.899400
#  642271         clean       manual    full-size  36.599870 -121.880839
#  740451         clean    automatic    full-size  33.741059 -116.356434
#  43879          clean        other    full-size  48.754800 -122.470000
#  1376282        clean        other    full-size  43.218500  -71.527700
#  1121000        clean       manual    full-size  28.583000  -81.894100
#  1175427        clean    automatic    full-size  27.299383  -82.513843
#  988052         clean    automatic    full-size  45.226972  -93.447336
#  1500489        clean       manual    full-size  48.862500 -122.595300
#  1174089        clean       manual    full-size  27.495880  -82.528450
#  737730         clean        other    full-size  36.212750 -119.350349
#  670095         clean    automatic    full-size  33.929280 -117.415667
#  631033         clean    automatic      compact  34.211400 -118.230500
#  668606         clean       manual    full-size  33.053500 -117.268900
#  560731         clean       manual     mid-size  38.978712  -76.490182
#  632686         clean    automatic    full-size  37.789455 -122.422115
#  715026         clean       manual    full-size  35.283445 -120.658029
#  669494         clean    automatic    full-size  33.741186 -116.356976
#  660764         clean    automatic    full-size  33.742308 -116.359469
#  496613         clean    automatic    full-size  33.409933 -111.860477
#  225673         clean        other    full-size  38.843330  -77.109620
#  583172         clean        other  sub-compact  45.616850 -122.693008
#  585996         clean        other  sub-compact  45.616850 -122.693008
#  1661060        clean       manual      compact  44.799299  -87.457416
#  339023         clean    automatic    full-size  49.110631 -122.643619
#  322047         clean    automatic    full-size  49.197012 -123.125587
#  1499004        clean    automatic    full-size  48.754800 -122.470000
#  1450224      rebuilt    automatic    full-size  40.862300  -74.075600
#  76395          clean    automatic    full-size  49.110631 -122.643619
#  614715         clean    automatic    full-size  38.581600 -121.494400
#  1207437        clean    automatic    full-size  45.578070 -111.126312
#  680826         clean    automatic    full-size  34.019500 -118.491200
#  1473912        clean    automatic    full-size  48.754800 -122.470000
#  344248         clean        other    full-size  43.218500  -71.527700
#  94328          clean    automatic    full-size  33.741186 -116.356976
#  1572642        clean       manual    full-size  40.865000  -73.627700
#  781747         clean    automatic    full-size  41.461653  -75.873299
#  682339         clean    automatic    full-size  33.741900 -117.746700
#  683466         clean    automatic    full-size  33.742308 -116.359469
#  1391340        clean        other    full-size  37.632900  -77.545100
#  611384         clean    automatic    full-size  33.741059 -116.356434
#  1483454        clean    automatic    full-size  48.754800 -122.470000
#  592246         clean    automatic    full-size  44.055050 -121.274500
#  686162         clean       manual      compact  33.240700 -117.302500
#  177995         clean       manual     mid-size  38.176800  -85.521800
#  638012         clean       manual    full-size  37.008900 -121.984900
#  686164         clean       manual      compact  33.240700 -117.302500
#  1133467        clean    automatic    full-size  29.201200  -81.037100
#  228068    parts only    automatic    full-size  30.455800  -91.059600  ,
#  'kia':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  44975    2007.0          kia          0          6  113584.991571
#  1382032  2009.0          kia          0          6  149729.000000
#  307219   2015.0          kia          2          6  113584.991571
#  114205   2018.0          kia          0          6   16481.000000
#  1383241  2012.0          kia          1          4   78524.000000
#  ...         ...          ...        ...        ...            ...
#  200155   2018.0          kia          0          6    2787.000000
#  195247   2016.0          kia          2          4  113584.991571
#  1162856  2015.0          kia          2         10   41058.000000
#  1545496  2006.0          kia          2          6   47000.000000
#  1178799  2015.0          kia          2          6   28000.000000
#
#          title_status transmission       size        lat        long
#  Id
#  44975        rebuilt    automatic  full-size  37.338900  -95.269300
#  1382032        clean    automatic  full-size  38.915906  -77.471196
#  307219         clean    automatic  full-size  51.174460 -114.013796
#  114205         clean    automatic  full-size  40.602980  -89.636950
#  1383241        clean    automatic   mid-size  37.288465  -80.009558
#  ...              ...          ...        ...        ...         ...
#  200155         clean    automatic  full-size  44.973187 -123.018138
#  195247         clean    automatic   mid-size  49.210949 -123.114720
#  1162856        clean        other    compact  28.466088  -81.396429
#  1545496        clean    automatic  full-size  39.595300  -79.922900
#  1178799        clean    automatic  full-size  28.490268  -81.253681
#
#  [6799 rows x 10 columns],
#  'harley-davidson':            year     manufacturer  condition  cylinders       odometer  \
#  Id
#  1499415  2012.0  harley-davidson          0          6   71801.000000
#  1232633  2001.0  harley-davidson          0          6  113584.991571
#  1470558  2007.0  harley-davidson          0          6  105906.000000
#  4002     2017.0  harley-davidson          2          6  113584.991571
#  826783   2014.0  harley-davidson          0          6    6900.000000
#  ...         ...              ...        ...        ...            ...
#  1516723  2010.0  harley-davidson          1          8  110000.000000
#  761832   2003.0  harley-davidson          2          6  113584.991571
#  1515570  2001.0  harley-davidson          2          6    9700.000000
#  103538   2015.0  harley-davidson          0          6   23736.000000
#  1549533  2010.0  harley-davidson          2          8  132000.000000
#
#          title_status transmission       size        lat        long
#  Id
#  1499415        clean    automatic  full-size  48.118005 -122.183513
#  1232633        clean       manual  full-size  31.869568 -102.374841
#  1470558        clean    automatic  full-size  47.656130 -117.236949
#  4002         rebuilt       manual  full-size  35.596829  -80.781097
#  826783         clean       manual  full-size  40.155300  -76.602500
#  ...              ...          ...        ...        ...         ...
#  1516723        clean    automatic  full-size  41.660954  -85.521483
#  761832         clean       manual  full-size  42.090182  -72.500668
#  1515570        clean       manual  full-size  39.788600  -85.977900
#  103538         clean        other  full-size  47.718250 -117.411650
#  1549533        clean    automatic  full-size  43.081400  -96.180000
#
#  [202 rows x 10 columns],
#  'morgan':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  1173925  1961.0       morgan          2          4  113584.991571
#  704129   2000.0       morgan          0         12  275000.000000
#  1147457  1967.0       morgan          1          4   50644.000000
#  816430   2012.0       morgan          2          6  113584.991571
#
#          title_status transmission       size        lat        long
#  Id
#  1173925        clean       manual   mid-size  26.434821  -81.746778
#  704129         clean        other   mid-size  38.640600 -121.444000
#  1147457        clean       manual   mid-size  29.883295  -81.282091
#  816430         clean    automatic  full-size  39.992500  -75.113300  ,
#  'mazda':            year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  848677   2008.0        mazda          0          6  138026.0        clean
#  1390549  2009.0        mazda          2          4   33874.0         lien
#  260963   2000.0        mazda          0          6       1.0        clean
#  686158   2018.0        mazda          0          4    6863.0        clean
#  9714     2010.0        mazda          1          4   93000.0      rebuilt
#  ...         ...          ...        ...        ...       ...          ...
#  1277044  2010.0        mazda          0          6  141070.0        clean
#  416386   2016.0        mazda          0          4   45396.0        clean
#  1003608  2003.0        mazda          1          6  152000.0   parts only
#  226827   2012.0        mazda          2          4  125000.0        clean
#  428050   2018.0        mazda          2          6    1450.0        clean
#
#          transmission       size        lat        long
#  Id
#  848677     automatic   mid-size  39.580500 -104.901100
#  1390549    automatic    compact  37.457736  -79.216276
#  260963     automatic  full-size  36.297130  -94.126778
#  686158     automatic   mid-size  33.131373 -117.323449
#  9714       automatic   mid-size  37.622300  -97.313600
#  ...              ...        ...        ...         ...
#  1277044    automatic   mid-size  27.656582  -97.481814
#  416386     automatic   mid-size  61.217220 -149.869960
#  1003608    automatic  full-size  34.375600  -80.084200
#  226827        manual   mid-size  32.533238  -93.762634
#  428050     automatic  full-size  30.003393  -90.161085
#
#  [6380 rows x 10 columns],
#  'mini':            year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  459196   2008.0         mini          0          6   79584.0        clean
#  1028076  1999.0         mini          1          6  229117.0        clean
#  1534331  2009.0         mini          2          4   80000.0        clean
#  651321   2005.0         mini          1          4   65000.0        clean
#  238909   2002.0         mini          1          4  106800.0        clean
#  ...         ...          ...        ...        ...       ...          ...
#  121016   2014.0         mini          2          4   46500.0        clean
#  784895   2007.0         mini          2          4   88000.0        clean
#  1336398  2003.0         mini          0          6  111913.0        clean
#  1353084  2012.0         mini          0          4   55640.0        clean
#  156559   2010.0         mini          2          4   76483.0        clean
#
#          transmission         size        lat        long
#  Id
#  459196     automatic  sub-compact  39.294493  -84.294923
#  1028076    automatic     mid-size  44.082354 -103.191228
#  1534331       manual      compact  35.533500 -105.926000
#  651321     automatic     mid-size  36.298504 -119.268200
#  238909        manual      compact  42.393211 -114.522170
#  ...              ...          ...        ...         ...
#  121016     automatic      compact  36.757986 -108.212199
#  784895     automatic     mid-size  40.259700  -76.859400
#  1336398       manual      compact  41.420980  -96.499110
#  1353084       manual     mid-size  39.494396 -119.789034
#  156559        manual     mid-size  49.312838 -124.359741
#
#  [1745 rows x 10 columns],
#  'volvo':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  473356   2008.0        volvo          2          6  143251.000000
#  1578360  2009.0        volvo          0          6   87000.000000
#  1570403  2004.0        volvo          0          5  143000.000000
#  1721281  2006.0        volvo          1          8  124600.000000
#  1393864  2005.0        volvo          2          5  147518.000000
#  ...         ...          ...        ...        ...            ...
#  599064   2006.0        volvo          0          6  113584.991571
#  490973   2004.0        volvo          2          6  113584.991571
#  70404    2011.0        volvo          2          6  110000.000000
#  648528   2004.0        volvo          1          4  168500.000000
#  1359380  2002.0        volvo          0          6  212175.000000
#
#          title_status transmission       size        lat        long
#  Id
#  473356         clean    automatic   mid-size  41.102240  -81.481860
#  1578360        clean    automatic  full-size  42.844100  -78.818200
#  1570403        clean    automatic  full-size  41.423700  -74.160100
#  1721281      salvage    automatic  full-size  44.282000 -105.497400
#  1393864        clean    automatic   mid-size  37.286501  -80.056719
#  ...              ...          ...        ...        ...         ...
#  599064         clean       manual  full-size  44.056100 -122.917100
#  490973         clean    automatic  full-size  34.778400 -111.785100
#  70404          clean    automatic  full-size  40.697964  -74.234082
#  648528         clean    automatic   mid-size  37.583300 -120.949600
#  1359380        clean    automatic  full-size  44.484000  -73.219900
#
#  [2991 rows x 10 columns],
#  'subaru':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  1319903  2009.0       subaru          1          6   96318.000000
#  34513    2010.0       subaru          0          6  113584.991571
#  1628135  2009.0       subaru          2          4   89000.000000
#  1370778  2003.0       subaru          1          4  195000.000000
#  30592    2010.0       subaru          2          4  184000.000000
#  ...         ...          ...        ...        ...            ...
#  842630   2002.0       subaru          1          6  242000.000000
#  928455   2013.0       subaru          2          6   92000.000000
#  568870   2017.0       subaru          0          4   16478.000000
#  796257   2003.0       subaru          1          4  231439.000000
#  808470   2009.0       subaru          0          6  159000.000000
#
#          title_status transmission       size        lat        long
#  Id
#  1319903        clean    automatic  full-size  33.514126  -82.061611
#  34513          clean       manual  full-size  41.784060  -72.276270
#  1628135        clean    automatic   mid-size  44.517389  -88.050361
#  1370778        clean       manual  full-size  43.810000 -111.789000
#  30592          clean    automatic   mid-size  50.086666  -96.915293
#  ...              ...          ...        ...        ...         ...
#  842630         clean    automatic    compact  39.997901 -105.242844
#  928455         clean    automatic  full-size  42.305997  -83.706174
#  568870         clean    automatic   mid-size  44.022481 -116.948910
#  796257         clean       manual    compact  41.378483  -75.376825
#  808470         clean    automatic  full-size  40.642100  -79.727300
#
#  [8099 rows x 10 columns],
#  'buick':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  413465   2005.0        buick          1          6     208.000000
#  1630866  2007.0        buick          1          8  113584.991571
#  890695   2006.0        buick          0          8  127693.000000
#  1358458  1994.0        buick          1          8   97000.000000
#  1310820  1970.0        buick          0          6  113584.991571
#  ...         ...          ...        ...        ...            ...
#  865182   2014.0        buick          0          6  113584.991571
#  1001355  2010.0        buick          2          6  152308.000000
#  1663442  1998.0        buick          0          6  160000.000000
#  806669   2005.0        buick          0          6  113584.991571
#  1445996  1998.0        buick          1          6  113687.000000
#
#          title_status transmission       size        lat       long
#  Id
#  413465         clean    automatic   mid-size  46.883894 -96.882838
#  1630866        clean    automatic  full-size  45.314799 -91.651403
#  890695         clean    automatic  full-size  42.997925 -83.678078
#  1358458        clean    automatic  full-size  43.998838 -72.449455
#  1310820        clean    automatic  full-size  33.833200 -84.603100
#  ...              ...          ...        ...        ...        ...
#  865182         clean    automatic  full-size  43.386900 -84.092600
#  1001355        clean    automatic  full-size  35.115400 -81.867800
#  1663442        clean    automatic  full-size  37.793400 -97.273700
#  806669         clean    automatic  full-size  40.029906 -75.167190
#  1445996        clean    automatic  full-size  39.786713 -89.695920
#
#  [6264 rows x 10 columns],
#  'cadillac':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  258558   2014.0     cadillac          1          4   55800.000000
#  387098   2009.0     cadillac          0          6  142701.000000
#  525861   2018.0     cadillac          0          6  113584.991571
#  413853   2008.0     cadillac          2          8  132500.000000
#  4372     2013.0     cadillac          2          6   46000.000000
#  ...         ...          ...        ...        ...            ...
#  1212250  2002.0     cadillac          0          8  115761.000000
#  1226480  2016.0     cadillac          0          6   37335.000000
#  289337   2007.0     cadillac          1          6  142000.000000
#  448932   1991.0     cadillac          2          8  160000.000000
#  684502   2003.0     cadillac          0          8  104395.000000
#
#          title_status transmission       size        lat        long
#  Id
#  258558         clean    automatic   mid-size  41.298474  -81.459900
#  387098         clean    automatic  full-size  43.186723  -84.163862
#  525861         clean    automatic  full-size  35.199000  -97.484100
#  413853         clean    automatic  full-size  47.927200  -97.067200
#  4372           clean    automatic  full-size  41.947509  -86.336947
#  ...              ...          ...        ...        ...         ...
#  1212250        clean    automatic  full-size  46.870626 -114.018477
#  1226480        clean    automatic  full-size  31.535000  -97.189900
#  289337         clean    automatic  full-size  41.076000  -81.464400
#  448932         clean    automatic   mid-size  39.689375  -83.938293
#  684502         clean    automatic  full-size  33.745583 -116.361979
#
#  [6814 rows x 10 columns],
#  'land rover':            year manufacturer  condition  cylinders      odometer title_status  \
#  Id
#  686329   2012.0   land rover          0          6  1.135850e+05        clean
#  1409194  2013.0   land rover          0          6  9.365000e+04        clean
#  1689963  2012.0   land rover          0          6  1.037740e+05        clean
#  123260   2015.0   land rover          2          6  3.672400e+04        clean
#  551828   2014.0   land rover          2          4  6.000000e+04        clean
#  ...         ...          ...        ...        ...           ...          ...
#  231836   1993.0   land rover          2          8  1.135850e+05        clean
#  5716     2013.0   land rover          0          6  1.135850e+05        clean
#  314562   2015.0   land rover          2          4  4.500000e+04        clean
#  1302604  2009.0   land rover          0          6  1.300000e+06        clean
#  1107835  2011.0   land rover          2          8  1.260000e+05        clean
#
#          transmission       size        lat        long
#  Id
#  686329     automatic  full-size  33.095400 -117.261900
#  1409194    automatic  full-size  38.917060  -77.469540
#  1689963    automatic  full-size  35.603540  -78.571766
#  123260     automatic  full-size  49.210740 -123.114853
#  551828     automatic   mid-size  39.045500  -76.924200
#  ...              ...        ...        ...         ...
#  231836        manual  full-size  42.170700  -72.604800
#  5716       automatic  full-size  43.452800 -110.739300
#  314562     automatic   mid-size  43.744344  -79.300990
#  1302604    automatic  full-size  33.566700  -84.436400
#  1107835    automatic  full-size  30.429114  -84.195530
#
#  [1551 rows x 10 columns],
#  'bmw':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  576171   2006.0          bmw          2          6  119000.000000
#  1690465  2002.0          bmw          0          6  260344.000000
#  1288292  2006.0          bmw          0          6  113584.991571
#  710260   2001.0          bmw          1          6  130900.000000
#  1369680  2001.0          bmw          2          6   92523.000000
#  ...         ...          ...        ...        ...            ...
#  728656   2007.0          bmw          2          6  147000.000000
#  1357986  2007.0          bmw          1          6   97410.000000
#  372768   2014.0          bmw          2          4   86000.000000
#  749225   2011.0          bmw          2          6   68016.000000
#  1327644  2010.0          bmw          0          6   80378.000000
#
#          title_status transmission       size        lat        long
#  Id
#  576171         clean    automatic  full-size  44.022300 -121.298500
#  1690465        clean       manual  full-size  35.859895  -78.711173
#  1288292        clean    automatic  full-size  30.373296  -97.651810
#  710260         clean    automatic  full-size  37.757592 -122.394107
#  1369680        clean        other    compact  43.525000 -116.610000
#  ...              ...          ...        ...        ...         ...
#  728656         clean    automatic  full-size  34.690900 -118.149100
#  1357986        clean    automatic  full-size  44.484000  -73.219900
#  372768         clean    automatic   mid-size  43.744344  -79.301162
#  749225         clean       manual  full-size  38.637025 -121.320825
#  1327644        clean    automatic  full-size  41.134500  -96.245800
#
#  [11840 rows x 10 columns],
#  'dodge':                 year manufacturer  condition  cylinders       odometer  \
#  Id
#  1429566  2018.000000        dodge          0          6  113584.991571
#  1133731  2000.000000        dodge          0          6  113584.991571
#  1475021  2005.000000        dodge          0          6  113682.000000
#  568200   2003.000000        dodge          1          6  135000.000000
#  1248485  2012.000000        dodge          2          4   58000.000000
#  ...              ...          ...        ...        ...            ...
#  1534465  2007.000000        dodge          0          6  113584.991571
#  1084557  2017.000000        dodge          1          6    6711.000000
#  477736   2013.000000        dodge          1          6   87000.000000
#  1062054  1999.000000        dodge          1          8     250.000000
#  624891   2004.869185        dodge          0          6  113584.991571
#
#          title_status transmission         size        lat        long
#  Id
#  1429566        clean    automatic    full-size  37.720000  -89.215800
#  1133731        clean    automatic    full-size  29.165000  -81.539900
#  1475021        clean       manual    full-size  47.801900 -117.589400
#  568200         clean    automatic     mid-size  44.304500 -120.833600
#  1248485        clean    automatic  sub-compact  26.165602  -97.705165
#  ...              ...          ...          ...        ...         ...
#  1534465      salvage    automatic    full-size  35.077600 -106.187200
#  1084557        clean        other    full-size  35.100000  -90.000000
#  477736       salvage    automatic     mid-size  33.493900 -112.169600
#  1062054        clean    automatic    full-size  39.754871  -94.500620
#  624891         clean    automatic    full-size  37.600004 -120.938713
#
#  [20779 rows x 10 columns],
#  'chrysler':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  690608   1950.0     chrysler          1          8  154000.000000
#  477921   2006.0     chrysler          1          6  119885.000000
#  1419190  2005.0     chrysler          1          6  129145.000000
#  447687   2012.0     chrysler          0          6  153000.000000
#  1226713  2015.0     chrysler          0          6   28500.000000
#  ...         ...          ...        ...        ...            ...
#  390901   2004.0     chrysler          2          4   55000.000000
#  472600   2006.0     chrysler          2          6   74712.000000
#  1009216  2005.0     chrysler          0          6  113584.991571
#  1149416  2006.0     chrysler          0          6  113584.991571
#  882889   2013.0     chrysler          1          6   76662.000000
#
#          title_status transmission       size        lat        long
#  Id
#  690608         clean    automatic  full-size  36.972288 -121.892178
#  477921         clean    automatic  full-size  34.894205 -111.874246
#  1419190         lien    automatic  full-size  39.149400  -89.488100
#  447687         clean    automatic  full-size  39.739000  -84.085600
#  1226713        clean    automatic   mid-size  31.535000  -97.189900
#  ...              ...          ...        ...        ...         ...
#  390901         clean    automatic   mid-size  31.439100  -85.643600
#  472600         clean    automatic  full-size  41.389700  -81.735100
#  1009216      salvage    automatic  full-size  34.924500  -82.319700
#  1149416        clean    automatic  full-size  27.196800  -80.253800
#  882889         clean    automatic  full-size  42.439874  -83.102712
#
#  [8658 rows x 10 columns],
#  'mitsubishi':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  751296   2012.0   mitsubishi          2          4   70000.000000
#  81351    2015.0   mitsubishi          0          6   23090.000000
#  1585758  2008.0   mitsubishi          1          6  113584.991571
#  63526    2007.0   mitsubishi          0          6  113584.991571
#  591048   2002.0   mitsubishi          1          4  144000.000000
#  ...         ...          ...        ...        ...            ...
#  333668   2016.0   mitsubishi          1          6   28529.000000
#  1151633  2003.0   mitsubishi          2          6  185000.000000
#  1698691  2001.0   mitsubishi          2          6  113584.991571
#  191762   2011.0   mitsubishi          0          6   60078.000000
#  1596504  1997.0   mitsubishi          2          6  113584.991571
#
#          title_status transmission         size        lat        long
#  Id
#  751296         clean    automatic     mid-size  41.709700  -70.158500
#  81351          clean       manual      compact  29.852359  -95.412096
#  1585758        clean    automatic    full-size  40.814600  -73.502400
#  63526          clean    automatic    full-size  33.727800  -84.214300
#  591048         clean    automatic     mid-size  45.498400 -122.957000
#  ...              ...          ...          ...        ...         ...
#  333668         clean    automatic    full-size  42.029800  -87.985995
#  1151633        clean    automatic    full-size  26.395714  -81.807804
#  1698691        clean    automatic    full-size  36.040300  -80.193300
#  191762         clean       manual  sub-compact  35.638878  -87.016869
#  1596504        clean    automatic    full-size  40.737500  -73.981300
#
#  [2945 rows x 10 columns],
#  'ford':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  931606   1997.0         ford          0          6  113584.991571
#  229951   2018.0         ford          2          6      38.000000
#  133494   2004.0         ford          1          8  113584.991571
#  59980    1975.0         ford          1          8   80000.000000
#  1266110  2008.0         ford          2          8     266.000000
#  ...         ...          ...        ...        ...            ...
#  103714   2001.0         ford          1          8  179000.000000
#  645068   2014.0         ford          0          6  113584.991571
#  605610   2003.0         ford          2          8  113584.991571
#  1038628  2010.0         ford          2          8  113584.991571
#  1505912  2005.0         ford          0          6  238047.000000
#
#          title_status transmission       size        lat        long
#  Id
#  931606         clean    automatic  full-size  43.483300  -83.383500
#  229951         clean    automatic  full-size  49.201117 -122.924410
#  133494         clean    automatic  full-size  45.600900  -88.106700
#  59980          clean       manual  full-size  39.620600 -105.090100
#  1266110        clean    automatic  full-size  32.705950  -97.326378
#  ...              ...          ...        ...        ...         ...
#  103714         clean    automatic  full-size  42.689600  -88.039000
#  645068         clean    automatic  full-size  40.450919 -122.300934
#  605610         clean    automatic  full-size  45.309900 -122.968500
#  1038628        clean    automatic  full-size  39.095572  -93.178816
#  1505912        clean    automatic  full-size  48.077990 -123.159590
#
#  [79933 rows x 10 columns],
#  'porche':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  460254   2004.0       porche          1          8  113584.991571
#  214525   1986.0       porche          2          6  100000.000000
#  1249646  2001.0       porche          1          6  139000.000000
#  86039    1985.0       porche          2          4   94280.000000
#  680575   2011.0       porche          0          6  113584.991571
#  1491844  2016.0       porche          2          6   22400.000000
#  199702   1983.0       porche          0          6  116000.000000
#  1169925  1974.0       porche          0          6  113584.991571
#  84224    2004.0       porche          1          6  113584.991571
#  1311307  2004.0       porche          0          6  113584.991571
#  753055   1986.0       porche          2          8   86000.000000
#  590487   2014.0       porche          2          6   12000.000000
#  533877   2006.0       porche          2          6  113584.991571
#  43107    2005.0       porche          2          6  158900.000000
#  1286511  2006.0       porche          2          8  161000.000000
#  1377860  2005.0       porche          0          6  113584.991571
#  658165   2006.0       porche          2          6  147000.000000
#  770697   2004.0       porche          2          6   94000.000000
#  1080122  1997.0       porche          2          6  109000.000000
#  80189    2004.0       porche          0          6  113584.991571
#  1632136  1983.0       porche          0          6  113584.991571
#  1644684  1983.0       porche          0          6  113584.991571
#  1234311  2008.0       porche          2          6   74000.000000
#  100335   2004.0       porche          0          8  113584.991571
#  1021298  2004.0       porche          1          6  113000.000000
#  774282   1986.0       porche          2          8   86000.000000
#  189547   2005.0       porche          1          6  110000.000000
#  497457   2003.0       porche          2          6  103000.000000
#
#          title_status transmission       size        lat        long
#  Id
#  460254         clean    automatic  full-size  41.703900  -83.603400
#  214525         clean    automatic  full-size  42.028700  -71.526900
#  1249646        clean       manual  full-size  30.403600  -97.752600
#  86039          clean       manual    compact  43.512600  -83.583500
#  680575         clean    automatic  full-size  33.955300 -117.245700
#  1491844        clean    automatic  full-size  46.738896 -117.172709
#  199702         clean       manual  full-size  61.570217 -149.338394
#  1169925        clean       manual  full-size  29.678500  -82.367900
#  84224          clean    automatic  full-size  36.814000  -76.240600
#  1311307        clean    automatic  full-size  33.705100  -84.380800
#  753055         clean    automatic   mid-size  41.676263  -70.195335
#  590487         clean    automatic  full-size  45.402100 -122.614400
#  533877       rebuilt        other  full-size  36.184297  -94.148603
#  43107          clean    automatic  full-size  30.769864  -84.048843
#  1286511        clean    automatic  full-size  32.955097  -96.916409
#  1377860        clean    automatic  full-size  42.784600  -71.217600
#  658165         clean    automatic   mid-size  34.151000 -118.366300
#  770697         clean    automatic   mid-size  41.718200  -71.140000
#  1080122        clean       manual    compact  36.513104  -86.891387
#  80189          clean    automatic  full-size  43.118800  -87.947800
#  1632136        clean       manual  full-size  44.906400  -89.581800
#  1644684        clean       manual  full-size  44.906400  -89.581800
#  1234311        clean    automatic  full-size  29.844000  -95.662300
#  100335         clean    automatic  full-size  41.835100  -71.397100
#  1021298        clean    automatic  full-size  34.977100  -89.999200
#  774282         clean    automatic   mid-size  41.673900  -70.194900
#  189547         clean    automatic  full-size  41.462200  -72.112600
#  497457         clean    automatic    compact  33.815500 -112.120200  ,
#  'ram':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  1265412  2003.0          ram          0          8  113584.991571
#  1203620  2006.0          ram          0          6  208270.000000
#  838967   1995.0          ram          0          8  113584.991571
#  1403469  2003.0          ram          1          6  390000.000000
#  1327267  2010.0          ram          1          6  198188.000000
#  ...         ...          ...        ...        ...            ...
#  1679395  2015.0          ram          0          6   47201.000000
#  594726   2015.0          ram          0          6   36234.000000
#  862055   2010.0          ram          0          8  142640.000000
#  1025143  2011.0          ram          1          6  198670.000000
#  1298707  2007.0          ram          0          6  176050.000000
#
#          title_status transmission       size        lat        long
#  Id
#  1265412        clean    automatic  full-size  27.850069  -99.668883
#  1203620        clean    automatic  full-size  46.707400 -111.958000
#  838967         clean    automatic  full-size  37.646500 -104.779800
#  1403469        clean    automatic  full-size  37.309329  -79.235928
#  1327267        clean    automatic  full-size  41.211700  -96.621900
#  ...              ...          ...        ...        ...         ...
#  1679395        clean    automatic  full-size  35.018200  -78.914647
#  594726         clean    automatic  full-size  42.453650 -123.321290
#  862055         clean    automatic  full-size  39.081944 -108.588542
#  1025143        clean    automatic  full-size  34.330800  -89.483500
#  1298707        clean    automatic  full-size  30.650210  -97.865150
#
#  [15561 rows x 10 columns],
#  'chevrolet':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  203486   2001.0    chevrolet          0          6   96000.000000
#  646472   1997.0    chevrolet          1          6  180000.000000
#  70746    2005.0    chevrolet          0          6  109715.000000
#  1429295  2014.0    chevrolet          2          4   66344.000000
#  1451731  2006.0    chevrolet          2          8  206629.000000
#  ...         ...          ...        ...        ...            ...
#  437652   2000.0    chevrolet          0          6  186056.000000
#  316066   2010.0    chevrolet          2          4  161308.000000
#  400020   2016.0    chevrolet          0          6  116801.000000
#  87925    2007.0    chevrolet          0          6  113584.991571
#  690884   2015.0    chevrolet          0          6  103414.000000
#
#          title_status transmission       size        lat        long
#  Id
#  203486         clean    automatic  full-size  43.169800  -77.600700
#  646472          lien    automatic  full-size  40.447664 -122.298730
#  70746          clean    automatic  full-size  42.788204  -71.233728
#  1429295        clean    automatic    compact  38.584848  -89.985587
#  1451731        clean    automatic  full-size  40.048903  -74.141727
#  ...              ...          ...        ...        ...         ...
#  437652         clean    automatic  full-size  41.612850  -83.480782
#  316066         clean    automatic   mid-size  43.936473  -78.601685
#  400020         clean    automatic  full-size  33.972201  -86.056643
#  87925          clean    automatic  full-size  37.132840  -95.785580
#  690884         clean    automatic  full-size  34.070311 -117.446303
#
#  [71349 rows x 10 columns],
#  'infiniti':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  872220   2004.0     infiniti          0          6  113584.991571
#  1680494  2000.0     infiniti          1          0  188000.000000
#  666918   2006.0     infiniti         -1          6  169000.000000
#  168781   2014.0     infiniti          0          6   91964.000000
#  737413   2013.0     infiniti          0          6  113584.991571
#  ...         ...          ...        ...        ...            ...
#  1437325  2008.0     infiniti          0          6  113584.991571
#  1310873  2007.0     infiniti          2          6  123604.000000
#  1034019  2014.0     infiniti          2          6   48000.000000
#  903831   2002.0     infiniti          0          4  202000.000000
#  617643   2015.0     infiniti          2          6  113584.991571
#
#          title_status transmission       size        lat        long
#  Id
#  872220         clean    automatic  full-size  42.769200  -86.116400
#  1680494        clean    automatic    compact  35.871300  -80.091300
#  666918       salvage    automatic  full-size  34.588333 -117.138716
#  168781         clean        other  full-size  38.641900  -94.328500
#  737413         clean    automatic  full-size  33.793800 -118.317200
#  ...              ...          ...        ...        ...         ...
#  1437325        clean    automatic  full-size  41.515061  -90.424765
#  1310873        clean    automatic  full-size  33.854734  -84.028618
#  1034019        clean    automatic  full-size  37.193061  -93.283324
#  903831         clean    automatic   mid-size  42.812781  -85.431576
#  617643         clean    automatic   mid-size  38.589200 -121.405700
#
#  [3406 rows x 10 columns],
#  'nissan':                 year manufacturer  condition  cylinders       odometer  \
#  Id
#  504420   2002.000000       nissan          0          6  150000.000000
#  1470561  2017.000000       nissan          0          6   41575.000000
#  1183281  2017.000000       nissan          1          6    3017.000000
#  715272   2007.000000       nissan          0          6  105222.000000
#  711115   2013.000000       nissan          2          6  144173.000000
#  ...              ...          ...        ...        ...            ...
#  1170883  2010.000000       nissan          2          4  113584.991571
#  442772   2005.000000       nissan          2          6  110000.000000
#  353759   2017.000000       nissan          0          6   39481.000000
#  1385959  2004.869185       nissan          1          6  152000.000000
#  251004   2016.000000       nissan          0          6   13208.000000
#
#          title_status transmission       size        lat        long
#  Id
#  504420       missing    automatic  full-size  43.695192  -70.351646
#  1470561        clean    automatic  full-size  47.766970 -117.405940
#  1183281        clean        other  full-size  28.500000  -81.370000
#  715272         clean    automatic  full-size  33.989000 -118.187700
#  711115         clean    automatic  full-size  39.145315 -121.596080
#  ...              ...          ...        ...        ...         ...
#  1170883        clean    automatic   mid-size  28.395061  -80.749430
#  442772         clean    automatic   mid-size  39.956037  -82.771297
#  353759         clean    automatic  full-size  42.259339  -84.349995
# ...
#  Id
#  869261         clean    automatic  full-size  43.144300  -86.138800
#  1576505        clean    automatic    compact  42.614800  -74.968500
#  6602           clean    automatic  full-size  42.330100  -83.272557
#  590131         clean       manual  full-size  45.574200 -122.684200
#  1154951        clean    automatic  full-size  30.143130  -81.640472
#  ...              ...          ...        ...        ...         ...
#  658322         clean    automatic   mid-size  36.985350 -121.989872
#  209844         clean    automatic  full-size  30.363300  -91.091900
#  148650         clean    automatic  full-size  34.726900  -86.567300
#  389299         clean    automatic  full-size  36.022301 -114.962607
#  724483         clean    automatic   mid-size  38.428136 -122.735101
#
#  [31722 rows x 10 columns],
#  'fiat':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  564971   2014.0         fiat          0          4   69088.000000
#  1085623  2012.0         fiat          0          6  113584.991571
#  126928   2012.0         fiat          2          4   70000.000000
#  190602   2016.0         fiat          0          4    3876.000000
#  195543   2012.0         fiat          0          6   55779.000000
#  ...         ...          ...        ...        ...            ...
#  741274   2015.0         fiat          0          0   21111.000000
#  495824   2012.0         fiat          2          4   53000.000000
#  359981   1982.0         fiat          0          6  113584.991571
#  932782   2012.0         fiat          0          6  156227.000000
#  62356    2013.0         fiat          2          4   62000.000000
#
#          title_status transmission         size        lat        long
#  Id
#  564971         clean    automatic     mid-size  42.378530 -122.857520
#  1085623        clean    automatic    full-size  36.137900  -86.741000
#  126928         clean    automatic     mid-size  42.258200  -90.435600
#  190602         clean    automatic  sub-compact  32.660500  -97.031100
#  195543         clean    automatic    full-size  49.237637 -123.071448
#  ...              ...          ...          ...        ...         ...
#  741274         clean    automatic  sub-compact  33.143405 -117.193062
#  495824         clean       manual     mid-size  34.818500 -112.958400
#  359981         clean        other    full-size  41.733200  -72.376700
#  932782         clean    automatic    full-size  43.182400  -84.112200
#  62356          clean    automatic      compact  34.742124  -76.809941
#
#  [560 rows x 10 columns],
#  'honda':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  941967   2007.0        honda          2          6  169000.000000
#  1705021  2007.0        honda          1          4  112070.000000
#  577586   2010.0        honda          2          4   85237.000000
#  680270   2002.0        honda          0          6  113584.991571
#  147590   1999.0        honda          1          4  113584.991571
#  ...         ...          ...        ...        ...            ...
#  996099   2003.0        honda          0          6  168000.000000
#  1186813  2007.0        honda          2          4  120000.000000
#  939113   2004.0        honda          2          6  168000.000000
#  221358   2003.0        honda          1          4   79742.000000
#  690622   2005.0        honda          0          4  113584.991571
#
#          title_status transmission       size        lat        long
#  Id
#  941967         clean    automatic  full-size  41.216000  -73.130400
#  1705021        clean    automatic  full-size  36.075407  -79.890687
#  577586         clean    automatic   mid-size  44.091500 -121.407300
#  680270         clean    automatic  full-size  34.048700 -118.208400
#  147590         clean       manual    compact  34.769686  -86.429495
#  ...              ...          ...        ...        ...         ...
#  996099         clean    automatic  full-size  34.915100  -81.012900
#  1186813        clean    automatic    compact  29.817500  -82.600600
#  939113         clean    automatic  full-size  41.605200  -71.980800
#  221358       rebuilt       manual    compact  29.983234  -90.213639
#  690622         clean       manual    compact  36.829371 -121.642483
#
#  [24585 rows x 10 columns],
#  'lexus':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  346088   2002.0        lexus          1          6  200229.000000
#  928922   2007.0        lexus          2          6  113584.991571
#  223420   2008.0        lexus          0          6  100556.000000
#  229480   2010.0        lexus          0          6   80752.000000
#  38676    2005.0        lexus          0          6  113584.991571
#  ...         ...          ...        ...        ...            ...
#  214795   2002.0        lexus          0          6  113584.991571
#  480602   2012.0        lexus          0          6   97400.000000
#  1120864  2007.0        lexus          2          6   93483.000000
#  1315891  1997.0        lexus          0          6  113584.991571
#  1035631  2001.0        lexus          2          6  113584.991571
#
#          title_status transmission       size        lat        long
#  Id
#  346088         clean    automatic    compact  43.168879 -111.017017
#  928922         clean    automatic  full-size  42.516400  -82.983200
#  223420         clean    automatic  full-size  44.834600  -91.515900
#  229480         clean    automatic  full-size  30.260542  -93.181528
#  38676          clean    automatic  full-size  46.856400  -96.812300
#  ...              ...          ...        ...        ...         ...
#  214795         clean    automatic  full-size  41.851436  -71.311986
#  480602         clean    automatic  full-size  33.330100 -111.863200
#  1120864        clean    automatic   mid-size  28.567194  -81.289892
#  1315891        clean    automatic  full-size  32.477900  -84.898000
#  1035631        clean    automatic  full-size  37.951153  -91.770631
#
#  [5523 rows x 10 columns],
#  'mercury':            year manufacturer  condition  cylinders      odometer title_status  \
#  Id
#  1578762  2005.0      mercury          2          6  9.646600e+06        clean
#  1228845  1967.0      mercury          2          8  4.632000e+04        clean
#  465051   2010.0      mercury          2          6  6.406000e+04        clean
#  1104598  2000.0      mercury          2          8  1.390000e+05        clean
#  276911   2002.0      mercury          0          6  1.460000e+05        clean
#  ...         ...          ...        ...        ...           ...          ...
#  1698886  1994.0      mercury          1          8  1.460000e+05        clean
#  1645204  1996.0      mercury          2          6  1.625210e+05        clean
#  1424750  2005.0      mercury          1          8  1.260000e+05        clean
#  714568   2003.0      mercury          1          6  1.135850e+05        clean
#  1512105  2003.0      mercury          1          6  1.690000e+05        clean
#
#          transmission       size        lat        long
#  Id
#  1578762    automatic  full-size  42.746200  -73.763000
#  1228845    automatic  full-size  32.652500  -96.558000
#  465051     automatic   mid-size  41.030560  -80.728080
#  1104598    automatic  full-size  27.588500  -80.392300
#  276911     automatic  full-size  39.532100  -84.389600
#  ...              ...        ...        ...         ...
#  1698886    automatic  full-size  35.909719  -80.809507
#  1645204    automatic   mid-size  44.887729  -89.339486
#  1424750    automatic  full-size  40.099760  -88.201675
#  714568     automatic   mid-size  34.964467 -120.577462
#  1512105    automatic  full-size  41.097700  -85.118900
#
#  [2793 rows x 10 columns],
#  'audi':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  13357    2005.0         audi          0          6  113584.991571
#  563595   2005.0         audi          2          4  122000.000000
#  354761   2011.0         audi          2          6   98900.000000
#  1497183  2003.0         audi          2          4   20000.000000
#  516585   2006.0         audi          1          4  156000.000000
#  ...         ...          ...        ...        ...            ...
#  1453834  2003.0         audi          0          6  182000.000000
#  859434   2011.0         audi          2          4  120496.000000
#  1128663  2011.0         audi          0          6   95000.000000
#  1548604  2008.0         audi          2          6  156000.000000
#  248112   2007.0         audi          2          4  184502.000000
#
#          title_status transmission       size        lat        long
#  Id
#  13357        salvage    automatic  full-size  43.614100  -72.970800
#  563595         clean    automatic  full-size  39.125106  -76.487417
#  354761         clean    automatic  full-size  40.519150 -111.395788
#  1497183        clean        other   mid-size  47.615500 -122.207200
#  516585         clean    automatic   mid-size  35.119200  -97.640100
#  ...              ...          ...        ...        ...         ...
#  1453834        clean    automatic  full-size  39.880500  -74.970600
#  859434         clean    automatic  full-size  39.740062 -105.050143
#  1128663        clean    automatic  full-size  26.320225  -81.762299
#  1548604        clean    automatic  full-size  41.569500  -93.799400
#  248112         clean    automatic   mid-size  40.029300  -74.949700
#
#  [4076 rows x 10 columns],
#  'saturn':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  1367601  2008.0       saturn          2          4  113584.991571
#  101468   2008.0       saturn          0          6  113584.991571
#  145676   2005.0       saturn          2          4  133480.000000
#  1636317  2006.0       saturn          0          4  160069.000000
#  1618201  2004.0       saturn          0          4     123.000000
#  ...         ...          ...        ...        ...            ...
#  1460963  2007.0       saturn          0          6  113584.991571
#  453981   2007.0       saturn          0          6  140350.000000
#  912204   2006.0       saturn          1          4   92970.000000
#  801123   2006.0       saturn          2          6  113584.991571
#  382200   2004.0       saturn          1          4  214000.000000
#
#          title_status transmission       size        lat        long
#  Id
#  1367601        clean    automatic  full-size  43.731800 -116.279700
#  101468         clean    automatic  full-size  40.505748  -96.705321
#  145676         clean       manual    compact  33.611500  -85.588500
#  1636317        clean       manual    compact  43.103964  -89.511643
#  1618201        clean    automatic   mid-size  43.183400  -77.604300
#  ...              ...          ...        ...        ...         ...
#  1460963        clean    automatic  full-size  40.517600  -74.275400
#  453981         clean    automatic   mid-size  39.245416  -84.547863
#  912204         clean       manual    compact  43.037800  -86.191200
#  801123         clean    automatic   mid-size  40.229061  -77.106342
#  382200         clean       manual   mid-size  39.949400  -76.713000
#
#  [2599 rows x 10 columns],
#  'datsun':            year manufacturer  condition  cylinders       odometer  \
#  Id
#  1567918  1981.0       datsun          0          6   62000.000000
#  1017016  1983.0       datsun          0          6  113584.991571
#  199894   1982.0       datsun          2          6  137939.000000
#  976280   1980.0       datsun          0          4  107000.000000
#  731953   1971.0       datsun          2          4  113584.991571
#  ...         ...          ...        ...        ...            ...
#  198268   1997.0       datsun          0          6  113584.991571
#  680422   1980.0       datsun          0          6  113584.991571
#  1179224  1984.0       datsun          1          6  295000.000000
#  1028242  1983.0       datsun          1          4  113584.991571
#  169295   1982.0       datsun         -1          6  193472.000000
#
#          title_status transmission       size        lat        long
#  Id
#  1567918        clean    automatic  full-size  42.940829  -78.867687
#  1017016        clean       manual  full-size  32.230877  -90.855886
#  199894         clean        other  full-size  35.554950  -77.406270
#  976280         clean       manual   mid-size  46.625700  -94.268400
#  731953          lien    automatic   mid-size  40.043000 -122.164900
#  ...              ...          ...        ...        ...         ...
#  198268         clean       manual  full-size  64.878089 -148.214529
#  680422         clean       manual  full-size  33.976100 -117.338900
#  1179224        clean       manual    compact  28.235288  -82.758207
#  1028242        clean       manual   mid-size  43.470500  -97.998800
#  169295       missing       manual  full-size  37.259300  -93.291200
#
#  [159 rows x 10 columns],
#  'unknown':                 year manufacturer  condition  cylinders       odometer  \
#  Id
#  559327   2006.000000      unknown          2          4  190000.000000
#  1260418  1980.000000      unknown          0          8  150000.000000
#  792110   2007.000000      unknown          2          8    1544.000000
#  1191078  2004.869185      unknown          0          4   12905.000000
#  228988   2009.000000      unknown          0          8  113584.991571
#  ...              ...          ...        ...        ...            ...
#  1561693  1984.000000      unknown          1          6    8888.000000
#  274624   2016.000000      unknown          0          6  113584.991571
#  681992   1979.000000      unknown          2          4  113584.991571
#  945416   2011.000000      unknown          0          6  113584.991571
#  589143   2013.000000      unknown          2          4   60400.000000
#
#          title_status transmission       size        lat        long
#  Id
#  559327         clean    automatic   mid-size  39.287000  -76.647600
#  1260418        clean       manual  full-size  27.807204  -97.398469
#  792110         clean    automatic    compact  40.275500  -80.059800
#  1191078        clean    automatic   mid-size  25.991206  -80.204135
#  228988         clean    automatic  full-size  30.207700  -92.065600
#  ...              ...          ...        ...        ...         ...
#  1561693        clean    automatic    compact  42.449402  -94.291964
#  274624         clean    automatic  full-size  33.521000  -86.806600
#  681992         clean       manual    compact  33.648300 -117.915500
#  945416         clean    automatic  full-size  41.540100  -72.818900
#  589143         clean    automatic  full-size  42.493500 -122.808800
#
#  [37260 rows x 10 columns]}

# %%
# Normalize columns
norm = ['year','condition','cylinders','odometer','lat','long']
for i, X in X_dec.items():
    X[norm] = normalize(X[norm])
for i, X_sub in X_sub_dec.items():
    X_sub[norm] = normalize(X_sub[norm])

# %%
X_dec
# Out:
# {'ferrari':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1446117  0.115744      ferrari   0.000058   0.000234  0.993263        clean
#  723398   0.017658      ferrari   0.000000   0.000053  0.999844        clean
#  1321337  0.049788      ferrari   0.000050   0.000200  0.998757        clean
#  608244   0.113560      ferrari   0.000056   0.000452  0.993506        clean
#  684579   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#  162605   0.117210      ferrari   0.000117   0.000350  0.993077        clean
#  635380   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#  315525   0.042871      ferrari   0.000043   0.000171  0.999079        clean
#  212262   0.017473      ferrari   0.000000   0.000053  0.999847      rebuilt
#  1190071  0.077948      ferrari   0.000000   0.000312  0.996952        clean
#  482666   0.245215      ferrari   0.000000   0.000978  0.969363        clean
#  841806   0.269206      ferrari   0.000000   0.001074  0.962964        clean
#  642271   0.050094      ferrari   0.000000   0.000151  0.998739        clean
#  740451   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#  43879    0.359490      ferrari   0.000179   0.001429  0.932851        clean
#  1376282  0.017648      ferrari   0.000018   0.000070  0.999844        clean
#  1121000  0.106877      ferrari   0.000108   0.000432  0.994261        clean
#  1175427  0.164875      ferrari   0.000164   0.000493  0.986288        clean
#  988052   0.103836      ferrari   0.000000   0.000311  0.994580        clean
#  1500489  0.044264      ferrari   0.000045   0.000178  0.999015        clean
#  1174089  0.101284      ferrari   0.000000   0.000303  0.994848        clean
#  737730   0.017764      ferrari   0.000000   0.000053  0.999842        clean
#  670095   0.070927      ferrari   0.000000   0.000425  0.997472        clean
#  631033   0.260863      ferrari   0.000000   0.000779  0.965243        clean
#  668606   0.894620      ferrari   0.000887   0.002661  0.443540        clean
#  560731   0.027182      ferrari   0.000027   0.000110  0.999630        clean
#  632686   0.067152      ferrari   0.000000   0.000201  0.997734        clean
#  715026   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#  669494   0.074264      ferrari   0.000074   0.000296  0.997229        clean
#  660764   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#  496613   0.129606      ferrari   0.000129   0.000517  0.991537        clean
#  225673   0.069071      ferrari   0.000000   0.000207  0.997607        clean
#  583172   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#  585996   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#  1661060  0.017473      ferrari   0.000018   0.000035  0.999847        clean
#  339023   0.084584      ferrari   0.000085   0.000254  0.996401        clean
#  322047   0.117210      ferrari   0.000117   0.000350  0.993077        clean
#  1499004  0.068867      ferrari   0.000034   0.000275  0.997615        clean
#  1450224  0.557607      ferrari   0.000553   0.001660  0.829773      rebuilt
#  76395    0.083374      ferrari   0.000083   0.000249  0.996503        clean
#  614715   0.067463      ferrari   0.000067   0.000268  0.997713        clean
#  1207437  0.017693      ferrari   0.000000   0.000070  0.999843        clean
#  680826   0.017711      ferrari   0.000000   0.000053  0.999843        clean
#  1473912  0.068867      ferrari   0.000034   0.000206  0.997616        clean
#  344248   0.077001      ferrari   0.000077   0.000307  0.997026        clean
#  94328    0.074264      ferrari   0.000074   0.000296  0.997229        clean
#  1572642  0.052349      ferrari   0.000053   0.000211  0.998626        clean
#  781747   0.017561      ferrari   0.000009   0.000053  0.999845        clean
#  682339   0.017755      ferrari   0.000000   0.000053  0.999842        clean
#  683466   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#  1391340  0.017658      ferrari   0.000000   0.000053  0.999844        clean
#  611384   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#  1483454  0.068867      ferrari   0.000034   0.000206  0.997616        clean
#  592246   0.112069      ferrari   0.000000   0.000335  0.993674        clean
#  686162   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#  177995   0.036013      ferrari   0.000018   0.000145  0.999350        clean
#  638012   0.091760      ferrari   0.000093   0.000371  0.995764        clean
#  686164   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#  1133467  0.017508      ferrari   0.000000   0.000053  0.999846        clean
#  228068   0.017464      ferrari   0.000000   0.000053  0.999847   parts only
#
#          transmission         size       lat      long
#  Id
#  1446117       manual      compact  0.002343 -0.005158
#  723398        manual    full-size  0.000297 -0.001038
#  1321337       manual    full-size  0.000858 -0.002071
#  608244     automatic     mid-size  0.002005 -0.006818
#  684579     automatic    full-size  0.000608 -0.002095
#  162605     automatic    full-size  0.002868 -0.007180
#  635380        manual    full-size  0.001243 -0.004252
#  315525        manual      compact  0.000553 -0.001721
#  212262        manual    full-size  0.000268 -0.000801
#  1190071    automatic    full-size  0.001041 -0.003121
#  482666     automatic    full-size  0.004086 -0.013681
#  841806     automatic    full-size  0.005436 -0.014085
#  642271        manual    full-size  0.000922 -0.003071
#  740451     automatic    full-size  0.001249 -0.004308
#  43879          other    full-size  0.008711 -0.021882
#  1376282        other    full-size  0.000380 -0.000630
#  1121000       manual    full-size  0.001542 -0.004418
#  1175427    automatic    full-size  0.002245 -0.006785
#  988052     automatic    full-size  0.002343 -0.004842
#  1500489       manual    full-size  0.001090 -0.002734
#  1174089       manual    full-size  0.001390 -0.004171
#  737730         other    full-size  0.000319 -0.001051
#  670095     automatic    full-size  0.001200 -0.004154
#  631033     automatic      compact  0.004444 -0.015360
#  668606        manual    full-size  0.014661 -0.052013
#  560731        manual     mid-size  0.000534 -0.001047
#  632686     automatic    full-size  0.001266 -0.004100
#  715026        manual    full-size  0.001243 -0.004252
#  669494     automatic    full-size  0.001249 -0.004308
#  660764     automatic    full-size  0.000608 -0.002095
#  496613     automatic    full-size  0.002160 -0.007231
#  225673         other    full-size  0.001339 -0.002658
#  583172         other  sub-compact  0.002514 -0.006762
#  585996         other  sub-compact  0.002514 -0.006762
#  1661060       manual      compact  0.000394 -0.000770
#  339023     automatic    full-size  0.002082 -0.005200
#  322047     automatic    full-size  0.002869 -0.007180
#  1499004    automatic    full-size  0.001675 -0.004209
#  1450224    automatic    full-size  0.011302 -0.020489
#  76395      automatic    full-size  0.002039 -0.005092
#  614715     automatic    full-size  0.001292 -0.004068
#  1207437    automatic    full-size  0.000401 -0.000978
#  680826     automatic    full-size  0.000299 -0.001043
#  1473912    automatic    full-size  0.001675 -0.004209
#  344248         other    full-size  0.001657 -0.002743
#  94328      automatic    full-size  0.001249 -0.004308
#  1572642       manual    full-size  0.001080 -0.001946
#  781747     automatic    full-size  0.000365 -0.000668
#  682339     automatic    full-size  0.000297 -0.001036
#  683466     automatic    full-size  0.000608 -0.002095
#  1391340        other    full-size  0.000331 -0.000683
#  611384     automatic    full-size  0.001249 -0.004308
#  1483454    automatic    full-size  0.001675 -0.004209
#  592246     automatic    full-size  0.002456 -0.006762
#  686162        manual      compact  0.001942 -0.006853
#  177995        manual     mid-size  0.000694 -0.001554
#  638012        manual    full-size  0.001717 -0.005659
#  686164        manual      compact  0.001942 -0.006853
#  1133467    automatic    full-size  0.000257 -0.000713
#  228068     automatic    full-size  0.000268 -0.000802  ,
#  'kia':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  44975    0.017667          kia   0.000000   0.000053  0.999844      rebuilt
#  1382032  0.013416          kia   0.000000   0.000040  0.999910        clean
#  307219   0.017737          kia   0.000018   0.000053  0.999842        clean
#  114205   0.121534          kia   0.000000   0.000361  0.992569        clean
#  1383241  0.025614          kia   0.000013   0.000051  0.999671        clean
#  ...           ...          ...        ...        ...       ...          ...
#  200155   0.586052          kia   0.000000   0.001742  0.809379        clean
#  195247   0.017746          kia   0.000018   0.000035  0.999842        clean
#  1162856  0.049018          kia   0.000049   0.000243  0.998796        clean
#  1545496  0.042642          kia   0.000043   0.000128  0.999089        clean
#  1178799  0.071778          kia   0.000071   0.000214  0.997416        clean
#
#          transmission       size       lat      long
#  Id
#  44975      automatic  full-size  0.000329 -0.000839
#  1382032    automatic  full-size  0.000260 -0.000517
#  307219     automatic  full-size  0.000450 -0.001004
#  114205     automatic  full-size  0.002445 -0.005398
#  1383241    automatic   mid-size  0.000475 -0.001019
#  ...              ...        ...       ...       ...
#  200155     automatic  full-size  0.013061 -0.035726
#  195247     automatic   mid-size  0.000433 -0.001084
#  1162856        other    compact  0.000692 -0.001980
#  1545496    automatic  full-size  0.000842 -0.001699
#  1178799    automatic  full-size  0.001015 -0.002894
#
#  [6799 rows x 10 columns],
#  'harley-davidson':              year     manufacturer  condition  cylinders  odometer  \
#  Id
#  1499415  0.028011  harley-davidson   0.000000   0.000084  0.999606
#  1232633  0.017614  harley-davidson   0.000000   0.000053  0.999844
#  1470558  0.018947  harley-davidson   0.000000   0.000057  0.999820
#  4002     0.017755  harley-davidson   0.000018   0.000053  0.999842
#  826783   0.280172  harley-davidson   0.000000   0.000835  0.959874
#  ...           ...              ...        ...        ...       ...
#  1516723  0.018270  harley-davidson   0.000009   0.000073  0.999833
#  761832   0.017632  harley-davidson   0.000018   0.000053  0.999844
#  1515570  0.202025  harley-davidson   0.000202   0.000606  0.979333
#  103538   0.084587  harley-davidson   0.000000   0.000252  0.996402
#  1549533  0.015226  harley-davidson   0.000015   0.000061  0.999884
#
#          title_status transmission       size       lat      long
#  Id
#  1499415        clean    automatic  full-size  0.000670 -0.001701
#  1232633        clean       manual  full-size  0.000281 -0.000901
#  1470558        clean    automatic  full-size  0.000450 -0.001107
#  4002         rebuilt       manual  full-size  0.000313 -0.000711
#  826783         clean       manual  full-size  0.005586 -0.010656
#  ...              ...          ...        ...       ...       ...
#  1516723        clean    automatic  full-size  0.000379 -0.000777
#  761832         clean       manual  full-size  0.000371 -0.000638
#  1515570        clean       manual  full-size  0.004017 -0.008681
#  103538         clean        other  full-size  0.002003 -0.004929
#  1549533        clean    automatic  full-size  0.000326 -0.000729
#
#  [202 rows x 10 columns],
#  'morgan':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1173925  0.017262       morgan   0.000018   0.000035  0.999851        clean
#  704129   0.007273       morgan   0.000000   0.000044  0.999973        clean
#  1147457  0.038810       morgan   0.000020   0.000079  0.999245        clean
#  816430   0.017711       morgan   0.000018   0.000053  0.999843        clean
#
#          transmission       size       lat      long
#  Id
#  1173925       manual   mid-size  0.000233 -0.000720
#  704129         other   mid-size  0.000141 -0.000442
#  1147457       manual   mid-size  0.000590 -0.001604
#  816430     automatic  full-size  0.000352 -0.000661  ,
#  'mazda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  848677   0.014546        mazda   0.000000   0.000043  0.999894        clean
#  1390549  0.059204        mazda   0.000059   0.000118  0.998243         lien
#  260963   0.998726        mazda   0.000000   0.002996  0.000499        clean
#  686158   0.282057        mazda   0.000000   0.000559  0.959246        clean
#  9714     0.021608        mazda   0.000011   0.000043  0.999766      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  1277044  0.014247        mazda   0.000000   0.000043  0.999898        clean
#  416386   0.044365        mazda   0.000000   0.000088  0.999009        clean
#  1003608  0.013176        mazda   0.000007   0.000039  0.999913   parts only
#  226827   0.016094        mazda   0.000016   0.000032  0.999870        clean
#  428050   0.811503        mazda   0.000804   0.002413  0.583092        clean
#
#          transmission       size       lat      long
#  Id
#  848677     automatic   mid-size  0.000287 -0.000760
#  1390549    automatic    compact  0.001104 -0.002334
#  260963     automatic  full-size  0.018125 -0.047003
#  686158     automatic   mid-size  0.004631 -0.016398
#  9714       automatic   mid-size  0.000404 -0.001046
#  ...              ...        ...       ...       ...
#  1277044    automatic   mid-size  0.000196 -0.000691
#  416386     automatic   mid-size  0.001347 -0.003298
#  1003608    automatic  full-size  0.000226 -0.000527
#  226827        manual   mid-size  0.000260 -0.000750
#  428050     automatic  full-size  0.012065 -0.036257
#
#  [6380 rows x 10 columns],
#  'mini':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  459196   0.025223         mini   0.000000   0.000075  0.999681        clean
#  1028076  0.008724         mini   0.000004   0.000026  0.999962        clean
#  1534331  0.025105         mini   0.000025   0.000050  0.999684        clean
#  651321   0.030831         mini   0.000015   0.000062  0.999523        clean
#  238909   0.018742         mini   0.000009   0.000037  0.999824        clean
#  ...           ...          ...        ...        ...       ...          ...
#  121016   0.043271         mini   0.000043   0.000086  0.999060        clean
#  784895   0.022801         mini   0.000023   0.000045  0.999740        clean
#  1336398  0.017895         mini   0.000000   0.000054  0.999839        clean
#  1353084  0.036137         mini   0.000000   0.000072  0.999344        clean
#  156559   0.026271         mini   0.000026   0.000052  0.999653        clean
#
#          transmission         size       lat      long
#  Id
#  459196     automatic  sub-compact  0.000494 -0.001059
#  1028076    automatic     mid-size  0.000192 -0.000450
#  1534331       manual      compact  0.000444 -0.001324
#  651321     automatic     mid-size  0.000558 -0.001834
#  238909        manual      compact  0.000397 -0.001072
#  ...              ...          ...       ...       ...
#  121016     automatic      compact  0.000790 -0.002325
#  784895     automatic     mid-size  0.000457 -0.000873
#  1336398       manual      compact  0.000370 -0.000862
#  1353084       manual     mid-size  0.000709 -0.002152
#  156559        manual     mid-size  0.000645 -0.001625
#
#  [1745 rows x 10 columns],
#  'volvo':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  473356   0.014016        volvo   0.000014   0.000042  0.999902        clean
#  1578360  0.023086        volvo   0.000000   0.000069  0.999733        clean
#  1570403  0.014013        volvo   0.000000   0.000035  0.999902        clean
#  1721281  0.016097        volvo   0.000008   0.000064  0.999870      salvage
#  1393864  0.013590        volvo   0.000014   0.000034  0.999907        clean
#  ...           ...          ...        ...        ...       ...          ...
#  599064   0.017658        volvo   0.000000   0.000053  0.999843        clean
#  490973   0.017640        volvo   0.000018   0.000053  0.999844        clean
#  70404    0.018279        volvo   0.000018   0.000055  0.999833        clean
#  648528   0.011892        volvo   0.000006   0.000024  0.999929        clean
#  1359380  0.009435        volvo   0.000000   0.000028  0.999955        clean
#
#          transmission       size       lat      long
#  Id
#  473356     automatic   mid-size  0.000287 -0.000569
#  1578360    automatic  full-size  0.000492 -0.000906
#  1570403    automatic  full-size  0.000290 -0.000519
#  1721281    automatic  full-size  0.000355 -0.000847
#  1393864    automatic   mid-size  0.000253 -0.000543
#  ...              ...        ...       ...       ...
#  599064        manual  full-size  0.000388 -0.001082
#  490973     automatic  full-size  0.000306 -0.000984
#  70404      automatic  full-size  0.000370 -0.000675
#  648528     automatic   mid-size  0.000223 -0.000718
#  1359380    automatic  full-size  0.000210 -0.000345
#
#  [2991 rows x 10 columns],
#  'subaru':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1319903  0.020853       subaru   0.000010   0.000062  0.999782        clean
#  34513    0.017693       subaru   0.000000   0.000053  0.999843        clean
#  1628135  0.022567       subaru   0.000022   0.000045  0.999745        clean
#  1370778  0.010271       subaru   0.000005   0.000021  0.999947        clean
#  30592    0.010923       subaru   0.000011   0.000022  0.999940        clean
#  ...           ...          ...        ...        ...       ...          ...
#  842630   0.008272       subaru   0.000004   0.000025  0.999966        clean
#  928455   0.021875       subaru   0.000022   0.000065  0.999760        clean
#  568870   0.121495       subaru   0.000000   0.000241  0.992563        clean
#  796257   0.008654       subaru   0.000004   0.000017  0.999962        clean
#  808470   0.012634       subaru   0.000000   0.000038  0.999920        clean
#
#          transmission       size       lat      long
#  Id
#  1319903    automatic  full-size  0.000348 -0.000852
#  34513         manual  full-size  0.000368 -0.000636
#  1628135    automatic   mid-size  0.000500 -0.000989
#  1370778       manual  full-size  0.000225 -0.000573
#  30592      automatic   mid-size  0.000272 -0.000527
#  ...              ...        ...       ...       ...
#  842630     automatic    compact  0.000165 -0.000435
#  928455     automatic  full-size  0.000460 -0.000910
#  568870     automatic   mid-size  0.002652 -0.007044
#  796257        manual    compact  0.000179 -0.000326
#  808470     automatic  full-size  0.000256 -0.000501
#
#  [8099 rows x 10 columns],
#  'buick':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  413465   0.993243        buick   0.000495   0.002972  0.103040        clean
#  1630866  0.017667        buick   0.000009   0.000070  0.999844        clean
#  890695   0.015708        buick   0.000000   0.000063  0.999876        clean
#  1358458  0.020552        buick   0.000010   0.000082  0.999788        clean
#  1310820  0.017341        buick   0.000000   0.000053  0.999849        clean
#  ...           ...          ...        ...        ...       ...          ...
#  865182   0.017728        buick   0.000000   0.000053  0.999842        clean
#  1001355  0.013196        buick   0.000013   0.000039  0.999913        clean
#  1663442  0.012487        buick   0.000000   0.000037  0.999922        clean
#  806669   0.017649        buick   0.000000   0.000053  0.999844        clean
#  1445996  0.017572        buick   0.000009   0.000053  0.999845        clean
#
#          transmission       size       lat      long
#  Id
#  413465     automatic   mid-size  0.023225 -0.047994
#  1630866    automatic  full-size  0.000399 -0.000807
#  890695     automatic  full-size  0.000337 -0.000655
#  1358458    automatic  full-size  0.000454 -0.000747
#  1310820    automatic  full-size  0.000298 -0.000745
#  ...              ...        ...       ...       ...
#  865182     automatic  full-size  0.000382 -0.000740
#  1001355    automatic  full-size  0.000231 -0.000537
#  1663442    automatic  full-size  0.000236 -0.000608
#  806669     automatic  full-size  0.000352 -0.000662
#  1445996    automatic  full-size  0.000350 -0.000789
#
#  [6264 rows x 10 columns],
#  'cadillac':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  258558   0.036070     cadillac   0.000018   0.000072  0.999348        clean
#  387098   0.014077     cadillac   0.000000   0.000042  0.999901        clean
#  525861   0.017764     cadillac   0.000000   0.000053  0.999842        clean
#  413853   0.015153     cadillac   0.000015   0.000060  0.999885        clean
#  4372     0.043719     cadillac   0.000043   0.000130  0.999042        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1212250  0.017292     cadillac   0.000000   0.000069  0.999850        clean
#  1226480  0.053919     cadillac   0.000000   0.000160  0.998542        clean
#  289337   0.014132     cadillac   0.000007   0.000042  0.999900        clean
#  448932   0.012443     cadillac   0.000012   0.000050  0.999922        clean
#  684502   0.019183     cadillac   0.000000   0.000077  0.999815        clean
#
#          transmission       size       lat      long
#  Id
#  258558     automatic   mid-size  0.000740 -0.001459
#  387098     automatic  full-size  0.000303 -0.000590
#  525861     automatic  full-size  0.000310 -0.000858
#  413853     automatic  full-size  0.000362 -0.000732
#  4372       automatic  full-size  0.000911 -0.001875
#  ...              ...        ...       ...       ...
#  1212250    automatic  full-size  0.000405 -0.000985
#  1226480    automatic  full-size  0.000843 -0.002599
#  289337     automatic  full-size  0.000289 -0.000574
#  448932     automatic   mid-size  0.000248 -0.000525
#  684502     automatic  full-size  0.000323 -0.001114
#
#  [6814 rows x 10 columns],
#  'land rover':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  686329   0.017711   land rover   0.000000   0.000053  0.999843        clean
#  1409194  0.021490   land rover   0.000000   0.000064  0.999769        clean
#  1689963  0.019385   land rover   0.000000   0.000058  0.999812        clean
#  123260   0.054786   land rover   0.000054   0.000163  0.998492        clean
#  551828   0.033548   land rover   0.000033   0.000067  0.999436        clean
#  ...           ...          ...        ...        ...       ...          ...
#  231836   0.017544   land rover   0.000018   0.000070  0.999846        clean
#  5716     0.017720   land rover   0.000000   0.000053  0.999842        clean
#  314562   0.044733   land rover   0.000044   0.000089  0.998997        clean
#  1302604  0.001545   land rover   0.000000   0.000005  0.999999        clean
#  1107835  0.015958   land rover   0.000016   0.000063  0.999872        clean
#
#          transmission       size       lat      long
#  Id
#  686329     automatic  full-size  0.000291 -0.001032
#  1409194    automatic  full-size  0.000415 -0.000827
#  1689963    automatic  full-size  0.000343 -0.000757
#  123260     automatic  full-size  0.001338 -0.003347
#  551828     automatic   mid-size  0.000650 -0.001281
#  ...              ...        ...       ...       ...
#  231836        manual  full-size  0.000371 -0.000639
#  5716       automatic  full-size  0.000382 -0.000975
#  314562     automatic   mid-size  0.000971 -0.001760
#  1302604    automatic  full-size  0.000026 -0.000065
#  1107835    automatic  full-size  0.000241 -0.000668
#
#  [1551 rows x 10 columns],
#  'bmw':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  576171   0.016855          bmw   0.000017   0.000050  0.999857        clean
#  1690465  0.007690          bmw   0.000000   0.000023  0.999970        clean
#  1288292  0.017658          bmw   0.000000   0.000053  0.999844        clean
#  710260   0.015285          bmw   0.000008   0.000046  0.999883        clean
#  1369680  0.021622          bmw   0.000022   0.000065  0.999765        clean
#  ...           ...          ...        ...        ...       ...          ...
#  728656   0.013652          bmw   0.000014   0.000041  0.999906        clean
#  1357986  0.020599          bmw   0.000010   0.000062  0.999787        clean
#  372768   0.023412          bmw   0.000023   0.000046  0.999725        clean
#  749225   0.029554          bmw   0.000029   0.000088  0.999561        clean
#  1327644  0.024999          bmw   0.000000   0.000075  0.999687        clean
#
#          transmission       size       lat      long
#  Id
#  576171     automatic  full-size  0.000370 -0.001019
#  1690465       manual  full-size  0.000138 -0.000302
#  1288292    automatic  full-size  0.000267 -0.000860
#  710260     automatic  full-size  0.000288 -0.000935
#  1369680        other    compact  0.000470 -0.001260
#  ...              ...        ...       ...       ...
#  728656     automatic  full-size  0.000236 -0.000804
#  1357986    automatic  full-size  0.000457 -0.000752
#  372768     automatic   mid-size  0.000509 -0.000922
#  749225        manual  full-size  0.000568 -0.001783
#  1327644    automatic  full-size  0.000512 -0.001197
#
#  [11840 rows x 10 columns],
#  'dodge':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1429566  0.017764        dodge   0.000000   0.000053  0.999842        clean
#  1133731  0.017605        dodge   0.000000   0.000053  0.999845        clean
#  1475021  0.017634        dodge   0.000000   0.000053  0.999844        clean
#  568200   0.014835        dodge   0.000007   0.000044  0.999889        clean
#  1248485  0.034669        dodge   0.000034   0.000069  0.999397        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1534465  0.017667        dodge   0.000000   0.000053  0.999843      salvage
#  1084557  0.287805        dodge   0.000143   0.000856  0.957589        clean
#  477736   0.023132        dodge   0.000011   0.000069  0.999732      salvage
#  1062054  0.990980        dodge   0.000496   0.003966  0.123934        clean
#  624891   0.017648        dodge   0.000000   0.000053  0.999844        clean
#
#          transmission         size       lat      long
#  Id
#  1429566    automatic    full-size  0.000332 -0.000785
#  1133731    automatic    full-size  0.000257 -0.000718
#  1475021       manual    full-size  0.000420 -0.001034
#  568200     automatic     mid-size  0.000328 -0.000895
#  1248485    automatic  sub-compact  0.000451 -0.001684
#  ...              ...          ...       ...       ...
#  1534465    automatic    full-size  0.000309 -0.000935
#  1084557        other    full-size  0.005008 -0.012842
#  477736     automatic     mid-size  0.000385 -0.001289
#  1062054    automatic    full-size  0.019708 -0.046848
#  624891     automatic    full-size  0.000331 -0.001065
#
#  [20779 rows x 10 columns],
#  'chrysler':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  690608   0.012661     chrysler   0.000006   0.000052  0.999919        clean
#  477921   0.016730     chrysler   0.000008   0.000050  0.999860        clean
#  1419190  0.015523     chrysler   0.000008   0.000046  0.999879         lien
#  447687   0.013149     chrysler   0.000000   0.000039  0.999913        clean
#  1226713  0.070525     chrysler   0.000000   0.000210  0.997504        clean
#  ...           ...          ...        ...        ...       ...          ...
#  390901   0.036412     chrysler   0.000036   0.000073  0.999335        clean
#  472600   0.026840     chrysler   0.000027   0.000080  0.999639        clean
#  1009216  0.017649     chrysler   0.000000   0.000053  0.999844      salvage
#  1149416  0.017658     chrysler   0.000000   0.000053  0.999844        clean
#  882889   0.026249     chrysler   0.000013   0.000078  0.999655        clean
#
#          transmission       size       lat      long
#  Id
#  690608     automatic  full-size  0.000240 -0.000791
#  477921     automatic  full-size  0.000291 -0.000933
#  1419190    automatic  full-size  0.000303 -0.000693
#  447687     automatic  full-size  0.000260 -0.000550
#  1226713    automatic   mid-size  0.001104 -0.003402
#  ...              ...        ...       ...       ...
#  390901     automatic   mid-size  0.000571 -0.001556
#  472600     automatic  full-size  0.000554 -0.001094
#  1009216    automatic  full-size  0.000307 -0.000725
#  1149416    automatic  full-size  0.000239 -0.000706
#  882889     automatic  full-size  0.000553 -0.001084
#
#  [8658 rows x 10 columns],
#  'mitsubishi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  751296   0.028731   mitsubishi   0.000029   0.000057  0.999586        clean
#  81351    0.086936   mitsubishi   0.000000   0.000259  0.996205        clean
#  1585758  0.017676   mitsubishi   0.000009   0.000053  0.999843        clean
#  63526    0.017667   mitsubishi   0.000000   0.000053  0.999844        clean
#  591048   0.013901   mitsubishi   0.000007   0.000028  0.999903        clean
#  ...           ...          ...        ...        ...       ...          ...
#  333668   0.070489   mitsubishi   0.000035   0.000210  0.997507        clean
#  1151633  0.010826   mitsubishi   0.000011   0.000032  0.999941        clean
#  1698691  0.017614   mitsubishi   0.000018   0.000053  0.999845        clean
#  191762   0.033454   mitsubishi   0.000000   0.000100  0.999439        clean
#  1596504  0.017579   mitsubishi   0.000018   0.000053  0.999845        clean
#
#          transmission         size       lat      long
#  Id
#  751296     automatic     mid-size  0.000596 -0.001002
#  81351         manual      compact  0.001288 -0.004116
#  1585758    automatic    full-size  0.000359 -0.000647
#  63526      automatic    full-size  0.000297 -0.000741
#  591048     automatic     mid-size  0.000316 -0.000854
#  ...              ...          ...       ...       ...
#  333668     automatic    full-size  0.001470 -0.003076
#  1151633    automatic    full-size  0.000143 -0.000442
#  1698691    automatic    full-size  0.000317 -0.000706
#  191762        manual  sub-compact  0.000593 -0.001448
#  1596504    automatic    full-size  0.000359 -0.000651
#
#  [2945 rows x 10 columns],
#  'ford':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  931606   0.017579         ford   0.000000   0.000053  0.999845        clean
#  229951   0.997673         ford   0.000989   0.002966  0.018787        clean
#  133494   0.017640         ford   0.000009   0.000070  0.999844        clean
#  59980    0.024680         ford   0.000012   0.000100  0.999694        clean
#  1266110  0.990060         ford   0.000986   0.003944  0.131153        clean
#  ...           ...          ...        ...        ...       ...          ...
#  103714   0.011178         ford   0.000006   0.000045  0.999937        clean
#  645068   0.017728         ford   0.000000   0.000053  0.999842        clean
#  605610   0.017632         ford   0.000018   0.000070  0.999844        clean
#  1038628  0.017693         ford   0.000018   0.000070  0.999843        clean
#  1505912  0.008422         ford   0.000000   0.000025  0.999964        clean
#
#          transmission       size       lat      long
#  Id
#  931606     automatic  full-size  0.000383 -0.000734
#  229951     automatic  full-size  0.024324 -0.060772
#  133494     automatic  full-size  0.000401 -0.000776
#  59980         manual  full-size  0.000495 -0.001313
#  1266110    automatic  full-size  0.016126 -0.047988
#  ...              ...        ...       ...       ...
#  103714     automatic  full-size  0.000238 -0.000492
#  645068     automatic  full-size  0.000356 -0.001077
#  605610     automatic  full-size  0.000399 -0.001082
#  1038628    automatic  full-size  0.000344 -0.000820
#  1505912    automatic  full-size  0.000202 -0.000517
#
#  [79933 rows x 10 columns],
#  'porche':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  460254   0.017640       porche   0.000009   0.000070  0.999844        clean
#  214525   0.019856       porche   0.000020   0.000060  0.999803        clean
#  1249646  0.014394       porche   0.000007   0.000043  0.999896        clean
#  86039    0.021050       porche   0.000021   0.000042  0.999778        clean
#  680575   0.017702       porche   0.000000   0.000053  0.999843        clean
#  1491844  0.089636       porche   0.000089   0.000267  0.995959        clean
#  199702   0.017092       porche   0.000000   0.000052  0.999853        clean
#  1169925  0.017376       porche   0.000000   0.000053  0.999849        clean
#  84224    0.017640       porche   0.000009   0.000053  0.999844        clean
#  1311307  0.017640       porche   0.000000   0.000053  0.999844        clean
#  753055   0.023087       porche   0.000023   0.000093  0.999733        clean
#  590487   0.165509       porche   0.000164   0.000493  0.986150        clean
#  533877   0.017658       porche   0.000018   0.000053  0.999844      rebuilt
#  43107    0.012617       porche   0.000013   0.000038  0.999920        clean
#  1286511  0.012459       porche   0.000012   0.000050  0.999922        clean
#  1377860  0.017649       porche   0.000000   0.000053  0.999844        clean
#  658165   0.013645       porche   0.000014   0.000041  0.999907        clean
#  770697   0.021314       porche   0.000021   0.000064  0.999772        clean
#  1080122  0.018318       porche   0.000018   0.000055  0.999832        clean
#  80189    0.017640       porche   0.000000   0.000053  0.999844        clean
#  1632136  0.017456       porche   0.000000   0.000053  0.999847        clean
#  1644684  0.017456       porche   0.000000   0.000053  0.999847        clean
#  1234311  0.027125       porche   0.000027   0.000081  0.999631        clean
#  100335   0.017640       porche   0.000000   0.000070  0.999844        clean
#  1021298  0.017732       porche   0.000009   0.000053  0.999842        clean
#  774282   0.023087       porche   0.000023   0.000093  0.999733        clean
#  189547   0.018224       porche   0.000009   0.000055  0.999834        clean
#  497457   0.019443       porche   0.000019   0.000058  0.999810        clean
#
#          transmission       size       lat      long
#  Id
#  460254     automatic  full-size  0.000367 -0.000736
#  214525     automatic  full-size  0.000420 -0.000715
#  1249646       manual  full-size  0.000219 -0.000703
#  86039         manual    compact  0.000461 -0.000886
#  680575     automatic  full-size  0.000299 -0.001032
#  1491844    automatic  full-size  0.002078 -0.005210
#  199702        manual  full-size  0.000531 -0.001287
#  1169925       manual  full-size  0.000261 -0.000725
#  84224      automatic  full-size  0.000324 -0.000671
#  1311307    automatic  full-size  0.000297 -0.000743
#  753055     automatic   mid-size  0.000484 -0.000816
#  590487     automatic  full-size  0.003731 -0.010076
#  533877         other  full-size  0.000319 -0.000829
#  43107      automatic  full-size  0.000194 -0.000529
#  1286511    automatic  full-size  0.000205 -0.000602
#  1377860    automatic  full-size  0.000377 -0.000627
#  658165     automatic   mid-size  0.000232 -0.000805
#  770697     automatic   mid-size  0.000444 -0.000757
#  1080122       manual    compact  0.000335 -0.000797
#  80189      automatic  full-size  0.000380 -0.000774
#  1632136       manual  full-size  0.000395 -0.000789
#  1644684       manual  full-size  0.000395 -0.000789
#  1234311    automatic  full-size  0.000403 -0.001292
#  100335     automatic  full-size  0.000368 -0.000628
#  1021298    automatic  full-size  0.000309 -0.000796
#  774282     automatic   mid-size  0.000484 -0.000816
#  189547     automatic  full-size  0.000377 -0.000655
#  497457     automatic    compact  0.000328 -0.001088  ,
#  'ram':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1265412  0.017632          ram   0.000000   0.000070  0.999844        clean
#  1203620  0.009631          ram   0.000000   0.000029  0.999953        clean
#  838967   0.017561          ram   0.000000   0.000070  0.999845        clean
#  1403469  0.005136          ram   0.000003   0.000015  0.999987        clean
#  1327267  0.010141          ram   0.000005   0.000030  0.999948        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1679395  0.042651          ram   0.000000   0.000127  0.999088        clean
#  594726   0.055525          ram   0.000000   0.000165  0.998451        clean
#  862055   0.014090          ram   0.000000   0.000056  0.999900        clean
#  1025143  0.010122          ram   0.000005   0.000030  0.999949        clean
#  1298707  0.011399          ram   0.000000   0.000034  0.999935        clean
#
#          transmission       size       lat      long
#  Id
#  1265412    automatic  full-size  0.000245 -0.000877
#  1203620    automatic  full-size  0.000224 -0.000538
#  838967     automatic  full-size  0.000331 -0.000922
#  1403469    automatic  full-size  0.000096 -0.000203
#  1327267    automatic  full-size  0.000208 -0.000488
#  ...              ...        ...       ...       ...
#  1679395    automatic  full-size  0.000741 -0.001670
#  594726     automatic  full-size  0.001170 -0.003398
#  862055     automatic  full-size  0.000274 -0.000761
#  1025143    automatic  full-size  0.000173 -0.000450
#  1298707    automatic  full-size  0.000174 -0.000556
#
#  [15561 rows x 10 columns],
#  'chevrolet':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  203486   0.020839    chevrolet   0.000000   0.000062  0.999782        clean
#  646472   0.011094    chevrolet   0.000006   0.000033  0.999938         lien
#  70746    0.018272    chevrolet   0.000000   0.000055  0.999833        clean
#  1429295  0.030343    chevrolet   0.000030   0.000060  0.999538        clean
#  1451731  0.009708    chevrolet   0.000010   0.000039  0.999953        clean
#  ...           ...          ...        ...        ...       ...          ...
#  437652   0.010749    chevrolet   0.000000   0.000032  0.999942        clean
#  316066   0.012460    chevrolet   0.000012   0.000025  0.999922        clean
#  400020   0.017258    chevrolet   0.000000   0.000051  0.999851        clean
#  87925    0.017667    chevrolet   0.000000   0.000053  0.999844        clean
#  690884   0.019481    chevrolet   0.000000   0.000058  0.999810        clean
#
#          transmission       size       lat      long
#  Id
#  203486     automatic  full-size  0.000450 -0.000808
#  646472     automatic  full-size  0.000225 -0.000679
#  70746      automatic  full-size  0.000390 -0.000649
#  1429295    automatic    compact  0.000581 -0.001356
#  1451731    automatic  full-size  0.000194 -0.000359
#  ...              ...        ...       ...       ...
#  437652     automatic  full-size  0.000224 -0.000449
#  316066     automatic   mid-size  0.000272 -0.000487
#  400020     automatic  full-size  0.000291 -0.000737
#  87925      automatic  full-size  0.000327 -0.000843
#  690884     automatic  full-size  0.000329 -0.001135
#
#  [71349 rows x 10 columns],
#  'infiniti':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  872220   0.017640     infiniti   0.000000   0.000053  0.999844        clean
#  1680494  0.010638     infiniti   0.000005   0.000000  0.999943        clean
#  666918   0.011869     infiniti  -0.000006   0.000036  0.999929      salvage
#  168781   0.021895     infiniti   0.000000   0.000065  0.999760        clean
#  737413   0.017720     infiniti   0.000000   0.000053  0.999842        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1437325  0.017676     infiniti   0.000000   0.000053  0.999843        clean
#  1310873  0.016235     infiniti   0.000016   0.000049  0.999868        clean
#  1034019  0.041921     infiniti   0.000042   0.000125  0.999119        clean
#  903831   0.009910     infiniti   0.000000   0.000020  0.999951        clean
#  617643   0.017737     infiniti   0.000018   0.000053  0.999842        clean
#
#          transmission       size       lat      long
#  Id
#  872220     automatic  full-size  0.000376 -0.000758
#  1680494    automatic    compact  0.000191 -0.000426
#  666918     automatic  full-size  0.000205 -0.000693
#  168781         other  full-size  0.000420 -0.001025
#  737413     automatic  full-size  0.000297 -0.001041
#  ...              ...        ...       ...       ...
#  1437325    automatic  full-size  0.000365 -0.000796
#  1310873    automatic  full-size  0.000274 -0.000680
#  1034019    automatic  full-size  0.000774 -0.001942
#  903831     automatic   mid-size  0.000212 -0.000423
#  617643     automatic   mid-size  0.000340 -0.001069
#
#  [3406 rows x 10 columns],
#  'nissan':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  504420   0.013345       nissan   0.000000   0.000040  0.999911      missing
#  1470561  0.048458       nissan   0.000000   0.000144  0.998821        clean
#  1183281  0.555623       nissan   0.000275   0.001653  0.831093        clean
#  715272   0.019070       nissan   0.000000   0.000057  0.999817        clean
#  711115   0.013961       nissan   0.000014   0.000042  0.999902        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1170883  0.017693       nissan   0.000018   0.000035  0.999843        clean
#  442772   0.018224       nissan   0.000018   0.000055  0.999834        clean
#  353759   0.051021       nissan   0.000000   0.000152  0.998695        clean
#  1385959  0.013189       nissan   0.000007   0.000039  0.999913        clean
#  251004   0.150884       nissan   0.000000   0.000449  0.988528        clean
#
#          transmission       size       lat      long
#  Id
#  504420     automatic  full-size  0.000291 -0.000469
#  1470561    automatic  full-size  0.001148 -0.002821
#  1183281        other  full-size  0.007851 -0.022415
#  715272     automatic  full-size  0.000323 -0.001123
#  711115     automatic  full-size  0.000271 -0.000843
#  ...              ...        ...       ...       ...
#  1170883    automatic   mid-size  0.000250 -0.000711
#  442772     automatic   mid-size  0.000363 -0.000752
#  353759     automatic  full-size  0.001069 -0.002134
#  1385959    automatic  full-size  0.000251 -0.000517
#  251004         other  full-size  0.003076 -0.006098
#
#  [21925 rows x 10 columns],
#  'lincoln':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1299110  0.017596      lincoln   0.000018   0.000053  0.999845        clean
#  194087   0.017676      lincoln   0.000018   0.000053  0.999843        clean
#  58003    0.005806      lincoln   0.000003   0.000023  0.999983         lien
#  615420   0.013285      lincoln   0.000000   0.000040  0.999911        clean
#  97647    0.017552      lincoln   0.000000   0.000053  0.999846        clean
#  ...           ...          ...        ...        ...       ...          ...
#  817243   0.015258      lincoln   0.000008   0.000045  0.999883        clean
#  1388591  0.016321      lincoln   0.000000   0.000049  0.999867        clean
#  506679   0.010523      lincoln   0.000005   0.000042  0.999945        clean
#  1375991  0.012613      lincoln   0.000000   0.000038  0.999920        clean
#  1123451  0.017061      lincoln   0.000017   0.000068  0.999854        clean
#
#          transmission       size       lat      long
#  Id
#  1299110    automatic  full-size  0.000299 -0.000867
#  194087     automatic  full-size  0.000335 -0.000753
#  58003      automatic  full-size  0.000122 -0.000257
#  615420     automatic  full-size  0.000257 -0.000809
#  97647      automatic  full-size  0.000322 -0.000827
#  ...              ...        ...       ...       ...
#  817243     automatic  full-size  0.000309 -0.000589
#  1388591    automatic  full-size  0.000310 -0.000630
#  506679     automatic  full-size  0.000235 -0.000361
#  1375991    automatic  full-size  0.000299 -0.000730
#  1123451    automatic  full-size  0.000238 -0.000695
#
#  [3553 rows x 10 columns],
#  'mercedes-benz':              year   manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  680343   0.017658  mercedes-benz   0.000000   0.000053  0.999844        clean
# ...
#  6602     0.016042       toyota   0.000000   0.000048  0.999871        clean
#  590131   0.036985       toyota   0.000000   0.000110  0.999313        clean
#  1154951  0.011275       toyota   0.000011   0.000045  0.999936        clean
#  ...           ...          ...        ...        ...       ...          ...
#  658322   0.016483       toyota   0.000016   0.000033  0.999864        clean
#  209844   0.017737       toyota   0.000018   0.000053  0.999842        clean
#  148650   0.014282       toyota   0.000014   0.000057  0.999898        clean
#  389299   0.015803       toyota   0.000016   0.000031  0.999875        clean
#  724483   0.021225       toyota   0.000021   0.000042  0.999774        clean
#
#          transmission       size       lat      long
#  Id
#  869261     automatic  full-size  0.000140 -0.000280
#  1576505    automatic    compact  0.021373 -0.037599
#  6602       automatic  full-size  0.000338 -0.000665
#  590131        manual  full-size  0.000837 -0.002253
#  1154951    automatic  full-size  0.000169 -0.000459
#  ...              ...        ...       ...       ...
#  658322     automatic   mid-size  0.000304 -0.001004
#  209844     automatic  full-size  0.000267 -0.000802
#  148650     automatic  full-size  0.000246 -0.000614
#  389299     automatic  full-size  0.000283 -0.000904
#  724483     automatic   mid-size  0.000407 -0.001299
#
#  [31722 rows x 10 columns],
#  'fiat':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  564971   0.029139         fiat   0.000000   0.000058  0.999574        clean
#  1085623  0.017711         fiat   0.000000   0.000053  0.999843        clean
#  126928   0.028731         fiat   0.000029   0.000057  0.999586        clean
#  190602   0.461312         fiat   0.000000   0.000915  0.886928        clean
#  195543   0.036047         fiat   0.000000   0.000107  0.999347        clean
#  ...           ...          ...        ...        ...       ...          ...
#  741274   0.095014         fiat   0.000000   0.000000  0.995459        clean
#  495824   0.037935         fiat   0.000038   0.000075  0.999278        clean
#  359981   0.017447         fiat   0.000000   0.000053  0.999848        clean
#  932782   0.012878         fiat   0.000000   0.000038  0.999917        clean
#  62356    0.032451         fiat   0.000032   0.000064  0.999472        clean
#
#          transmission         size       lat      long
#  Id
#  564971     automatic     mid-size  0.000613 -0.001778
#  1085623    automatic    full-size  0.000318 -0.000764
#  126928     automatic     mid-size  0.000603 -0.001291
#  190602     automatic  sub-compact  0.007474 -0.022203
#  195543     automatic    full-size  0.000882 -0.002205
#  ...              ...          ...       ...       ...
#  741274     automatic  sub-compact  0.001563 -0.005526
#  495824        manual     mid-size  0.000656 -0.002130
#  359981         other    full-size  0.000367 -0.000637
#  932782     automatic    full-size  0.000276 -0.000538
#  62356      automatic      compact  0.000560 -0.001238
#
#  [560 rows x 10 columns],
#  'honda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  941967   0.011875        honda   0.000012   0.000036  0.999929        clean
#  1705021  0.017906        honda   0.000009   0.000036  0.999839        clean
#  577586   0.023575        honda   0.000023   0.000047  0.999721        clean
#  680270   0.017623        honda   0.000000   0.000053  0.999844        clean
#  147590   0.017596        honda   0.000009   0.000035  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  996099   0.011922        honda   0.000000   0.000036  0.999929        clean
#  1186813  0.016723        honda   0.000017   0.000033  0.999860        clean
#  939113   0.011928        honda   0.000012   0.000036  0.999929        clean
#  221358   0.025111        honda   0.000013   0.000050  0.999684      rebuilt
#  690622   0.017649        honda   0.000000   0.000035  0.999844        clean
#
#          transmission       size       lat      long
#  Id
#  941967     automatic  full-size  0.000244 -0.000433
#  1705021    automatic  full-size  0.000322 -0.000713
#  577586     automatic   mid-size  0.000517 -0.001424
#  680270     automatic  full-size  0.000300 -0.001041
#  147590        manual    compact  0.000306 -0.000761
#  ...              ...        ...       ...       ...
#  996099     automatic  full-size  0.000208 -0.000482
#  1186813    automatic    compact  0.000248 -0.000688
#  939113     automatic  full-size  0.000248 -0.000428
#  221358        manual    compact  0.000376 -0.001131
#  690622        manual    compact  0.000324 -0.001071
#
#  [24585 rows x 10 columns],
#  'lexus':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  346088   0.009998        lexus   0.000005   0.000030  0.999950        clean
#  928922   0.017667        lexus   0.000018   0.000053  0.999844        clean
#  223420   0.019965        lexus   0.000000   0.000060  0.999800        clean
#  229480   0.024883        lexus   0.000000   0.000074  0.999690        clean
#  38676    0.017649        lexus   0.000000   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  214795   0.017623        lexus   0.000000   0.000053  0.999844        clean
#  480602   0.020653        lexus   0.000000   0.000062  0.999786        clean
#  1120864  0.021464        lexus   0.000021   0.000064  0.999769        clean
#  1315891  0.017579        lexus   0.000000   0.000053  0.999845        clean
#  1035631  0.017614        lexus   0.000018   0.000053  0.999844        clean
#
#          transmission       size       lat      long
#  Id
#  346088     automatic    compact  0.000216 -0.000554
#  928922     automatic  full-size  0.000374 -0.000730
#  223420     automatic  full-size  0.000446 -0.000910
#  229480     automatic  full-size  0.000375 -0.001154
#  38676      automatic  full-size  0.000412 -0.000852
#  ...              ...        ...       ...       ...
#  214795     automatic  full-size  0.000368 -0.000628
#  480602     automatic  full-size  0.000342 -0.001148
#  1120864    automatic   mid-size  0.000306 -0.000869
#  1315891    automatic  full-size  0.000286 -0.000747
#  1035631    automatic  full-size  0.000334 -0.000808
#
#  [5523 rows x 10 columns],
#  'mercury':              year manufacturer     condition     cylinders  odometer  \
#  Id
#  1578762  0.000208      mercury  2.073269e-07  6.219808e-07  1.000000
#  1228845  0.042427      mercury  4.313891e-05  1.725556e-04  0.999097
#  465051   0.031361      mercury  3.120534e-05  9.361603e-05  0.999507
#  1104598  0.014387      mercury  1.438700e-05  5.754799e-05  0.999896
#  276911   0.013711      mercury  0.000000e+00  4.109202e-05  0.999906
#  ...           ...          ...           ...           ...       ...
#  1698886  0.013656      mercury  6.848675e-06  5.478940e-05  0.999907
#  1645204  0.012281      mercury  1.230517e-05  3.691551e-05  0.999924
#  1424750  0.015911      mercury  7.935501e-06  6.348401e-05  0.999873
#  714568   0.017632      mercury  8.802606e-06  5.281564e-05  0.999844
#  1512105  0.011851      mercury  5.916743e-06  3.550046e-05  0.999930
#
#          title_status transmission       size       lat      long
#  Id
#  1578762        clean    automatic  full-size  0.000004 -0.000008
#  1228845        clean    automatic  full-size  0.000704 -0.002083
#  465051         clean    automatic   mid-size  0.000640 -0.001260
#  1104598        clean    automatic  full-size  0.000198 -0.000578
#  276911         clean    automatic  full-size  0.000271 -0.000578
#  ...              ...          ...        ...       ...       ...
#  1698886        clean    automatic  full-size  0.000246 -0.000553
#  1645204        clean    automatic   mid-size  0.000276 -0.000550
#  1424750        clean    automatic  full-size  0.000318 -0.000700
#  714568         clean    automatic   mid-size  0.000308 -0.001061
#  1512105        clean    automatic  full-size  0.000243 -0.000504
#
#  [2793 rows x 10 columns],
#  'audi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  13357    0.017649         audi   0.000000   0.000053  0.999844      salvage
#  563595   0.016432         audi   0.000016   0.000033  0.999865        clean
#  354761   0.020329         audi   0.000020   0.000061  0.999793        clean
#  1497183  0.099649         audi   0.000100   0.000199  0.995001        clean
#  516585   0.012858         audi   0.000006   0.000026  0.999917        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1453834  0.011005         audi   0.000000   0.000033  0.999939        clean
#  859434   0.016687         audi   0.000017   0.000033  0.999860        clean
#  1128663  0.021164         audi   0.000000   0.000063  0.999776        clean
#  1548604  0.012871         audi   0.000013   0.000038  0.999917        clean
#  248112   0.010877         audi   0.000011   0.000022  0.999941        clean
#
#          transmission       size       lat      long
#  Id
#  13357      automatic  full-size  0.000384 -0.000642
#  563595     automatic  full-size  0.000321 -0.000627
#  354761     automatic  full-size  0.000410 -0.001126
#  1497183        other   mid-size  0.002369 -0.006080
#  516585     automatic   mid-size  0.000225 -0.000626
#  ...              ...        ...       ...       ...
#  1453834    automatic  full-size  0.000219 -0.000412
#  859434     automatic  full-size  0.000330 -0.000872
#  1128663    automatic  full-size  0.000277 -0.000860
#  1548604    automatic  full-size  0.000266 -0.000601
#  248112     automatic   mid-size  0.000217 -0.000406
#
#  [4076 rows x 10 columns],
#  'saturn':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1367601  0.017676       saturn   0.000018   0.000035  0.999843        clean
#  101468   0.017676       saturn   0.000000   0.000053  0.999843        clean
#  145676   0.015019       saturn   0.000015   0.000030  0.999887        clean
#  1636317  0.012531       saturn   0.000000   0.000025  0.999921        clean
#  1618201  0.997145       saturn   0.000000   0.001990  0.061202        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1460963  0.017667       saturn   0.000000   0.000053  0.999844        clean
#  453981   0.014298       saturn   0.000000   0.000043  0.999898        clean
#  912204   0.021572       saturn   0.000011   0.000043  0.999767        clean
#  801123   0.017658       saturn   0.000018   0.000053  0.999844        clean
#  382200   0.009364       saturn   0.000005   0.000019  0.999956        clean
#
#          transmission       size       lat      long
#  Id
#  1367601    automatic  full-size  0.000385 -0.001024
#  101468     automatic  full-size  0.000357 -0.000851
#  145676        manual    compact  0.000252 -0.000641
#  1636317       manual    compact  0.000269 -0.000559
#  1618201    automatic   mid-size  0.021487 -0.038614
#  ...              ...        ...       ...       ...
#  1460963    automatic  full-size  0.000357 -0.000654
#  453981     automatic   mid-size  0.000280 -0.000602
#  912204        manual    compact  0.000463 -0.000927
#  801123     automatic   mid-size  0.000354 -0.000679
#  382200        manual   mid-size  0.000187 -0.000358
#
#  [2599 rows x 10 columns],
#  'datsun':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1567918  0.031935       datsun   0.000000   0.000097  0.999489        clean
#  1017016  0.017456       datsun   0.000000   0.000053  0.999847        clean
#  199894   0.014367       datsun   0.000014   0.000043  0.999897        clean
#  976280   0.018501       datsun   0.000000   0.000037  0.999828        clean
#  731953   0.017350       datsun   0.000018   0.000035  0.999849         lien
#  ...           ...          ...        ...        ...       ...          ...
#  198268   0.017579       datsun   0.000000   0.000053  0.999844        clean
#  680422   0.017429       datsun   0.000000   0.000053  0.999848        clean
#  1179224  0.006725       datsun   0.000003   0.000020  0.999977        clean
#  1028242  0.017456       datsun   0.000009   0.000035  0.999847        clean
#  169295   0.010244       datsun  -0.000005   0.000031  0.999947      missing
#
#          transmission       size       lat      long
#  Id
#  1567918    automatic  full-size  0.000692 -0.001271
#  1017016       manual  full-size  0.000284 -0.000800
#  199894         other  full-size  0.000258 -0.000561
#  976280        manual   mid-size  0.000436 -0.000881
#  731953     automatic   mid-size  0.000352 -0.001075
#  ...              ...        ...       ...       ...
#  198268        manual  full-size  0.000571 -0.001305
#  680422        manual  full-size  0.000299 -0.001033
#  1179224       manual    compact  0.000096 -0.000281
#  1028242       manual   mid-size  0.000383 -0.000863
#  169295        manual  full-size  0.000193 -0.000482
#
#  [159 rows x 10 columns],
#  'unknown':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  559327   0.010557      unknown   0.000011   0.000021  0.999944        clean
#  1260418  0.013199      unknown   0.000000   0.000053  0.999913        clean
#  792110   0.792094      unknown   0.000789   0.003157  0.609364        clean
#  1191078  0.153511      unknown   0.000000   0.000306  0.988126        clean
#  228988   0.017684      unknown   0.000000   0.000070  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1561693  0.217846      unknown   0.000110   0.000659  0.975917        clean
#  274624   0.017746      unknown   0.000000   0.000053  0.999842        clean
#  681992   0.017420      unknown   0.000018   0.000035  0.999848        clean
#  945416   0.017702      unknown   0.000000   0.000053  0.999843        clean
#  589143   0.033309      unknown   0.000033   0.000066  0.999443        clean
#
#          transmission       size       lat      long
#  Id
#  559327     automatic   mid-size  0.000207 -0.000403
#  1260418       manual  full-size  0.000185 -0.000649
#  792110     automatic    compact  0.015895 -0.031597
#  1191078    automatic   mid-size  0.001990 -0.006141
#  228988     automatic  full-size  0.000266 -0.000810
#  ...              ...        ...       ...       ...
#  1561693    automatic    compact  0.004661 -0.010353
#  274624     automatic  full-size  0.000295 -0.000764
#  681992        manual    compact  0.000296 -0.001038
#  945416     automatic  full-size  0.000366 -0.000641
#  589143     automatic  full-size  0.000703 -0.002032
#
#  [37260 rows x 10 columns]}

# %%
for i, dic in X_dec.items():
    print(dic)
    break
# Out:
#              year manufacturer  condition  cylinders  odometer title_status  \
# Id
# 1446117  0.115744      ferrari   0.000058   0.000234  0.993263        clean
# 723398   0.017658      ferrari   0.000000   0.000053  0.999844        clean
# 1321337  0.049788      ferrari   0.000050   0.000200  0.998757        clean
# 608244   0.113560      ferrari   0.000056   0.000452  0.993506        clean
# 684579   0.036192      ferrari   0.000000   0.000144  0.999342        clean
# 162605   0.117210      ferrari   0.000117   0.000350  0.993077        clean
# 635380   0.070377      ferrari   0.000070   0.000211  0.997511        clean
# 315525   0.042871      ferrari   0.000043   0.000171  0.999079        clean
# 212262   0.017473      ferrari   0.000000   0.000053  0.999847      rebuilt
# 1190071  0.077948      ferrari   0.000000   0.000312  0.996952        clean
# 482666   0.245215      ferrari   0.000000   0.000978  0.969363        clean
# 841806   0.269206      ferrari   0.000000   0.001074  0.962964        clean
# 642271   0.050094      ferrari   0.000000   0.000151  0.998739        clean
# 740451   0.074264      ferrari   0.000000   0.000296  0.997229        clean
# 43879    0.359490      ferrari   0.000179   0.001429  0.932851        clean
# 1376282  0.017648      ferrari   0.000018   0.000070  0.999844        clean
# 1121000  0.106877      ferrari   0.000108   0.000432  0.994261        clean
# 1175427  0.164875      ferrari   0.000164   0.000493  0.986288        clean
# 988052   0.103836      ferrari   0.000000   0.000311  0.994580        clean
# 1500489  0.044264      ferrari   0.000045   0.000178  0.999015        clean
# 1174089  0.101284      ferrari   0.000000   0.000303  0.994848        clean
# 737730   0.017764      ferrari   0.000000   0.000053  0.999842        clean
# 670095   0.070927      ferrari   0.000000   0.000425  0.997472        clean
# 631033   0.260863      ferrari   0.000000   0.000779  0.965243        clean
# 668606   0.894620      ferrari   0.000887   0.002661  0.443540        clean
# 560731   0.027182      ferrari   0.000027   0.000110  0.999630        clean
# 632686   0.067152      ferrari   0.000000   0.000201  0.997734        clean
# 715026   0.070377      ferrari   0.000070   0.000211  0.997511        clean
# 669494   0.074264      ferrari   0.000074   0.000296  0.997229        clean
# 660764   0.036192      ferrari   0.000000   0.000144  0.999342        clean
# 496613   0.129606      ferrari   0.000129   0.000517  0.991537        clean
# 225673   0.069071      ferrari   0.000000   0.000207  0.997607        clean
# 583172   0.110840      ferrari   0.000000   0.000331  0.993812        clean
# 585996   0.110840      ferrari   0.000000   0.000331  0.993812        clean
# 1661060  0.017473      ferrari   0.000018   0.000035  0.999847        clean
# 339023   0.084584      ferrari   0.000085   0.000254  0.996401        clean
# 322047   0.117210      ferrari   0.000117   0.000350  0.993077        clean
# 1499004  0.068867      ferrari   0.000034   0.000275  0.997615        clean
# 1450224  0.557607      ferrari   0.000553   0.001660  0.829773      rebuilt
# 76395    0.083374      ferrari   0.000083   0.000249  0.996503        clean
# 614715   0.067463      ferrari   0.000067   0.000268  0.997713        clean
# 1207437  0.017693      ferrari   0.000000   0.000070  0.999843        clean
# 680826   0.017711      ferrari   0.000000   0.000053  0.999843        clean
# 1473912  0.068867      ferrari   0.000034   0.000206  0.997616        clean
# 344248   0.077001      ferrari   0.000077   0.000307  0.997026        clean
# 94328    0.074264      ferrari   0.000074   0.000296  0.997229        clean
# 1572642  0.052349      ferrari   0.000053   0.000211  0.998626        clean
# 781747   0.017561      ferrari   0.000009   0.000053  0.999845        clean
# 682339   0.017755      ferrari   0.000000   0.000053  0.999842        clean
# 683466   0.036192      ferrari   0.000000   0.000144  0.999342        clean
# 1391340  0.017658      ferrari   0.000000   0.000053  0.999844        clean
# 611384   0.074264      ferrari   0.000000   0.000296  0.997229        clean
# 1483454  0.068867      ferrari   0.000034   0.000206  0.997616        clean
# 592246   0.112069      ferrari   0.000000   0.000335  0.993674        clean
# 686162   0.116723      ferrari   0.000117   0.000467  0.993139        clean
# 177995   0.036013      ferrari   0.000018   0.000145  0.999350        clean
# 638012   0.091760      ferrari   0.000093   0.000371  0.995764        clean
# 686164   0.116723      ferrari   0.000117   0.000467  0.993139        clean
# 1133467  0.017508      ferrari   0.000000   0.000053  0.999846        clean
# 228068   0.017464      ferrari   0.000000   0.000053  0.999847   parts only
#
#         transmission         size       lat      long
# Id
# 1446117       manual      compact  0.002343 -0.005158
# 723398        manual    full-size  0.000297 -0.001038
# 1321337       manual    full-size  0.000858 -0.002071
# 608244     automatic     mid-size  0.002005 -0.006818
# 684579     automatic    full-size  0.000608 -0.002095
# 162605     automatic    full-size  0.002868 -0.007180
# 635380        manual    full-size  0.001243 -0.004252
# 315525        manual      compact  0.000553 -0.001721
# 212262        manual    full-size  0.000268 -0.000801
# 1190071    automatic    full-size  0.001041 -0.003121
# 482666     automatic    full-size  0.004086 -0.013681
# 841806     automatic    full-size  0.005436 -0.014085
# 642271        manual    full-size  0.000922 -0.003071
# 740451     automatic    full-size  0.001249 -0.004308
# 43879          other    full-size  0.008711 -0.021882
# 1376282        other    full-size  0.000380 -0.000630
# 1121000       manual    full-size  0.001542 -0.004418
# 1175427    automatic    full-size  0.002245 -0.006785
# 988052     automatic    full-size  0.002343 -0.004842
# 1500489       manual    full-size  0.001090 -0.002734
# 1174089       manual    full-size  0.001390 -0.004171
# 737730         other    full-size  0.000319 -0.001051
# 670095     automatic    full-size  0.001200 -0.004154
# 631033     automatic      compact  0.004444 -0.015360
# 668606        manual    full-size  0.014661 -0.052013
# 560731        manual     mid-size  0.000534 -0.001047
# 632686     automatic    full-size  0.001266 -0.004100
# 715026        manual    full-size  0.001243 -0.004252
# 669494     automatic    full-size  0.001249 -0.004308
# 660764     automatic    full-size  0.000608 -0.002095
# 496613     automatic    full-size  0.002160 -0.007231
# 225673         other    full-size  0.001339 -0.002658
# 583172         other  sub-compact  0.002514 -0.006762
# 585996         other  sub-compact  0.002514 -0.006762
# 1661060       manual      compact  0.000394 -0.000770
# 339023     automatic    full-size  0.002082 -0.005200
# 322047     automatic    full-size  0.002869 -0.007180
# 1499004    automatic    full-size  0.001675 -0.004209
# 1450224    automatic    full-size  0.011302 -0.020489
# 76395      automatic    full-size  0.002039 -0.005092
# 614715     automatic    full-size  0.001292 -0.004068
# 1207437    automatic    full-size  0.000401 -0.000978
# 680826     automatic    full-size  0.000299 -0.001043
# 1473912    automatic    full-size  0.001675 -0.004209
# 344248         other    full-size  0.001657 -0.002743
# 94328      automatic    full-size  0.001249 -0.004308
# 1572642       manual    full-size  0.001080 -0.001946
# 781747     automatic    full-size  0.000365 -0.000668
# 682339     automatic    full-size  0.000297 -0.001036
# 683466     automatic    full-size  0.000608 -0.002095
# 1391340        other    full-size  0.000331 -0.000683
# 611384     automatic    full-size  0.001249 -0.004308
# 1483454    automatic    full-size  0.001675 -0.004209
# 592246     automatic    full-size  0.002456 -0.006762
# 686162        manual      compact  0.001942 -0.006853
# 177995        manual     mid-size  0.000694 -0.001554
# 638012        manual    full-size  0.001717 -0.005659
# 686164        manual      compact  0.001942 -0.006853
# 1133467    automatic    full-size  0.000257 -0.000713
# 228068     automatic    full-size  0.000268 -0.000802

# %%
y_dec['lincoln']
# Out:
# Id
# 1299110     1200
# 194087      9999
# 58003       7300
# 615420      1400
# 97647       1500
#            ...
# 817243     12136
# 1388591     9299
# 506679      9500
# 1375991    11500
# 1123451     4200
# Name: price, Length: 3553, dtype: int64

# %%
# Split Train and Test
train_test_dec = {}
for i, X_new in X_dec.items():
    X_train, X_test, y_train, y_test = train_test_split(X_new,y_dec[i],test_size=0.2,random_state=200)
    train_test_dec[i] = [X_train, X_test, y_train, y_test]

# %%
train_test_dec
# Out:
# {'ferrari': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   583172   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#   482666   0.245215      ferrari   0.000000   0.000978  0.969363        clean
#   638012   0.091760      ferrari   0.000093   0.000371  0.995764        clean
#   76395    0.083374      ferrari   0.000083   0.000249  0.996503        clean
#   212262   0.017473      ferrari   0.000000   0.000053  0.999847      rebuilt
#   614715   0.067463      ferrari   0.000067   0.000268  0.997713        clean
#   1500489  0.044264      ferrari   0.000045   0.000178  0.999015        clean
#   225673   0.069071      ferrari   0.000000   0.000207  0.997607        clean
#   669494   0.074264      ferrari   0.000074   0.000296  0.997229        clean
#   683466   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#   496613   0.129606      ferrari   0.000129   0.000517  0.991537        clean
#   1450224  0.557607      ferrari   0.000553   0.001660  0.829773      rebuilt
#   988052   0.103836      ferrari   0.000000   0.000311  0.994580        clean
#   660764   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#   1473912  0.068867      ferrari   0.000034   0.000206  0.997616        clean
#   1661060  0.017473      ferrari   0.000018   0.000035  0.999847        clean
#   1446117  0.115744      ferrari   0.000058   0.000234  0.993263        clean
#   1174089  0.101284      ferrari   0.000000   0.000303  0.994848        clean
#   1499004  0.068867      ferrari   0.000034   0.000275  0.997615        clean
#   608244   0.113560      ferrari   0.000056   0.000452  0.993506        clean
#   781747   0.017561      ferrari   0.000009   0.000053  0.999845        clean
#   686164   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#   740451   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#   670095   0.070927      ferrari   0.000000   0.000425  0.997472        clean
#   344248   0.077001      ferrari   0.000077   0.000307  0.997026        clean
#   668606   0.894620      ferrari   0.000887   0.002661  0.443540        clean
#   737730   0.017764      ferrari   0.000000   0.000053  0.999842        clean
#   631033   0.260863      ferrari   0.000000   0.000779  0.965243        clean
#   94328    0.074264      ferrari   0.000074   0.000296  0.997229        clean
#   592246   0.112069      ferrari   0.000000   0.000335  0.993674        clean
#   1190071  0.077948      ferrari   0.000000   0.000312  0.996952        clean
#   1391340  0.017658      ferrari   0.000000   0.000053  0.999844        clean
#   315525   0.042871      ferrari   0.000043   0.000171  0.999079        clean
#   723398   0.017658      ferrari   0.000000   0.000053  0.999844        clean
#   177995   0.036013      ferrari   0.000018   0.000145  0.999350        clean
#   635380   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#   841806   0.269206      ferrari   0.000000   0.001074  0.962964        clean
#   1483454  0.068867      ferrari   0.000034   0.000206  0.997616        clean
#   715026   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#   43879    0.359490      ferrari   0.000179   0.001429  0.932851        clean
#   560731   0.027182      ferrari   0.000027   0.000110  0.999630        clean
#   1376282  0.017648      ferrari   0.000018   0.000070  0.999844        clean
#   642271   0.050094      ferrari   0.000000   0.000151  0.998739        clean
#   680826   0.017711      ferrari   0.000000   0.000053  0.999843        clean
#   684579   0.036192      ferrari   0.000000   0.000144  0.999342        clean
#   1121000  0.106877      ferrari   0.000108   0.000432  0.994261        clean
#   1207437  0.017693      ferrari   0.000000   0.000070  0.999843        clean
#   632686   0.067152      ferrari   0.000000   0.000201  0.997734        clean
#
#           transmission         size       lat      long
#   Id
#   583172         other  sub-compact  0.002514 -0.006762
#   482666     automatic    full-size  0.004086 -0.013681
#   638012        manual    full-size  0.001717 -0.005659
#   76395      automatic    full-size  0.002039 -0.005092
#   212262        manual    full-size  0.000268 -0.000801
#   614715     automatic    full-size  0.001292 -0.004068
#   1500489       manual    full-size  0.001090 -0.002734
#   225673         other    full-size  0.001339 -0.002658
#   669494     automatic    full-size  0.001249 -0.004308
#   683466     automatic    full-size  0.000608 -0.002095
#   496613     automatic    full-size  0.002160 -0.007231
#   1450224    automatic    full-size  0.011302 -0.020489
#   988052     automatic    full-size  0.002343 -0.004842
#   660764     automatic    full-size  0.000608 -0.002095
#   1473912    automatic    full-size  0.001675 -0.004209
#   1661060       manual      compact  0.000394 -0.000770
#   1446117       manual      compact  0.002343 -0.005158
#   1174089       manual    full-size  0.001390 -0.004171
#   1499004    automatic    full-size  0.001675 -0.004209
#   608244     automatic     mid-size  0.002005 -0.006818
#   781747     automatic    full-size  0.000365 -0.000668
#   686164        manual      compact  0.001942 -0.006853
#   740451     automatic    full-size  0.001249 -0.004308
#   670095     automatic    full-size  0.001200 -0.004154
#   344248         other    full-size  0.001657 -0.002743
#   668606        manual    full-size  0.014661 -0.052013
#   737730         other    full-size  0.000319 -0.001051
#   631033     automatic      compact  0.004444 -0.015360
#   94328      automatic    full-size  0.001249 -0.004308
#   592246     automatic    full-size  0.002456 -0.006762
#   1190071    automatic    full-size  0.001041 -0.003121
#   1391340        other    full-size  0.000331 -0.000683
#   315525        manual      compact  0.000553 -0.001721
#   723398        manual    full-size  0.000297 -0.001038
#   177995        manual     mid-size  0.000694 -0.001554
#   635380        manual    full-size  0.001243 -0.004252
#   841806     automatic    full-size  0.005436 -0.014085
#   1483454    automatic    full-size  0.001675 -0.004209
#   715026        manual    full-size  0.001243 -0.004252
#   43879          other    full-size  0.008711 -0.021882
#   560731        manual     mid-size  0.000534 -0.001047
#   1376282        other    full-size  0.000380 -0.000630
#   642271        manual    full-size  0.000922 -0.003071
#   680826     automatic    full-size  0.000299 -0.001043
#   684579     automatic    full-size  0.000608 -0.002095
#   1121000       manual    full-size  0.001542 -0.004418
#   1207437    automatic    full-size  0.000401 -0.000978
#   632686     automatic    full-size  0.001266 -0.004100  ,
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1175427  0.164875      ferrari   0.000164   0.000493  0.986288        clean
#   162605   0.117210      ferrari   0.000117   0.000350  0.993077        clean
#   585996   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#   682339   0.017755      ferrari   0.000000   0.000053  0.999842        clean
#   1133467  0.017508      ferrari   0.000000   0.000053  0.999846        clean
#   1321337  0.049788      ferrari   0.000050   0.000200  0.998757        clean
#   322047   0.117210      ferrari   0.000117   0.000350  0.993077        clean
#   686162   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#   1572642  0.052349      ferrari   0.000053   0.000211  0.998626        clean
#   611384   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#   228068   0.017464      ferrari   0.000000   0.000053  0.999847   parts only
#   339023   0.084584      ferrari   0.000085   0.000254  0.996401        clean
#
#           transmission         size       lat      long
#   Id
#   1175427    automatic    full-size  0.002245 -0.006785
#   162605     automatic    full-size  0.002868 -0.007180
#   585996         other  sub-compact  0.002514 -0.006762
#   682339     automatic    full-size  0.000297 -0.001036
#   1133467    automatic    full-size  0.000257 -0.000713
#   1321337       manual    full-size  0.000858 -0.002071
#   322047     automatic    full-size  0.002869 -0.007180
#   686162        manual      compact  0.001942 -0.006853
#   1572642       manual    full-size  0.001080 -0.001946
#   611384     automatic    full-size  0.001249 -0.004308
#   228068     automatic    full-size  0.000268 -0.000802
#   339023     automatic    full-size  0.002082 -0.005200  ,
#   Id
#   583172     107990
#   482666     119950
#   638012     100000
#   76395      279995
#   212262      20500
#   614715     139800
#   1500489     89990
#   225673      77777
#   669494     129999
#   683466     140000
#   496613     104950
#   1450224    229000
#   988052      99000
#   660764     148450
#   1473912     95850
#   1661060      6500
#   1446117      5000
#   1174089     69976
#   1499004     95850
#   608244      99500
#   781747       8000
#   686164      95000
#   740451     109970
#   670095      73777
#   344248     129900
#   668606     285000
#   737730       1234
#   631033     180000
#   94328      129999
#   592246     149999
#   1190071     69899
#   1391340     99000
#   315525      82500
#   723398      99600
#   177995      30000
#   635380     129995
#   841806      97900
#   1483454     95850
#   715026     129995
#   43879      189850
#   560731      35000
#   1376282    129900
#   642271      89500
#   680826          1
#   684579     148450
#   1121000     40000
#   1207437     67500
#   632686      89900
#   Name: price, dtype: int64,
#   Id
#   1175427     98129
#   162605     159999
#   585996     109990
#   682339        599
#   1133467      3000
#   1321337     49000
#   322047     159999
#   686162      95000
#   1572642     70000
#   611384     109999
#   228068       8400
#   339023     367999
#   Name: price, dtype: int64],
#  'kia': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   122874   0.016248          kia   0.000000   0.000049  0.999868        clean
#   986274   0.012524          kia   0.000006   0.000025  0.999921        clean
#   1156585  0.036643          kia   0.000018   0.000109  0.999327        clean
#   1115247  0.020106          kia   0.000020   0.000040  0.999797        clean
#   1163956  0.036099          kia   0.000000   0.000108  0.999347        clean
#   ...           ...          ...        ...        ...       ...          ...
#   973490   0.067168          kia   0.000000   0.000133  0.997736        clean
#   1558596  0.019352          kia   0.000010   0.000038  0.999812        clean
#   1543675  0.010390          kia   0.000005   0.000031  0.999946        clean
#   1497621  0.009913          kia   0.000000   0.000030  0.999951        clean
#   525746   0.264559          kia   0.000000   0.000787  0.964276        clean
#
#           transmission       size       lat      long
#   Id
#   122874     automatic  full-size  0.000317 -0.000880
#   986274     automatic  full-size  0.000295 -0.000601
#   1156585    automatic  full-size  0.000554 -0.001585
#   1115247    automatic  full-size  0.000258 -0.000803
#   1163956    automatic  full-size  0.000535 -0.001458
#   ...              ...        ...       ...       ...
#   973490         other   mid-size  0.001489 -0.003153
#   1558596    automatic   mid-size  0.000408 -0.000888
#   1543675    automatic   mid-size  0.000205 -0.000404
#   1497621    automatic  full-size  0.000233 -0.000605
#   525746     automatic  full-size  0.004732 -0.012574
#
#   [5439 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   142527   0.021886          kia   0.000022   0.000043  0.999760        clean
#   278461   0.022350          kia   0.000022   0.000044  0.999750        clean
#   614711   0.010172          kia   0.000000   0.000020  0.999948        clean
#   824714   0.168574          kia   0.000084   0.000337  0.985662        clean
#   1340569  0.050335          kia   0.000000   0.000150  0.998728        clean
#   ...           ...          ...        ...        ...       ...          ...
#   781073   0.013412          kia   0.000013   0.000027  0.999910        clean
#   1114296  0.011656          kia   0.000000   0.000023  0.999932        clean
#   995572   0.991543          kia   0.000494   0.001975  0.122461        clean
#   1663454  0.232461          kia   0.000000   0.000461  0.972531        clean
#   999038   0.094134          kia   0.000047   0.000280  0.995551        clean
#
#           transmission       size       lat      long
#   Id
#   142527        manual   mid-size  0.000332 -0.000959
#   278461     automatic   mid-size  0.000327 -0.001095
#   614711     automatic   mid-size  0.000196 -0.000616
#   824714     automatic   mid-size  0.003498 -0.006365
#   1340569    automatic  full-size  0.000927 -0.002839
#   ...              ...        ...       ...       ...
#   781073        manual    compact  0.000277 -0.000504
#   1114296    automatic    compact  0.000160 -0.000480
#   995572     automatic    compact  0.016839 -0.039473
#   1663454       manual   mid-size  0.004387 -0.011229
#   999038         other  full-size  0.001531 -0.003735
#
#   [1360 rows x 10 columns],
#   Id
#   122874      7149
#   986274      1350
#   1156585    15000
#   1115247     6800
#   1163956     9995
#              ...
#   973490     18888
#   1558596     7595
#   1543675      800
#   1497621     2888
#   525746     12911
#   Name: price, Length: 5439, dtype: int64,
#   Id
#   142527      6400
#   278461      6499
#   614711      2700
#   824714      2700
#   1340569    12000
#              ...
#   781073      4600
#   1114296     1200
#   995572      2495
#   1663454    12303
#   999038     21500
#   Name: price, Length: 1360, dtype: int64],
#  'harley-davidson': [             year     manufacturer  condition  cylinders  odometer  \
#   Id
#   183698   0.017676  harley-davidson   0.000000   0.000053  0.999843
#   55626    0.017667  harley-davidson   0.000000   0.000053  0.999844
#   719881   0.163306  harley-davidson   0.000000   0.000489  0.986521
#   520899   0.152646  harley-davidson   0.000152   0.000456  0.988249
#   896017   0.904019  harley-davidson   0.000000   0.002692  0.425315
#   ...           ...              ...        ...        ...       ...
#   379606   0.742379  harley-davidson   0.000000   0.002212  0.668288
#   1437662  0.017482  harley-davidson   0.000009   0.000053  0.999847
#   538326   0.017588  harley-davidson   0.000000   0.000053  0.999845
#   1442786  0.017482  harley-davidson   0.000009   0.000053  0.999847
#   879840   0.742501  harley-davidson   0.000743   0.002230  0.668920
#
#           title_status transmission       size       lat      long
#   Id
#   183698       rebuilt       manual  full-size  0.000331 -0.000751
#   55626          clean       manual  full-size  0.000333 -0.000666
#   719881         clean       manual  full-size  0.002989 -0.009914
#   520899         clean       manual  full-size  0.002767 -0.007439
#   896017         clean       manual  full-size  0.019371 -0.038387
#   ...              ...          ...        ...       ...       ...
#   379606         clean        other  full-size  0.017840 -0.044064
#   1437662        clean       manual  full-size  0.000370 -0.000789
#   538326         clean        other  full-size  0.000311 -0.000820
#   1442786        clean       manual  full-size  0.000370 -0.000789
#   879840         clean       manual  full-size  0.015685 -0.031421
#
#   [161 rows x 10 columns],
#                year     manufacturer  condition  cylinders  odometer  \
#   Id
#   1332570  0.017728  harley-davidson   0.000018   0.000053  0.999842
#   434947   0.006663  harley-davidson   0.000000   0.000020  0.999978
#   1194933  0.017632  harley-davidson   0.000018   0.000053  0.999844
#   1381328  0.017649  harley-davidson   0.000000   0.000053  0.999844
#   1672641  0.224683  harley-davidson   0.000225   0.000676  0.974379
#   993682   0.022104  harley-davidson   0.000022   0.000088  0.999755
#   297100   0.141488  harley-davidson   0.000000   0.000424  0.989919
#   1281987  0.017711  harley-davidson   0.000000   0.000053  0.999843
#   230045   0.027113  harley-davidson   0.000027   0.000081  0.999631
#   1559134  0.017649  harley-davidson   0.000000   0.000053  0.999844
#   871738   0.017588  harley-davidson   0.000018   0.000053  0.999845
#   1477563  0.975611  harley-davidson   0.000972   0.002917  0.209997
#   1532607  0.286006  harley-davidson   0.000000   0.000852  0.958133
#   53968    0.097574  harley-davidson   0.000097   0.000291  0.995219
#   415708   0.017693  harley-davidson   0.000000   0.000053  0.999842
#   53738    0.097574  harley-davidson   0.000097   0.000291  0.995219
#   1653561  0.023102  harley-davidson   0.000000   0.000069  0.999732
#   107311   0.006262  harley-davidson   0.000006   0.000025  0.999980
#   1524185  0.017720  harley-davidson   0.000018   0.000053  0.999843
#   972718   0.012543  harley-davidson   0.000006   0.000037  0.999921
#   1306175  0.017614  harley-davidson   0.000000   0.000053  0.999845
#   331032   0.016014  harley-davidson   0.000008   0.000064  0.999871
#   1141219  0.017658  harley-davidson   0.000000   0.000053  0.999844
#   1166550  0.011149  harley-davidson   0.000011   0.000033  0.999938
#   1234337  0.989072  harley-davidson   0.000000   0.002947  0.138981
#   775854   0.064606  harley-davidson   0.000000   0.000193  0.997907
#   438529   0.062960  harley-davidson   0.000000   0.000188  0.998012
#   1074697  0.017667  harley-davidson   0.000009   0.000053  0.999844
#   1107482  0.017711  harley-davidson   0.000018   0.000053  0.999843
#   87776    0.017658  harley-davidson   0.000009   0.000070  0.999844
#   783643   0.100846  harley-davidson   0.000000   0.000301  0.994892
#   1473754  0.017640  harley-davidson   0.000000   0.000053  0.999844
#   426717   0.017649  harley-davidson   0.000000   0.000053  0.999844
#   809250   0.717353  harley-davidson   0.000713   0.002139  0.695961
#   508134   0.177503  harley-davidson   0.000000   0.000530  0.984079
#   1295604  0.017649  harley-davidson   0.000000   0.000053  0.999844
#   1014387  0.017570  harley-davidson   0.000000   0.000053  0.999845
#   457993   0.011110  harley-davidson   0.000006   0.000044  0.999938
#   1630028  0.017632  harley-davidson   0.000000   0.000053  0.999844
#   1550128  0.071707  harley-davidson   0.000036   0.000214  0.997419
#   848072   0.373643  harley-davidson   0.000000   0.001113  0.927339
#
#           title_status transmission       size       lat      long
#   Id
#   1332570        clean        other  full-size  0.000362 -0.000847
#   434947         clean       manual  full-size  0.000133 -0.000280
#   1194933        clean    automatic  full-size  0.000238 -0.000706
#   1381328        clean        other  full-size  0.000376 -0.000627
#   1672641        clean        other  full-size  0.004005 -0.009289
#   993682         clean    automatic  full-size  0.000383 -0.000904
#   297100         clean       manual  full-size  0.002802 -0.005836
#   1281987      rebuilt    automatic  full-size  0.000231 -0.000866
#   230045         clean        other  full-size  0.000662 -0.001652
#   1559134        clean       manual  full-size  0.000379 -0.000846
#   871738         clean       manual  full-size  0.000370 -0.000740
#   1477563        clean    automatic  full-size  0.023271 -0.059438
#   1532607        clean        other  full-size  0.005699 -0.012214
#   53968          clean       manual  full-size  0.001976 -0.003899
#   415708         clean    automatic  full-size  0.000538 -0.001319
#   53738          clean       manual  full-size  0.001976 -0.003899
#   1653561        clean    automatic  full-size  0.000515 -0.001052
#   107311         clean    automatic  full-size  0.000101 -0.000326
#   1524185         lien       manual  full-size  0.000353 -0.000754
#   972718         clean    automatic  full-size  0.000275 -0.000580
#   1306175        clean    automatic  full-size  0.000284 -0.000716
#   331032         clean    automatic  full-size  0.000489 -0.001200
#   1141219        clean       manual  full-size  0.000249 -0.000728
#   1166550        clean    automatic  full-size  0.000146 -0.000446
#   1234337        clean       manual  full-size  0.014693 -0.046870
#   775854         clean       manual  full-size  0.001356 -0.002336
#   438529         clean    automatic  full-size  0.001225 -0.002644
#   1074697        clean       manual   mid-size  0.000316 -0.000749
#   1107482        clean    automatic  full-size  0.000262 -0.000726
#   87776          clean    automatic  full-size  0.000312 -0.000713
#   783643         clean       manual  full-size  0.002004 -0.004010
#   1473754        clean       manual  full-size  0.000431 -0.001078
#   426717         clean       manual  full-size  0.000265 -0.000810
#   809250         clean       manual  full-size  0.015047 -0.028477
#   508134         clean    automatic  full-size  0.003183 -0.008458
#   1295604        clean       manual  full-size  0.000289 -0.000857
#   1014387        clean       manual  full-size  0.000350 -0.000666
#   457993         clean    automatic  full-size  0.000218 -0.000456
#   1630028        clean       manual  full-size  0.000376 -0.000783
#   1550128        clean       manual  full-size  0.001499 -0.003235
#   848072         clean       manual  full-size  0.007358 -0.019455  ,
#   Id
#   183698         1
#   55626      15000
#   719881      9999
#   520899     15142
#   896017     15998
#              ...
#   379606     14970
#   1437662     4500
#   538326      6000
#   1442786     6100
#   879840     14500
#   Name: price, Length: 161, dtype: int64,
#   Id
#   1332570    19988
#   434947      3700
#   1194933    24900
#   1381328     9995
#   1672641        1
#   993682     28500
#   297100      3000
#   1281987    19500
#   230045     12320
#   1559134        1
#   871738     11500
#   1477563    14995
#   1532607    15500
#   53968      11001
#   415708     20700
#   53738      13500
#   1653561    21950
#   107311      8995
#   1524185       12
#   972718     14900
#   1306175     7800
#   331032     12000
#   1141219     5500
#   1166550    16990
#   1234337     2500
#   775854      7000
#   438529      5000
#   1074697     6000
#   1107482    25509
#   87776      11000
#   783643      8995
#   1473754     7000
#   426717     10000
#   809250     11991
#   508134     12891
#   1295604        1
#   1014387     2500
#   457993      5500
#   1630028     6995
#   1550128     9500
#   848072     17494
#   Name: price, dtype: int64],
#  'morgan': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1173925  0.017262       morgan   0.000018   0.000035  0.999851        clean
#   704129   0.007273       morgan   0.000000   0.000044  0.999973        clean
#   1147457  0.038810       morgan   0.000020   0.000079  0.999245        clean
#
#           transmission      size       lat      long
#   Id
#   1173925       manual  mid-size  0.000233 -0.000720
#   704129         other  mid-size  0.000141 -0.000442
#   1147457       manual  mid-size  0.000590 -0.001604  ,
#               year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   816430  0.017711       morgan   0.000018   0.000053  0.999843        clean
#
#          transmission       size       lat      long
#   Id
#   816430    automatic  full-size  0.000352 -0.000661  ,
#   Id
#   1173925    34000
#   704129         1
#   1147457    29900
#   Name: price, dtype: int64,
#   Id
#   816430    3500
#   Name: price, dtype: int64],
#  'mazda': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   190815   0.026926        mazda   0.000027   0.000054  0.999637        clean
#   970915   0.018859        mazda   0.000019   0.000037  0.999822        clean
#   209472   0.990600        mazda   0.000982   0.001965  0.120326      rebuilt
#   812421   0.009532        mazda   0.000005   0.000019  0.999954        clean
#   691784   0.017552        mazda   0.000009   0.000053  0.999845        clean
#   ...           ...          ...        ...        ...       ...          ...
#   839918   0.060172        mazda   0.000000   0.000179  0.998182        clean
#   610450   0.024475        mazda   0.000024   0.000073  0.999699        clean
#   312320   0.010707        mazda   0.000011   0.000032  0.999942        clean
#   1556542  0.031637        mazda   0.000000   0.000063  0.999498      rebuilt
#   27462    0.011724        mazda   0.000012   0.000023  0.999931        clean
#
#           transmission         size       lat      long
#   Id
#   190815     automatic  sub-compact  0.000605 -0.001229
#   970915     automatic     mid-size  0.000424 -0.000879
#   209472     automatic     mid-size  0.024166 -0.060372
#   812421        manual     mid-size  0.000194 -0.000364
#   691784        manual    full-size  0.000326 -0.001057
#   ...              ...          ...       ...       ...
#   839918     automatic    full-size  0.001161 -0.003128
#   610450        manual      compact  0.000496 -0.001495
#   312320     automatic    full-size  0.000262 -0.000654
#   1556542    automatic     mid-size  0.000644 -0.001438
#   27462         manual     mid-size  0.000288 -0.000720
#
#   [5104 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1074839  0.012482        mazda   0.000000   0.000037  0.999922        clean
#   1643880  0.012687        mazda   0.000006   0.000025  0.999919        clean
#   631718   0.017605        mazda   0.000000   0.000053  0.999844      salvage
#   1273072  0.017693        mazda   0.000018   0.000035  0.999843        clean
#   61292    0.051779        mazda   0.000051   0.000103  0.998653        clean
#   ...           ...          ...        ...        ...       ...          ...
#   152347   0.018437        mazda   0.000018   0.000037  0.999830        clean
#   1523946  0.021207        mazda   0.000011   0.000042  0.999775        clean
#   1082405  0.997700        mazda   0.000992   0.001983  0.050083        clean
#   1251949  0.026332        mazda   0.000013   0.000078  0.999652        clean
#   1316536  0.010440        mazda   0.000005   0.000021  0.999945        clean
#
#           transmission       size       lat      long
#   Id
#   1074839    automatic  full-size  0.000227 -0.000513
#   1643880       manual    compact  0.000286 -0.000582
#   631718     automatic  full-size  0.000320 -0.001053
#   1273072    automatic   mid-size  0.000266 -0.000861
#   61292      automatic   mid-size  0.001264 -0.003157
#   ...              ...        ...       ...       ...
#   152347     automatic   mid-size  0.000385 -0.000678
#   1523946       manual   mid-size  0.000435 -0.000900
#   1082405    automatic   mid-size  0.017394 -0.042181
#   1251949    automatic  full-size  0.000343 -0.001283
#   1316536       manual   mid-size  0.000168 -0.000441
#
#   [1276 rows x 10 columns],
#   Id
#   190815      8500
#   970915     10975
#   209472     17990
#   812421      2650
#   691784       600
#              ...
#   839918     10998
#   610450      6995
#   312320      8450
#   1556542     4500
#   27462       5495
#   Name: price, Length: 5104, dtype: int64,
#   Id
#   1074839     4400
#   1643880     3300
#   631718      2500
#   1273072     6000
#   61292      11995
#              ...
#   152347      5495
#   1523946     7500
#   1082405     8000
#   1251949      299
#   1316536     2600
#   Name: price, Length: 1276, dtype: int64],
#  'mini': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   55221    0.998834         mini   0.000000   0.002980  0.000000        clean
#   169900   0.017684         mini   0.000000   0.000053  0.999843        clean
#   1323755  0.017702         mini   0.000000   0.000053  0.999843        clean
#   89302    0.017667         mini   0.000000   0.000035  0.999843      salvage
#   537552   0.015155         mini   0.000008   0.000045  0.999885        clean
#   ...           ...          ...        ...        ...       ...          ...
#   957337   0.017676         mini   0.000000   0.000053  0.999843        clean
#   281367   0.016054         mini   0.000000   0.000048  0.999871        clean
#   636354   0.032719         mini   0.000033   0.000065  0.999462        clean
#   643853   0.029404         mini   0.000000   0.000088  0.999566        clean
#   544247   0.025344         mini   0.000025   0.000050  0.999678        clean
#
#           transmission         size       lat      long
#   Id
#   55221          other    full-size  0.020673 -0.043526
#   169900     automatic    full-size  0.000359 -0.000643
#   1323755    automatic    full-size  0.000360 -0.000866
#   89302      automatic      compact  0.000420 -0.001032
#   537552     automatic    full-size  0.000272 -0.000711
#   ...              ...          ...       ...       ...
#   957337        manual    full-size  0.000368 -0.000641
#   281367        manual    full-size  0.000264 -0.000641
#   636354     automatic      compact  0.000615 -0.001977
#   643853         other  sub-compact  0.000567 -0.001782
#   544247     automatic      compact  0.000495 -0.000964
#
#   [1396 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   717949   0.042926         mini   0.000021   0.000085  0.999075        clean
#   65563    0.019501         mini   0.000019   0.000039  0.999809        clean
#   734065   0.017684         mini   0.000018   0.000035  0.999843        clean
#   1234877  0.016496         mini   0.000016   0.000049  0.999864        clean
#   501115   0.014247         mini   0.000007   0.000028  0.999898        clean
#   ...           ...          ...        ...        ...       ...          ...
#   312202   0.068644         mini   0.000068   0.000102  0.997631        clean
#   460414   0.034961         mini   0.000017   0.000104  0.999387        clean
#   1384721  0.012995         mini   0.000000   0.000039  0.999915        clean
#   189226   0.018559         mini   0.000000   0.000056  0.999827        clean
#   1427371  0.024479         mini   0.000000   0.000073  0.999700        clean
#
#           transmission         size       lat      long
#   Id
#   717949        manual     mid-size  0.000723 -0.002511
#   65563      automatic     mid-size  0.000450 -0.001158
#   734065     automatic      compact  0.000335 -0.001059
#   1234877       manual    full-size  0.000246 -0.000785
#   501115     automatic      compact  0.000232 -0.000813
#   ...              ...          ...       ...       ...
#   312202     automatic      compact  0.001676 -0.004194
#   460414         other    full-size  0.000718 -0.001452
#   1384721    automatic    full-size  0.000244 -0.000506
#   189226     automatic  sub-compact  0.000353 -0.000794
#   1427371    automatic    full-size  0.000513 -0.001078
#
#   [349 rows x 10 columns],
#   Id
#   55221       2100
#   169900      2000
#   1323755     7999
#   89302       4200
#   537552      7995
#              ...
#   957337      3600
#   281367      6000
#   636354      9495
#   643853      6999
#   544247     10900
#   Name: price, Length: 1396, dtype: int64,
#   Id
#   717949      6900
#   65563       6800
#   734065      6200
#   1234877     3350
#   501115      6800
#              ...
#   312202     20000
#   460414     16600
#   1384721     7995
#   189226      4799
#   1427371     4399
#   Name: price, Length: 349, dtype: int64],
#  'volvo': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1589093  0.011382        volvo   0.000000   0.000034  0.999935        clean
#   1250437  0.017711        volvo   0.000000   0.000053  0.999843        clean
#   626116   0.017737        volvo   0.000000   0.000053  0.999842        clean
#   948085   0.017649        volvo   0.000000   0.000053  0.999844        clean
#   838087   0.036310        volvo   0.000000   0.000108  0.999339        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1443177  0.017746        volvo   0.000000   0.000053  0.999842        clean
#   1032602  0.012138        volvo   0.000006   0.000036  0.999926        clean
#   1347456  0.015541        volvo   0.000016   0.000039  0.999879        clean
#   586765   0.995092        volvo   0.000993   0.002483  0.074483        clean
#   780904   0.017696        volvo   0.000009   0.000035  0.999843      rebuilt
#
#           transmission       size       lat      long
#   Id
#   1589093    automatic  full-size  0.000235 -0.000420
#   1250437    automatic  full-size  0.000279 -0.000833
#   626116     automatic  full-size  0.000310 -0.001048
#   948085     automatic  full-size  0.000364 -0.000635
#   838087     automatic  full-size  0.000725 -0.001896
#   ...              ...        ...       ...       ...
#   1443177    automatic  full-size  0.000369 -0.000772
#   1032602    automatic  full-size  0.000267 -0.000626
#   1347456    automatic   mid-size  0.000280 -0.000893
#   586765     automatic   mid-size  0.022141 -0.061211
#   780904     automatic   mid-size  0.000354 -0.000679
#
#   [2392 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   323356   0.017746        volvo   0.000018   0.000053  0.999842        clean
#   1212207  0.017649        volvo   0.000018   0.000070  0.999844        clean
#   778384   0.016618        volvo   0.000008   0.000041  0.999862        clean
#   705529   0.021217        volvo   0.000021   0.000053  0.999774        clean
#   608039   0.110730        volvo   0.000110   0.000329  0.993827        clean
#   ...           ...          ...        ...        ...       ...          ...
#   993905   0.017658        volvo   0.000000   0.000053  0.999844        clean
#   20649    0.012058        volvo   0.000006   0.000036  0.999927        clean
#   1717491  0.017667        volvo   0.000000   0.000053  0.999844        clean
#   697130   0.164668        volvo   0.000163   0.000490  0.986296        clean
#   1378815  0.009542        volvo   0.000000   0.000019  0.999954        clean
#
#           transmission       size       lat      long
#   Id
#   323356     automatic  full-size  0.000365 -0.000776
#   1212207    automatic  full-size  0.000412 -0.001004
#   778384     automatic   mid-size  0.000347 -0.000586
#   705529     automatic  full-size  0.000395 -0.001293
#   608039     automatic  full-size  0.001936 -0.006621
#   ...              ...        ...       ...       ...
#   993905     automatic  full-size  0.000290 -0.000703
#   20649      automatic  full-size  0.000254 -0.000458
#   1717491    automatic  full-size  0.000310 -0.000712
#   697130     automatic  full-size  0.002879 -0.009846
#   1378815    automatic   mid-size  0.000205 -0.000339
#
#   [599 rows x 10 columns],
#   Id
#   1589093     4595
#   1250437     5800
#   626116     28000
#   948085       800
#   838087     18999
#              ...
#   1443177    18275
#   1032602     1900
#   1347456     4200
#   586765      7950
#   780904      1595
#   Name: price, Length: 2392, dtype: int64,
#   Id
#   323356     50000
#   1212207     4995
#   778384      9995
#   705529      5800
#   608039     46995
#              ...
#   993905      3200
#   20649       2995
#   1717491     5300
#   697130     28995
#   1378815     2900
#   Name: price, Length: 599, dtype: int64],
#  'subaru': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   947006   0.010700       subaru   0.000011   0.000021  0.999943        clean
#   673672   0.013110       subaru   0.000013   0.000039  0.999914        clean
#   87979    0.211945       subaru   0.000210   0.000420  0.977237      salvage
#   4334     0.996621       subaru   0.000000   0.002966  0.049436        clean
#   1416374  0.031438       subaru   0.000016   0.000062  0.999505        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1273987  0.017649       subaru   0.000000   0.000053  0.999844        clean
#   478772   0.011206       subaru   0.000000   0.000034  0.999937        clean
#   250313   0.025812       subaru   0.000000   0.000077  0.999665        clean
#   1479697  0.025324       subaru   0.000025   0.000075  0.999678        clean
#   1440579  0.012657       subaru   0.000006   0.000025  0.999920        clean
#
#           transmission       size       lat      long
#   Id
#   947006     automatic   mid-size  0.000221 -0.000391
#   673672     automatic  full-size  0.000253 -0.000790
#   87979      automatic   mid-size  0.003681 -0.008614
#   4334       automatic  full-size  0.024341 -0.060841
#   1416374       manual    compact  0.000575 -0.001192
#   ...              ...        ...       ...       ...
#   1273987    automatic  full-size  0.000258 -0.000834
#   478772     automatic  full-size  0.000191 -0.000614
#   250313     automatic  full-size  0.000628 -0.001574
#   1479697    automatic  full-size  0.000609 -0.001541
#   1440579    automatic   mid-size  0.000265 -0.000555
#
#   [6479 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1686923  0.017605       subaru   0.000000   0.000053  0.999845        clean
#   631177   0.012934       subaru   0.000013   0.000026  0.999916        clean
#   1590815  0.016211       subaru   0.000016   0.000048  0.999868        clean
#   841961   0.023606       subaru   0.000000   0.000047  0.999720        clean
#   362831   0.017676       subaru   0.000000   0.000053  0.999843        clean
#   ...           ...          ...        ...        ...       ...          ...
#   758366   0.010578       subaru   0.000011   0.000021  0.999944        clean
#   347152   0.017693       subaru   0.000000   0.000053  0.999843        clean
#   800449   0.015099       subaru   0.000015   0.000060  0.999886        clean
#   767144   0.016361       subaru   0.000000   0.000049  0.999866        clean
#   1415212  0.014880       subaru   0.000007   0.000030  0.999889        clean
#
#           transmission       size       lat      long
#   Id
#   1686923    automatic  full-size  0.000316 -0.000705
#   631177     automatic   mid-size  0.000220 -0.000762
#   1590815    automatic  full-size  0.000348 -0.000618
#   841961     automatic    compact  0.000465 -0.001232
#   362831        manual  full-size  0.000353 -0.000659
#   ...              ...        ...       ...       ...
#   758366     automatic   mid-size  0.000222 -0.000382
#   347152     automatic  full-size  0.000384 -0.000758
#   800449     automatic  full-size  0.000303 -0.000581
#   767144     automatic  full-size  0.000339 -0.000577
#   1415212    automatic   mid-size  0.000280 -0.000588
#
#   [1620 rows x 10 columns],
#   Id
#   947006      3850
#   673672      8000
#   87979      12500
#   4334       22995
#   1416374    16900
#              ...
#   1273987     1200
#   478772      4500
#   250313     12990
#   1479697    17688
#   1440579     3795
#   Name: price, Length: 6479, dtype: int64,
#   Id
#   1686923     2495
#   631177      6490
#   1590815    11980
#   841961     17999
#   362831      4450
#              ...
#   758366      5800
#   347152      6800
#   800449      7995
#   767144     14500
#   1415212     6300
#   Name: price, Length: 1620, dtype: int64],
#  'buick': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   349501   0.011811        buick   0.000006   0.000035  0.999930        clean
#   1583536  0.108388        buick   0.000112   0.000335  0.994096        clean
#   1672160  0.017570        buick   0.000000   0.000053  0.999845        clean
#   113564   0.017737        buick   0.000000   0.000053  0.999842        clean
#   571062   0.017332        buick   0.000009   0.000070  0.999849        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1598296  0.017632        buick   0.000000   0.000053  0.999844        clean
#   1215958  0.038891        buick   0.000039   0.000116  0.999241        clean
#   1046998  0.020878        buick   0.000021   0.000062  0.999781      rebuilt
#   705743   0.017306        buick   0.000000   0.000070  0.999850        clean
#   203365   0.016062        buick   0.000016   0.000048  0.999871        clean
#
#           transmission       size       lat      long
#   Id
#   349501     automatic   mid-size  0.000179 -0.000523
#   1583536       manual  full-size  0.002409 -0.004318
#   1672160    automatic  full-size  0.000309 -0.000695
#   113564     automatic  full-size  0.000434 -0.001084
#   571062     automatic  full-size  0.000395 -0.001083
#   ...              ...        ...       ...       ...
#   1598296    automatic  full-size  0.000377 -0.000694
#   1215958    automatic  full-size  0.000924 -0.002137
#   1046998    automatic   mid-size  0.000407 -0.000957
#   705743     automatic  full-size  0.000350 -0.001073
#   203365     automatic  full-size  0.000345 -0.000620
#
#   [5011 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   1050582  0.025414        buick   0.000000   0.000076  0.999676        clean
#   1560438  0.021920        buick   0.000011   0.000066  0.999759        clean
#   883486   0.011764        buick   0.000000   0.000035  0.999931        clean
#   660683   0.014527        buick   0.000000   0.000043  0.999894        clean
#   1607047  0.017324        buick   0.000000   0.000053  0.999850        clean
#   ...           ...          ...        ...        ...       ...          ...
#   873330   0.096452        buick   0.000096   0.000192  0.995327        clean
#   20601    0.041079        buick   0.000041   0.000122  0.999154        clean
#   1441896  0.017588        buick   0.000000   0.000053  0.999845        clean
#   1670174  0.015027        buick   0.000007   0.000045  0.999887        clean
#   265222   0.011060        buick   0.000000   0.000044  0.999939        clean
#
#           transmission       size       lat      long
#   Id
#   1050582    automatic  full-size  0.000488 -0.001190
#   1560438    automatic  full-size  0.000464 -0.001009
#   883486     automatic  full-size  0.000251 -0.000490
#   660683     automatic  full-size  0.000249 -0.000867
#   1607047    automatic  full-size  0.000370 -0.000651
#   ...              ...        ...       ...       ...
#   873330         other   mid-size  0.002066 -0.004097
#   20601      automatic   mid-size  0.000855 -0.001553
#   1441896    automatic   mid-size  0.000370 -0.000775
#   1670174    automatic  full-size  0.000292 -0.000715
#   265222     automatic  full-size  0.000236 -0.000487
#
#   [1253 rows x 10 columns],
#   Id
#   349501      3900
#   1583536    11000
#   1672160      350
#   113564     17995
#   571062      2800
#              ...
#   1598296     3900
#   1215958    26888
#   1046998     7500
#   705743      3500
#   203365      8500
#   Name: price, Length: 5011, dtype: int64,
#   Id
#   1050582    23633
#   1560438     6995
#   883486      1000
#   660683      1600
#   1607047    17000
#              ...
#   873330     14952
#   20601      29500
#   1441896     1200
#   1670174     8795
#   265222      2000
#   Name: price, Length: 1253, dtype: int64],
#  'cadillac': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   700455   0.012725     cadillac   0.000000   0.000038  0.999919        clean
#   1231242  0.081312     cadillac   0.000000   0.000323  0.996680        clean
#   1672349  0.009104     cadillac   0.000009   0.000036  0.999958        clean
#   682700   0.018707     cadillac   0.000009   0.000056  0.999824        clean
#   1338686  0.017183     cadillac   0.000000   0.000070  0.999852        clean
#   ...           ...          ...        ...        ...       ...          ...
#   188014   0.029502     cadillac   0.000029   0.000118  0.999564        clean
#   86556    0.017640     cadillac   0.000000   0.000053  0.999844        clean
#   1123436  0.017693     cadillac   0.000018   0.000053  0.999843        clean
#   578947   0.013237     cadillac   0.000013   0.000040  0.999912        clean
#   513649   0.017588     cadillac   0.000009   0.000053  0.999845        clean
#
#           transmission       size       lat      long
#   Id
#   700455     automatic  full-size  0.000244 -0.000768
#   1231242    automatic  full-size  0.001117 -0.003927
#   1672349    automatic  full-size  0.000163 -0.000368
#   682700     automatic   mid-size  0.000315 -0.001101
#   1338686    automatic  full-size  0.000360 -0.000863
#   ...              ...        ...       ...       ...
#   188014     automatic  full-size  0.000566 -0.001215
#   86556      automatic  full-size  0.000372 -0.000702
#   1123436    automatic  full-size  0.000247 -0.000722
#   578947     automatic  full-size  0.000296 -0.000811
#   513649     automatic  full-size  0.000316 -0.000844
#
#   [5451 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   708653   0.996075     cadillac   0.000496   0.002978  0.064023        clean
#   118611   0.017394     cadillac   0.000000   0.000053  0.999848        clean
#   331948   0.017676     cadillac   0.000000   0.000053  0.999843        clean
#   1164305  0.015921     cadillac   0.000016   0.000048  0.999873        clean
#   1446318  0.021404     cadillac   0.000011   0.000086  0.999770        clean
#   ...           ...          ...        ...        ...       ...          ...
# ...
#   319214      3995
#   1227707    13444
#              ...
#   652513      8995
#   1270504     5500
#   1387828     2300
#   1455670     7500
#   798929       975
#   Name: price, Length: 816, dtype: int64],
#  'saturn': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   826658   0.996882       saturn   0.000497   0.002980  0.066061        clean
#   428981   0.017658       saturn   0.000000   0.000053  0.999844        clean
#   1654693  0.008542       saturn   0.000000   0.000017  0.999963        clean
#   1366873  0.017579       saturn   0.000000   0.000035  0.999845      salvage
#   1393631  0.017649       saturn   0.000000   0.000053  0.999844        clean
#   ...           ...          ...        ...        ...       ...          ...
#   68636    0.009478       saturn   0.000005   0.000019  0.999955        clean
#   53458    0.014741       saturn   0.000000   0.000044  0.999891        clean
#   434382   0.017676       saturn   0.000000   0.000053  0.999843        clean
#   1657322  0.014704       saturn   0.000015   0.000029  0.999892        clean
#   1428911  0.017482       saturn   0.000017   0.000052  0.999847        clean
#
#           transmission         size       lat      long
#   Id
#   826658     automatic     mid-size  0.019871 -0.038174
#   428981     automatic    full-size  0.000286 -0.000811
#   1654693    automatic     mid-size  0.000193 -0.000381
#   1366873       manual     mid-size  0.000404 -0.001026
#   1393631    automatic     mid-size  0.000337 -0.000679
#   ...              ...          ...       ...       ...
#   68636      automatic     mid-size  0.000233 -0.000583
#   53458      automatic     mid-size  0.000314 -0.000542
#   434382     automatic    full-size  0.000348 -0.000742
#   1657322       manual  sub-compact  0.000326 -0.000660
#   1428911    automatic    full-size  0.000330 -0.000780
#
#   [2079 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   101468   0.017676       saturn   0.000000   0.000053  0.999843        clean
#   240116   0.017658       saturn   0.000000   0.000053  0.999843        clean
#   895322   0.009999       saturn   0.000005   0.000030  0.999950        clean
#   1582882  0.020676       saturn   0.000000   0.000062  0.999786        clean
#   1355874  0.016274       saturn   0.000008   0.000033  0.999867        clean
#   ...           ...          ...        ...        ...       ...          ...
#   386196   0.022807       saturn   0.000000   0.000046  0.999739        clean
#   258688   0.051879       saturn   0.000026   0.000155  0.998651        clean
#   1130190  0.014027       saturn   0.000007   0.000042  0.999901        clean
#   887435   0.017649       saturn   0.000000   0.000053  0.999844        clean
#   1396333  0.017640       saturn   0.000000   0.000053  0.999844        clean
#
#           transmission       size       lat      long
#   Id
#   101468     automatic  full-size  0.000357 -0.000851
#   240116     automatic  full-size  0.000434 -0.001083
#   895322     automatic  full-size  0.000215 -0.000428
#   1582882    automatic  full-size  0.000446 -0.000800
#   1355874    automatic   mid-size  0.000362 -0.000594
#   ...              ...        ...       ...       ...
#   386196     automatic   mid-size  0.000390 -0.000887
#   258688     automatic  full-size  0.001069 -0.002130
#   1130190    automatic   mid-size  0.000196 -0.000576
#   887435     automatic  full-size  0.000384 -0.000739
#   1396333       manual  full-size  0.000338 -0.000687
#
#   [520 rows x 10 columns],
#   Id
#   826658     2395
#   428981     3800
#   1654693    1500
#   1366873     500
#   1393631    1000
#              ...
#   68636      1200
#   53458       995
#   434382     2995
#   1657322    1850
#   1428911    2995
#   Name: price, Length: 2079, dtype: int64,
#   Id
#   101468     6499
#   240116     3980
#   895322     1150
#   1582882    7400
#   1355874    2300
#              ...
#   386196     3595
#   258688     6200
#   1130190    2550
#   887435      300
#   1396333     900
#   Name: price, Length: 520, dtype: int64],
#  'datsun': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   497577   0.011379       datsun   0.000006   0.000034  0.999935        clean
#   689948   0.017359       datsun   0.000000   0.000053  0.999849        clean
#   88441    0.045018       datsun   0.000045   0.000136  0.998984        clean
#   1487165  0.017350       datsun   0.000018   0.000053  0.999849        clean
#   634079   0.017394       datsun   0.000000   0.000035  0.999848        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1512325  0.017456       datsun   0.000000   0.000053  0.999847        clean
#   664324   0.017447       datsun   0.000000   0.000053  0.999847        clean
#   896198   0.056111       datsun   0.000000   0.000114  0.998421        clean
#   597816   0.017403       datsun   0.000009   0.000035  0.999848        clean
#   694699   0.027838       datsun   0.000014   0.000085  0.999611        clean
#
#           transmission         size       lat      long
#   Id
#   497577     automatic  sub-compact  0.000201 -0.000658
#   689948        manual    full-size  0.000323 -0.001072
#   88441      automatic     mid-size  0.000976 -0.001740
#   1487165       manual      compact  0.000420 -0.001077
#   634079     automatic      compact  0.000317 -0.001048
#   ...              ...          ...       ...       ...
#   1512325       manual    full-size  0.000362 -0.000749
#   664324        manual    full-size  0.000310 -0.001047
#   896198        manual      compact  0.001220 -0.002438
#   597816        manual     mid-size  0.000372 -0.001071
#   694699        manual      compact  0.000484 -0.001679
#
#   [127 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   74099    0.017456       datsun   0.000009   0.000053  0.999847        clean
#   525988   0.017341       datsun   0.000000   0.000053  0.999849        clean
#   423248   0.015151       datsun   0.000008   0.000046  0.999885        clean
#   1357509  0.011640       datsun   0.000000   0.000035  0.999932      missing
#   1346819  0.011379       datsun   0.000011   0.000034  0.999935        clean
#   507499   0.017438       datsun   0.000000   0.000053  0.999848        clean
#   736280   0.017350       datsun   0.000000   0.000053  0.999849      missing
#   1491189  0.017456       datsun   0.000000   0.000053  0.999847        clean
#   1182402  0.012380       datsun   0.000006   0.000025  0.999923        clean
#   1352067  0.017394       datsun   0.000000   0.000053  0.999848        clean
#   389588   0.017359       datsun   0.000000   0.000053  0.999849   parts only
#   418650   0.017403       datsun   0.000009   0.000053  0.999848        clean
#   1672789  0.017412       datsun   0.000018   0.000053  0.999848        clean
#   1366232  0.017420       datsun   0.000009   0.000035  0.999848        clean
#   1350023  0.017447       datsun   0.000000   0.000053  0.999847        clean
#   661697   0.020569       datsun   0.000010   0.000063  0.999788        clean
#   1202575  0.017403       datsun   0.000009   0.000053  0.999848        clean
#   42328    0.018309       datsun   0.000000   0.000056  0.999832        clean
#   728786   0.096851       datsun   0.000098   0.000294  0.995281        clean
#   723975   0.016912       datsun   0.000009   0.000051  0.999856        clean
#   1146124  0.017456       datsun   0.000000   0.000053  0.999847        clean
#   413787   0.015136       datsun   0.000008   0.000046  0.999885        clean
#   1017006  0.017341       datsun   0.000000   0.000035  0.999849        clean
#   199894   0.014367       datsun   0.000014   0.000043  0.999897        clean
#   611661   0.017420       datsun   0.000000   0.000035  0.999848        clean
#   771675   0.020903       datsun   0.000000   0.000063  0.999781        clean
#   680005   0.017359       datsun   0.000000   0.000053  0.999849        clean
#   1539104  0.017412       datsun   0.000009   0.000035  0.999848        clean
#   491173   0.017447       datsun   0.000009   0.000053  0.999847        clean
#   88833    0.017420       datsun   0.000018   0.000053  0.999848        clean
#   101122   0.017456       datsun   0.000000   0.000053  0.999847        clean
#   1584027  0.017350       datsun   0.000009   0.000053  0.999849        clean
#
#           transmission         size       lat      long
#   Id
#   74099         manual    full-size  0.000267 -0.000784
#   525988        manual    full-size  0.000313 -0.000859
#   423248     automatic    full-size  0.000232 -0.000694
#   1357509       manual    full-size  0.000262 -0.000431
#   1346819       manual    full-size  0.000227 -0.000689
#   507499        manual    full-size  0.000313 -0.000869
#   736280        manual    full-size  0.000296 -0.001025
#   1491189       manual    full-size  0.000418 -0.001058
#   1182402       manual    full-size  0.000162 -0.000501
#   1352067       manual      compact  0.000317 -0.001013
#   389588        manual    full-size  0.000423 -0.001059
#   418650        manual    full-size  0.000542 -0.001316
#   1672789       manual  sub-compact  0.000313 -0.000727
#   1366232       manual     mid-size  0.000383 -0.000985
#   1350023       manual    full-size  0.000317 -0.001014
#   661697        manual     mid-size  0.000348 -0.001224
#   1202575       manual    full-size  0.000402 -0.000954
#   42328         manual    full-size  0.000405 -0.000738
#   728786        manual      compact  0.001677 -0.005798
#   723975     automatic      compact  0.000322 -0.001047
#   1146124       manual    full-size  0.000238 -0.000705
#   413787        manual      compact  0.000367 -0.000770
#   1017006       manual     mid-size  0.000272 -0.000785
#   199894         other    full-size  0.000258 -0.000561
#   611661        manual     mid-size  0.000340 -0.001066
#   771675        manual    full-size  0.000446 -0.000755
#   680005         other    full-size  0.000300 -0.001033
#   1539104       manual     mid-size  0.000309 -0.000938
#   491173        manual      compact  0.000308 -0.000974
#   88833         manual      compact  0.000406 -0.001048
#   101122        manual    full-size  0.000359 -0.001076
#   1584027       manual    full-size  0.000374 -0.000680  ,
#   Id
#   497577      8000
#   689948      3800
#   88441       6550
#   1487165    20000
#   634079      2200
#              ...
#   1512325     1400
#   664324     10500
#   896198      3500
#   597816      1000
#   694699     21000
#   Name: price, Length: 127, dtype: int64,
#   Id
#   74099       5000
#   525988      2500
#   423248      5500
#   1357509     1600
#   1346819     9200
#   507499      3000
#   736280     18500
#   1491189     3500
#   1182402     5600
#   1352067     9000
#   389588       300
#   418650      5500
#   1672789    18500
#   1366232     1800
#   1350023     1600
#   661697      4500
#   1202575     3000
#   42328      10500
#   728786      5000
#   723975      5400
#   1146124     5800
#   413787      7500
#   1017006     1500
#   199894     13995
#   611661      3000
#   771675      9000
#   680005      2800
#   1539104     3900
#   491173      5500
#   88833      23500
#   101122       500
#   1584027    13500
#   Name: price, dtype: int64],
#  'unknown': [             year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   266110   0.017605      unknown   0.000000   0.000053  0.999845        clean
#   512789   0.825306      unknown   0.000834   0.003336  0.562993        clean
#   1647048  0.022369      unknown  -0.000011   0.000091  0.999749        clean
#   1356245  0.016901      unknown  -0.000009   0.000053  0.999857      missing
#   1614782  0.017658      unknown   0.000000   0.000053  0.999844        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1454963  0.015778      unknown   0.000000   0.000047  0.999875        clean
#   1159378  0.017711      unknown   0.000000   0.000053  0.999843      rebuilt
#   363525   0.017728      unknown   0.000000   0.000053  0.999842        clean
#   1000359  0.017711      unknown   0.000009   0.000053  0.999843        clean
#   1353936  0.016707      unknown   0.000008   0.000033  0.999860        clean
#
#           transmission       size       lat      long
#   Id
#   266110     automatic  full-size  0.000378 -0.000775
#   512789     automatic  full-size  0.015202 -0.040813
#   1647048    automatic  full-size  0.000504 -0.001005
#   1356245       manual  full-size  0.000385 -0.000642
#   1614782    automatic  full-size  0.000359 -0.000647
#   ...              ...        ...       ...       ...
#   1454963    automatic  full-size  0.000314 -0.000590
#   1159378    automatic  full-size  0.000228 -0.000707
#   363525     automatic  full-size  0.000273 -0.000861
#   1000359    automatic  full-size  0.000295 -0.000712
#   1353936       manual   mid-size  0.000329 -0.000998
#
#   [29808 rows x 10 columns],
#                year manufacturer  condition  cylinders  odometer title_status  \
#   Id
#   5985     0.998608      unknown   0.001036   0.002073  0.001036        clean
#   1614208  0.025735      unknown   0.000026   0.000103  0.999668        clean
#   357505   0.017640      unknown   0.000000   0.000053  0.999844        clean
#   1629585  0.017737      unknown   0.000018   0.000053  0.999842        clean
#   1415933  0.017588      unknown   0.000009   0.000053  0.999845        clean
#   ...           ...          ...        ...        ...       ...          ...
#   1199932  0.011200      unknown   0.000006   0.000034  0.999937      rebuilt
#   889945   0.008800      unknown   0.000000   0.000018  0.999961        clean
#   1125400  0.017403      unknown   0.000000   0.000053  0.999848        clean
#   78602    0.017552      unknown   0.000000   0.000053  0.999846        clean
#   218675   0.017306      unknown   0.000000   0.000053  0.999850        clean
#
#           transmission       size       lat      long
#   Id
#   5985          manual    compact  0.022013 -0.047866
#   1614208    automatic  full-size  0.000540 -0.000985
#   357505     automatic  full-size  0.000358 -0.000648
#   1629585    automatic  full-size  0.000379 -0.000776
#   1415933       manual  full-size  0.000327 -0.000701
#   ...              ...        ...       ...       ...
#   1199932    automatic    compact  0.000266 -0.000643
#   889945     automatic   mid-size  0.000190 -0.000368
#   1125400    automatic  full-size  0.000269 -0.000769
#   78602      automatic  full-size  0.000350 -0.000757
#   218675        manual  full-size  0.000380 -0.000848
#
#   [7452 rows x 10 columns],
#   Id
#   266110      1700
#   512789     16500
#   1647048      700
#   1356245      800
#   1614782        1
#              ...
#   1454963     1600
#   1159378     6500
#   363525      2900
#   1000359     4995
#   1353936     3995
#   Name: price, Length: 29808, dtype: int64,
#   Id
#   5985       12000
#   1614208    23995
#   357505      1200
#   1629585    41991
#   1415933    22000
#              ...
#   1199932     4900
#   889945       500
#   1125400     2500
#   78602        825
#   218675      1500
#   Name: price, Length: 7452, dtype: int64]}

# %%
# Linear Regression
lin_reg_dec = {}
for j, [X_train, X_test, y_train, y_test] in train_test_dec.items():
    lin_reg = LinearRegression()
    lin_reg_dec[j] = lin_reg.fit(X_train.drop(columns=['manufacturer','title_status','transmission','size']),y_train.drop(columns=['manufacturer','title_status','transmission','size']))

# %%
lin_reg_dec
# Out:
# {'ferrari': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'kia': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'harley-davidson': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'morgan': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'mazda': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'mini': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'volvo': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'subaru': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'buick': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'cadillac': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'land rover': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'bmw': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'dodge': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'chrysler': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'mitsubishi': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'ford': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'porche': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'ram': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'chevrolet': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'infiniti': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'nissan': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'lincoln': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'mercedes-benz': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'jeep': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'gmc': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'volkswagen': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'hyundai': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'alfa-romeo': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'acura': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'aston-martin': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'pontiac': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'jaguar': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'toyota': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'fiat': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'honda': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'lexus': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'mercury': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'audi': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'saturn': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'datsun': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'unknown': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)}

# %%
# Predict
y_pred_dec = {}
for i, [X_train, X_test, y_train, y_test] in train_test_dec.items():
    y_pred_dec[i] = lin_reg_dec[i].predict(train_test_dec[i][1].drop(columns=['manufacturer','title_status','transmission','size']))

# %%
# Check error
error = {}
for i, [X_train, X_test, y_train, y_test] in train_test_dec.items():
    error[i] = mean_squared_error(y_test, y_pred_dec[i])

# %%
error
# Out:
# {'ferrari': 5948267708.054666,
#  'kia': 70198781.32000004,
#  'harley-davidson': 54105650.83417925,
#  'morgan': 1062733517.3517891,
#  'mazda': 35849196.9410954,
#  'mini': 60336863.128620826,
#  'volvo': 74288718.39847171,
#  'subaru': 48395820.63363186,
#  'buick': 52711328.36517765,
#  'cadillac': 192008770.87808326,
#  'land rover': 250539786.05716062,
#  'bmw': 24108471638.012726,
#  'dodge': 106911280825697.9,
#  'chrysler': 36783728748.42921,
#  'mitsubishi': 98840166111.41888,
#  'ford': 92471142277262.02,
#  'porche': 79040291.79787548,
#  'ram': 10884794587.189919,
#  'chevrolet': 161084961393.0348,
#  'infiniti': 100085474.17920615,
#  'nissan': 3474710599438.902,
#  'lincoln': 2148958664.695621,
#  'mercedes-benz': 720912157635184.9,
#  'jeep': 193386289.94866368,
#  'gmc': 108222222521.50026,
#  'volkswagen': 100017452154.09772,
#  'hyundai': 2096626489.9974241,
#  'alfa-romeo': 103717087.24070063,
#  'acura': 62939961.42808076,
#  'aston-martin': 283454374.2847888,
#  'pontiac': 38356339.030160934,
#  'jaguar': 136616870.87737834,
#  'toyota': 1961926309808.1675,
#  'fiat': 18267177.607972827,
#  'honda': 1001845235504.7997,
#  'lexus': 925206053.9824438,
#  'mercury': 1787518371.126381,
#  'audi': 110476223.44588515,
#  'saturn': 1915317626.2755644,
#  'datsun': 41252661.88198952,
#  'unknown': 153456452370.9838}

# %%
X_sub_dec
# Out:
# {'ferrari':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  873208   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  1615923  0.017548      ferrari   0.000000   0.000053  0.999846        clean
#  1245573  0.062069      ferrari   0.000062   0.000373  0.998067        clean
#  657050   0.017443      ferrari   0.000000   0.000053  0.999847        clean
#  682622   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#  1676954  0.997843      ferrari   0.000000   0.002976  0.049595        clean
#  576328   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#  930632   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  336544   0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  684874   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#  622772   0.017522      ferrari   0.000018   0.000070  0.999846      salvage
#  1690604  0.033438      ferrari   0.000034   0.000135  0.999440        clean
#  10603    0.074264      ferrari   0.000074   0.000296  0.997229        clean
#  659788   0.113560      ferrari   0.000056   0.000452  0.993506        clean
#  728801   0.017715      ferrari   0.000000   0.000053  0.999842        clean
#  1482578  0.359490      ferrari   0.000179   0.001072  0.932851        clean
#  495319   0.127177      ferrari   0.000127   0.000507  0.991852        clean
#  369481   0.060495      ferrari   0.000060   0.000181  0.998160        clean
#  683400   0.479265      ferrari   0.000476   0.001903  0.877185        clean
#  1125515  0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  627533   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#  629673   0.070927      ferrari   0.000000   0.000425  0.997472        clean
#  1159787  0.051496      ferrari   0.000051   0.000205  0.998671      rebuilt
#  44047    0.068867      ferrari   0.000034   0.000275  0.997615        clean
#  1014750  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  742494   0.153949      ferrari   0.000153   0.000613  0.988030        clean
#  1015452  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  825776   0.011901      ferrari  -0.000006   0.000047  0.999929      salvage
#  339032   0.073293      ferrari   0.000073   0.000220  0.997299        clean
#  228087   0.017434      ferrari   0.000000   0.000053  0.999848      rebuilt
#  630726   0.045068      ferrari   0.000045   0.000182  0.998980        clean
#  669317   0.074264      ferrari   0.000074   0.000296  0.997229        clean
#
#          transmission         size       lat      long
#  Id
#  873208     automatic    full-size  0.002119 -0.004230
#  1615923    automatic    full-size  0.000377 -0.000691
#  1245573       manual     mid-size  0.000943 -0.003033
#  657050        manual    full-size  0.000339 -0.001065
#  682622        manual      compact  0.001981 -0.006881
#  1676954       manual    full-size  0.017802 -0.039033
#  576328         other  sub-compact  0.002514 -0.006762
#  930632     automatic    full-size  0.002119 -0.004230
#  336544        manual    full-size  0.001957 -0.006105
#  684874     automatic    full-size  0.001249 -0.004308
#  622772        manual    full-size  0.000330 -0.001074
#  1690604       manual      compact  0.000602 -0.001329
#  10603      automatic    full-size  0.001249 -0.004308
#  659788     automatic     mid-size  0.002013 -0.006819
#  728801     automatic    full-size  0.000299 -0.001039
#  1482578        other    full-size  0.008711 -0.021882
#  495319     automatic    full-size  0.002118 -0.007096
#  369481     automatic    full-size  0.001490 -0.003723
#  683400     automatic    full-size  0.007997 -0.027983
#  1125515    automatic    full-size  0.001957 -0.006105
#  627533        manual    full-size  0.001243 -0.004252
#  629673     automatic    full-size  0.001200 -0.004154
#  1159787    automatic    full-size  0.000668 -0.002054
#  44047      automatic    full-size  0.001675 -0.004209
#  1014750    automatic      compact  0.000796 -0.001535
#  742494     automatic     mid-size  0.002803 -0.009340
#  1015452    automatic    full-size  0.000792 -0.001534
#  825776     automatic    full-size  0.000244 -0.000447
#  339032     automatic    full-size  0.001797 -0.004488
#  228087        manual    full-size  0.000267 -0.000799
#  630726        manual    full-size  0.000774 -0.002688
#  669317     automatic    full-size  0.001249 -0.004308  ,
#  'kia':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  144337   0.011551          kia   0.000011   0.000034  0.999933        clean
#  1158202  0.037935          kia   0.000000   0.000113  0.999279      rebuilt
#  539918   0.022257          kia   0.000011   0.000066  0.999752        clean
#  1223914  0.017662          kia   0.000000   0.000053  0.999844        clean
#  1532059  0.015848          kia   0.000016   0.000032  0.999874        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1106624  0.019163          kia   0.000000   0.000057  0.999816        clean
#  1219609  0.022623          kia   0.000022   0.000045  0.999743        clean
#  1340428  0.057504          kia   0.000057   0.000114  0.998339        clean
#  1263028  0.016756          kia   0.000017   0.000050  0.999859        clean
#  720330   0.022801          kia   0.000000   0.000068  0.999739        clean
#
#          transmission       size       lat      long
#  Id
#  144337     automatic   mid-size  0.000193 -0.000496
#  1158202    automatic  full-size  0.000485 -0.001517
#  539918     automatic  full-size  0.000398 -0.001039
#  1223914    automatic  full-size  0.000297 -0.000865
#  1532059    automatic    compact  0.000329 -0.000685
#  ...              ...        ...       ...       ...
#  1106624    automatic  full-size  0.000283 -0.000784
#  1219609    automatic    compact  0.000294 -0.001104
#  1340428    automatic    compact  0.001059 -0.003241
#  1263028    automatic  full-size  0.000248 -0.000796
#  720330     automatic  full-size  0.000384 -0.001322
#
#  [3629 rows x 10 columns],
#  'harley-davidson':              year     manufacturer  condition  cylinders  odometer  \
#  Id
#  1295554  0.017513  harley-davidson   0.000018   0.000053  0.999846
#  442879   0.448546  harley-davidson   0.000447   0.001340  0.893519
#  181606   0.017548  harley-davidson   0.000000   0.000053  0.999846
#  1010170  0.152648  harley-davidson   0.000152   0.000456  0.988259
#  310213   0.201971  harley-davidson   0.000101   0.000605  0.979302
#  ...           ...              ...        ...        ...       ...
#  782715   0.280042  harley-davidson   0.000278   0.000835  0.959906
#  1679923  0.017618  harley-davidson   0.000000   0.000035  0.999845
#  1604512  0.009118  harley-davidson   0.000005   0.000036  0.999958
#  494891   0.017592  harley-davidson   0.000009   0.000070  0.999845
#  1615057  0.017618  harley-davidson   0.000000   0.000053  0.999845
#
#          title_status transmission       size       lat      long
#  Id
#  1295554         lien       manual  full-size  0.000284 -0.000844
#  442879         clean       manual  full-size  0.009187 -0.018545
#  181606         clean       manual  full-size  0.000310 -0.000937
#  1010170        clean       manual  full-size  0.002562 -0.006000
#  310213         clean       manual  full-size  0.004760 -0.012334
#  ...              ...          ...        ...       ...       ...
#  782715         clean       manual  full-size  0.005688 -0.011120
#  1679923        clean    automatic    compact  0.000306 -0.000680
#  1604512        clean    automatic  full-size  0.000200 -0.000345
#  494891       rebuilt    automatic  full-size  0.000282 -0.000974
#  1615057        clean    automatic  full-size  0.000356 -0.000650
#
#  [138 rows x 10 columns],
#  'morgan':             year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  935779  0.017689       morgan   0.000018   0.000053  0.999843        clean
#  842649  0.989985       morgan   0.000984   0.002951  0.129834        clean
#
#         transmission       size       lat      long
#  Id
#  935779        other  full-size  0.000367 -0.000627
#  842649       manual  full-size  0.019673 -0.051725  ,
#  'mazda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  830219   0.065874        mazda   0.000000   0.000196  0.997821        clean
#  314758   0.088681        mazda   0.000088   0.000176  0.996052         lien
#  999201   0.017504        mazda  -0.000009   0.000053  0.999846        clean
#  421641   0.357951        mazda   0.000355   0.000710  0.933298        clean
#  1101173  0.044927        mazda   0.000045   0.000089  0.998988        clean
#  ...           ...          ...        ...        ...       ...          ...
#  317870   0.052952        mazda   0.000000   0.000158  0.998591        clean
#  860527   0.011758        mazda   0.000006   0.000035  0.999931        clean
#  287062   0.017609        mazda   0.000018   0.000053  0.999844        clean
#  1410661  0.021987        mazda   0.000000   0.000066  0.999758        clean
#  815566   0.017636        mazda   0.000000   0.000053  0.999844        clean
#
#          transmission       size       lat      long
#  Id
#  830219     automatic  full-size  0.001251 -0.003420
#  314758     automatic    compact  0.001922 -0.003498
#  999201        manual  full-size  0.000290 -0.000704
#  421641     automatic   mid-size  0.010853 -0.026590
#  1101173    automatic    compact  0.000675 -0.001820
#  ...              ...        ...       ...       ...
#  317870     automatic  full-size  0.001292 -0.003227
#  860527        manual   mid-size  0.000233 -0.000619
#  287062     automatic  full-size  0.000296 -0.001003
#  1410661    automatic  full-size  0.000409 -0.000870
#  815566     automatic  full-size  0.000358 -0.000664
#
#  [3462 rows x 10 columns],
#  'mini':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1565975  0.017583         mini   0.000009   0.000035  0.999845        clean
#  711505   0.031548         mini   0.000000   0.000063  0.999500        clean
#  231273   0.017662         mini   0.000000   0.000053  0.999844        clean
#  1160215  0.038242         mini   0.000038   0.000114  0.999267        clean
#  1529924  0.012609         mini   0.000006   0.000025  0.999920        clean
#  ...           ...          ...        ...        ...       ...          ...
#  691349   0.021114         mini   0.000021   0.000063  0.999776        clean
#  584522   0.017671         mini   0.000000   0.000053  0.999843        clean
#  1530742  0.042973         mini   0.000043   0.000128  0.999074        clean
#  1452433  0.024708         mini   0.000025   0.000049  0.999694        clean
#  109704   0.029453         mini   0.000029   0.000088  0.999565        clean
#
#          transmission         size       lat      long
#  Id
#  1565975       manual      compact  0.000365 -0.000822
#  711505     automatic      compact  0.000553 -0.001894
#  231273     automatic    full-size  0.000273 -0.000819
#  1160215    automatic    full-size  0.000531 -0.001562
#  1529924    automatic    full-size  0.000250 -0.000542
#  ...              ...          ...       ...       ...
#  691349     automatic    full-size  0.000385 -0.001256
#  584522        manual    full-size  0.000387 -0.001082
#  1530742       manual  sub-compact  0.000890 -0.001842
#  1452433       manual      compact  0.000500 -0.000921
#  109704     automatic    full-size  0.000446 -0.001302
#
#  [1040 rows x 10 columns],
#  'volvo':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  305757   0.017662        volvo   0.000018   0.000044  0.999844        clean
#  926352   0.010121        volvo   0.000005   0.000025  0.999949        clean
#  671502   0.016274        volvo   0.000008   0.000041  0.999867        clean
#  431731   0.018599        volvo   0.000009   0.000056  0.999827        clean
#  843681   0.007766        volvo   0.000004   0.000023  0.999970        clean
#  ...           ...          ...        ...        ...       ...          ...
#  118994   0.017583        volvo   0.000000   0.000053  0.999845        clean
#  1698378  0.025447        volvo   0.000025   0.000076  0.999676      rebuilt
#  1401417  0.012258        volvo   0.000006   0.000031  0.999925        clean
#  761453   0.018804        volvo   0.000019   0.000047  0.999823        clean
#  756304   0.017680        volvo   0.000000   0.000053  0.999843        clean
#
#          transmission         size       lat      long
#  Id
#  305757     automatic  sub-compact  0.000354 -0.000678
#  926352     automatic     mid-size  0.000218 -0.000429
#  671502     automatic     mid-size  0.000314 -0.000987
#  431731     automatic    full-size  0.000278 -0.000835
#  843681     automatic    full-size  0.000154 -0.000412
#  ...              ...          ...       ...       ...
#  118994     automatic    full-size  0.000267 -0.000740
#  1698378    automatic     mid-size  0.000453 -0.001016
#  1401417       manual     mid-size  0.000234 -0.000483
#  761453     automatic    full-size  0.000395 -0.000666
#  756304     automatic    full-size  0.000374 -0.000627
#
#  [1675 rows x 10 columns],
#  'subaru':             year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  764904  0.017601       subaru   0.000000   0.000053  0.999845        clean
#  330867  0.017513       subaru   0.000000   0.000053  0.999846        clean
#  608763  0.007673       subaru   0.000000   0.000015  0.999970        clean
#  769396  0.024563       subaru   0.000024   0.000049  0.999698        clean
#  938823  0.017610       subaru   0.000009   0.000035  0.999845        clean
#  ...          ...          ...        ...        ...       ...          ...
#  704741  0.058687       subaru   0.000000   0.000175  0.998270        clean
#  730006  0.022093       subaru   0.000022   0.000044  0.999755        clean
#  963343  0.011434       subaru   0.000000   0.000034  0.999934        clean
#  829242  0.011216       subaru   0.000000   0.000033  0.999937        clean
#  63033   0.017539       subaru  -0.000009   0.000035  0.999846        clean
#
#         transmission       size       lat      long
#  Id
#  764904    automatic  full-size  0.000372 -0.000633
#  330867    automatic  full-size  0.000513 -0.001182
#  608763    automatic   mid-size  0.000135 -0.000464
#  769396    automatic  full-size  0.000513 -0.000886
#  938823    automatic   mid-size  0.000363 -0.000632
#  ...             ...        ...       ...       ...
#  704741       manual  full-size  0.001124 -0.003534
#  730006       manual    compact  0.000428 -0.001330
#  963343    automatic  full-size  0.000266 -0.000524
#  829242        other  full-size  0.000224 -0.000586
#  63033     automatic    compact  0.000364 -0.000800
#
#  [4341 rows x 10 columns],
#  'buick':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1211117  0.011939        buick   0.000000   0.000036  0.999928        clean
#  947857   0.016358        buick   0.000000   0.000049  0.999866        clean
#  1113129  0.021282        buick   0.000011   0.000064  0.999773        clean
#  170062   0.019698        buick   0.000020   0.000059  0.999806        clean
#  1488852  0.017680        buick   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  511377   0.013507        buick   0.000013   0.000040  0.999909        clean
#  1289744  0.017618        buick   0.000000   0.000053  0.999844        clean
#  923478   0.017548        buick   0.000018   0.000053  0.999846        clean
#  121897   0.019108        buick   0.000000   0.000057  0.999817        clean
#  205239   0.017557        buick   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long
#  Id
#  1211117    automatic  full-size  0.000284 -0.000664
#  947857     automatic  full-size  0.000339 -0.000590
#  1113129    automatic  full-size  0.000292 -0.000878
#  170062     automatic  full-size  0.000400 -0.000716
#  1488852    automatic  full-size  0.000406 -0.001047
#  ...              ...        ...       ...       ...
#  511377     automatic  full-size  0.000238 -0.000657
#  1289744    automatic  full-size  0.000258 -0.000865
#  923478     automatic  full-size  0.000380 -0.000725
#  121897     automatic  full-size  0.000352 -0.001078
#  205239     automatic  full-size  0.000412 -0.000850
#
#  [3399 rows x 10 columns],
#  'cadillac':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  507587   0.071247     cadillac   0.000000   0.000212  0.997452        clean
#  2265     0.998960     cadillac   0.001007   0.003021  0.000000        clean
#  142638   0.038702     cadillac   0.000038   0.000077  0.999249        clean
#  1377147  0.017680     cadillac   0.000000   0.000053  0.999843        clean
#  1193213  0.020250     cadillac   0.000010   0.000081  0.999795      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  898890   0.012954     cadillac   0.000006   0.000039  0.999916         lien
#  501516   0.028257     cadillac   0.000000   0.000084  0.999600        clean
#  415087   0.066391     cadillac   0.000066   0.000264  0.997779        clean
#  1527196  0.017548     cadillac   0.000000   0.000053  0.999846        clean
#  1519119  0.017337     cadillac   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  507587     automatic  full-size  0.001257 -0.003451
#  2265       automatic  full-size  0.021250 -0.040215
#  142638     automatic   mid-size  0.000589 -0.001696
#  1377147    automatic  full-size  0.000383 -0.000628
#  1193213    automatic  full-size  0.000274 -0.000832
#  ...              ...        ...       ...       ...
#  898890     automatic  full-size  0.000289 -0.000554
#  501516     automatic   mid-size  0.000611 -0.000989
#  415087     automatic  full-size  0.002018 -0.004945
#  1527196    automatic  full-size  0.000349 -0.000757
#  1519119    automatic  full-size  0.000366 -0.000747
#
#  [3682 rows x 10 columns],
#  'bmw':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  629957   0.088878          bmw   0.000088   0.000176  0.996028        clean
#  370879   0.090656          bmw   0.000090   0.000270  0.995864        clean
#  670648   0.057473          bmw   0.000000   0.000114  0.998340        clean
#  1170904  0.019386          bmw   0.000000   0.000058  0.999812        clean
#  627499   0.020465          bmw   0.000010   0.000082  0.999790        clean
#  ...           ...          ...        ...        ...       ...          ...
#  762018   0.013881          bmw   0.000007   0.000042  0.999903        clean
#  412066   0.036764          bmw   0.000037   0.000110  0.999323        clean
#  266383   0.055885          bmw   0.000055   0.000111  0.998433      rebuilt
#  827094   0.025142          bmw   0.000025   0.000050  0.999683        clean
#  688556   0.009852          bmw   0.000005   0.000039  0.999951        clean
#
#          transmission       size       lat      long
#  Id
#  629957     automatic    compact  0.001506 -0.005216
#  370879     automatic  full-size  0.002213 -0.005539
#  670648     automatic    compact  0.001105 -0.003458
#  1170904    automatic  full-size  0.000263 -0.000795
#  627499     automatic  full-size  0.000376 -0.001240
#  ...              ...        ...       ...       ...
#  762018        manual   mid-size  0.000293 -0.000502
#  412066     automatic    compact  0.000697 -0.001548
#  266383     automatic   mid-size  0.001295 -0.002554
#  827094     automatic    compact  0.000500 -0.000956
#  688556     automatic  full-size  0.000185 -0.000596
#
#  [6302 rows x 10 columns],
#  'mitsubishi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  527762   0.017689   mitsubishi   0.000018   0.000053  0.999843        clean
#  1247933  0.017645   mitsubishi   0.000000   0.000053  0.999844      salvage
#  1675559  0.017594   mitsubishi   0.000018   0.000053  0.999845        clean
#  724442   0.023753   mitsubishi   0.000024   0.000071  0.999717        clean
#  1092376  0.017627   mitsubishi   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  957482   0.045476   mitsubishi   0.000045   0.000136  0.998964        clean
#  210130   0.030526   mitsubishi   0.000000   0.000091  0.999533        clean
#  1500155  0.074420   mitsubishi   0.000000   0.000221  0.997216        clean
#  658852   0.017513   mitsubishi   0.000000   0.000053  0.999846        clean
#  1304023  0.017522   mitsubishi   0.000000   0.000053  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  527762     automatic  full-size  0.000312 -0.000857
#  1247933    automatic  full-size  0.000230 -0.000861
#  1675559    automatic   mid-size  0.000311 -0.000707
#  724442     automatic  full-size  0.000462 -0.001455
#  1092376    automatic  full-size  0.000313 -0.000780
#  ...              ...        ...       ...       ...
#  957482        manual  full-size  0.000938 -0.001649
#  210130         other  full-size  0.000454 -0.001365
#  1500155    automatic  full-size  0.001705 -0.004393
#  658852        manual  full-size  0.000312 -0.001060
#  1304023    automatic  full-size  0.000288 -0.000736
#
#  [1678 rows x 10 columns],
#  'dodge':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  296855   0.017610        dodge   0.000000   0.000053  0.999845        clean
#  1239902  0.014573        dodge   0.000000   0.000029  0.999894        clean
#  1305765  0.017583        dodge   0.000000   0.000052  0.999845        clean
#  1234416  0.017706        dodge   0.000000   0.000053  0.999843        clean
#  491202   0.011105        dodge   0.000006   0.000056  0.999938        clean
#  ...           ...          ...        ...        ...       ...          ...
#  492086   0.013964        dodge   0.000007   0.000042  0.999902        clean
#  649565   0.016274        dodge   0.000016   0.000032  0.999867        clean
#  909774   0.024101        dodge   0.000000   0.000096  0.999709        clean
#  585898   0.017267        dodge   0.000000   0.000053  0.999850        clean
#  662527   0.017406        dodge  -0.000009   0.000052  0.999848      salvage
#
#          transmission       size       lat      long
#  Id
#  296855     automatic  full-size  0.000361 -0.000708
#  1239902    automatic    compact  0.000201 -0.000706
#  1305765    automatic  full-size  0.000286 -0.000732
#  1234416    automatic  full-size  0.000261 -0.000839
#  491202     automatic  full-size  0.000190 -0.000618
#  ...              ...        ...       ...       ...
#  492086     automatic  full-size  0.000232 -0.000778
#  649565     automatic   mid-size  0.000304 -0.000978
#  909774     automatic  full-size  0.000507 -0.001034
#  585898        manual   mid-size  0.000405 -0.001087
#  662527     automatic   mid-size  0.000284 -0.001018
#
#  [11237 rows x 10 columns],
#  'chrysler':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  16156    0.012402     chrysler   0.000006   0.000037  0.999923        clean
#  1442002  0.017601     chrysler   0.000000   0.000053  0.999845        clean
#  1636834  0.017610     chrysler   0.000018   0.000053  0.999845        clean
#  290057   0.016070     chrysler   0.000008   0.000048  0.999871        clean
#  1496219  0.068258     chrysler   0.000000   0.000203  0.997658        clean
#  ...           ...          ...        ...        ...       ...          ...
#  138193   0.012537     chrysler   0.000012   0.000025  0.999921        clean
#  230387   0.017610     chrysler   0.000000   0.000053  0.999845        clean
#  1110817  0.015437     chrysler   0.000015   0.000046  0.999881        clean
#  885711   0.018253     chrysler   0.000009   0.000054  0.999833        clean
#  373566   0.017423     chrysler   0.000017   0.000052  0.999848        clean
#
#          transmission       size       lat      long
#  Id
#  16156      automatic  full-size  0.000226 -0.000550
#  1442002    automatic  full-size  0.000366 -0.000769
#  1636834    automatic   mid-size  0.000383 -0.000782
#  290057     automatic  full-size  0.000285 -0.000630
#  1496219    automatic  full-size  0.001565 -0.004033
#  ...              ...        ...       ...       ...
#  138193     automatic    compact  0.000209 -0.000698
#  230387     automatic  full-size  0.000266 -0.000790
#  1110817    automatic  full-size  0.000228 -0.000637
#  885711     automatic  full-size  0.000391 -0.000759
#  373566     automatic   mid-size  0.000352 -0.000682
#
#  [4542 rows x 10 columns],
#  'land rover':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  208608   0.034637   land rover   0.000034   0.000138  0.999397        clean
#  608308   0.017645   land rover   0.000000   0.000053  0.999844        clean
#  1681805  0.019323   land rover   0.000019   0.000077  0.999813        clean
#  1538357  0.017697   land rover   0.000018   0.000053  0.999843        clean
#  1199177  0.017539   land rover   0.000000   0.000053  0.999846        clean
#  ...           ...          ...        ...        ...       ...          ...
#  369422   0.011005   land rover   0.000005   0.000033  0.999939        clean
#  398722   0.017610   land rover   0.000018   0.000070  0.999845        clean
#  667988   0.017225   land rover   0.000017   0.000069  0.999851        clean
#  949042   0.019610   land rover   0.000000   0.000059  0.999807        clean
#  1367703  0.008951   land rover   0.000000   0.000036  0.999960        clean
#
#          transmission       size       lat      long
#  Id
#  208608     automatic   mid-size  0.000845 -0.002115
#  608308     automatic  full-size  0.000323 -0.001069
#  1681805    automatic  full-size  0.000329 -0.000749
#  1538357    automatic  full-size  0.000308 -0.000936
#  1199177       manual  full-size  0.000241 -0.000726
#  ...              ...        ...       ...       ...
#  369422     automatic  full-size  0.000270 -0.000676
#  398722     automatic  full-size  0.000295 -0.000762
#  667988     automatic  full-size  0.000320 -0.001046
#  949042     automatic  full-size  0.000407 -0.000712
#  1367703    automatic  full-size  0.000195 -0.000521
#
#  [796 rows x 10 columns],
#  'ford':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  974298   0.012991         ford   0.000006   0.000052  0.999915        clean
#  1473203  0.016925         ford   0.000000   0.000053  0.999856      missing
#  972509   0.016491         ford   0.000016   0.000066  0.999864        clean
#  656907   0.116697         ford   0.000000   0.000347  0.993140        clean
#  525619   0.017645         ford   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  24233    0.012388         ford   0.000012   0.000037  0.999923        clean
#  1184470  0.017715         ford   0.000018   0.000053  0.999843        clean
#  1533790  0.007103         ford   0.000004   0.000028  0.999975        clean
#  1026234  0.017610         ford   0.000000   0.000053  0.999845        clean
#  1541257  0.019554         ford   0.000010   0.000078  0.999808        clean
#
#          transmission         size       lat      long
#  Id
#  974298     automatic    full-size  0.000309 -0.000585
#  1473203       manual    full-size  0.000430 -0.001078
#  972509     automatic    full-size  0.000361 -0.000759
#  656907     automatic  sub-compact  0.002186 -0.007076
#  525619        manual    full-size  0.000312 -0.000857
#  ...              ...          ...       ...       ...
#  24233      automatic    full-size  0.000219 -0.000498
#  1184470    automatic    full-size  0.000262 -0.000724
#  1533790    automatic    full-size  0.000116 -0.000379
#  1026234    automatic    full-size  0.000268 -0.000788
#  1541257    automatic    full-size  0.000341 -0.001036
#
#  [42919 rows x 10 columns],
#  'porche':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  636319   0.017609       porche   0.000009   0.000053  0.999844        clean
#  230466   0.007426       porche   0.000004   0.000022  0.999972        clean
#  1243223  0.015421       porche   0.000000   0.000046  0.999881        clean
#  1257255  0.017601       porche   0.000018   0.000070  0.999845        clean
#  270807   0.060100       porche   0.000060   0.000119  0.998189        clean
#  649219   0.015964       porche   0.000016   0.000048  0.999872        clean
#  998349   0.017636       porche   0.000000   0.000053  0.999844        clean
#  118563   0.014430       porche   0.000000   0.000043  0.999896        clean
#  1673513  0.017434       porche   0.000018   0.000035  0.999848        clean
#  460826   0.051582       porche   0.000051   0.000154  0.998666        clean
#  1122102  0.016593       porche   0.000017   0.000050  0.999862        clean
#  1283713  0.027125       porche   0.000027   0.000081  0.999631        clean
#  1427123  0.014430       porche   0.000000   0.000043  0.999896        clean
#  181352   0.017460       porche   0.000000   0.000053  0.999847        clean
#  49033    0.028328       porche   0.000028   0.000085  0.999598        clean
#  17490    0.009192       porche   0.000005   0.000028  0.999958        clean
#  1673500  0.017434       porche   0.000018   0.000035  0.999848        clean
#  735070   0.017662       porche   0.000000   0.000053  0.999843        clean
#  248741   0.021174       porche   0.000021   0.000084  0.999775        clean
#  374129   0.017557       porche   0.000000   0.000053  0.999845        clean
#  1610906  0.096163       porche   0.000096   0.000287  0.995357        clean
#
#          transmission       size       lat      long
#  Id
#  636319     automatic  full-size  0.000328 -0.001058
#  230466     automatic  full-size  0.000159 -0.000292
#  1243223    automatic  full-size  0.000244 -0.000818
#  1257255    automatic  full-size  0.000265 -0.000838
#  270807     automatic  full-size  0.001066 -0.002460
#  649219     automatic  full-size  0.000294 -0.000953
#  998349     automatic  full-size  0.000288 -0.000702
#  118563     automatic  full-size  0.000300 -0.000634
#  1673513       manual    compact  0.000311 -0.000724
#  460826     automatic    compact  0.001064 -0.002094
#  1122102    automatic  full-size  0.000237 -0.000673
#  1283713    automatic  full-size  0.000403 -0.001292
#  1427123    automatic  full-size  0.000300 -0.000634
#  181352        manual  full-size  0.000332 -0.000737
#  49033      automatic  full-size  0.000579 -0.001050
#  17490      automatic  full-size  0.000186 -0.000340
#  1673500       manual    compact  0.000311 -0.000724
#  735070     automatic  full-size  0.000298 -0.001030
#  248741     automatic   mid-size  0.000429 -0.000862
#  374129     automatic  full-size  0.000310 -0.000937
#  1610906       manual  full-size  0.001950 -0.003514  ,
#  'ram':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  634975   0.019917          ram   0.000020   0.000059  0.999801        clean
#  879412   0.017662          ram   0.000018   0.000070  0.999844        clean
#  1013552  0.017539          ram   0.000000   0.000053  0.999846        clean
#  1274584  0.037973          ram   0.000038   0.000113  0.999277        clean
#  1464669  0.009048          ram   0.000005   0.000027  0.999959        clean
#  ...           ...          ...        ...        ...       ...          ...
#  54116    0.201711          ram   0.000200   0.000600  0.979356        clean
#  1623008  0.014082          ram   0.000000   0.000042  0.999901        clean
#  1456520  0.086064          ram   0.000000   0.000256  0.996283        clean
#  1574376  0.020896          ram   0.000000   0.000062  0.999781        clean
#  1216327  0.994072          ram   0.000000   0.002978  0.089829        clean
#
#          transmission       size       lat      long
#  Id
#  634975     automatic  full-size  0.000359 -0.001180
#  879412     automatic  full-size  0.000378 -0.000734
#  1013552    automatic  full-size  0.000348 -0.000664
#  1274584    automatic  full-size  0.000551 -0.001863
#  1464669    automatic  full-size  0.000183 -0.000335
#  ...              ...        ...       ...       ...
#  54116      automatic  full-size  0.004911 -0.012269
#  1623008    automatic  full-size  0.000302 -0.000618
#  1456520    automatic  full-size  0.001727 -0.003170
#  1574376    automatic  full-size  0.000448 -0.000789
#  1216327       manual  full-size  0.023254 -0.056590
#
#  [8326 rows x 10 columns],
#  'chevrolet':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1051884  0.017451    chevrolet   0.000000   0.000053  0.999847        clean
#  1255387  0.017592    chevrolet   0.000000   0.000070  0.999845        clean
#  1388526  0.008329    chevrolet   0.000008   0.000033  0.999965        clean
#  746176   0.023666    chevrolet   0.000012   0.000096  0.999719        clean
#  1088447  0.027565    chevrolet   0.000000   0.000082  0.999619      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  482200   0.106388    chevrolet   0.000108   0.000431  0.994304        clean
#  765689   0.013254    chevrolet   0.000013   0.000040  0.999912        clean
#  1302371  0.008391    chevrolet   0.000004   0.000034  0.999965        clean
#  1700280  0.019752    chevrolet   0.000000   0.000078  0.999805        clean
#  53108    0.020658    chevrolet   0.000000   0.000082  0.999786        clean
#
#          transmission       size       lat      long
#  Id
#  1051884    automatic  full-size  0.000337 -0.000824
#  1255387    automatic  full-size  0.000264 -0.000862
#  1388526    automatic  full-size  0.000153 -0.000318
#  746176     automatic  full-size  0.000409 -0.001425
#  1088447    automatic  full-size  0.000495 -0.001187
#  ...              ...        ...       ...       ...
#  482200     automatic  full-size  0.001886 -0.006167
#  765689     automatic  full-size  0.000275 -0.000464
#  1302371    automatic  full-size  0.000137 -0.000352
#  1700280    automatic  full-size  0.000348 -0.000808
#  53108      automatic  full-size  0.000352 -0.000799
#
#  [38596 rows x 10 columns],
#  'infiniti':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  397885   0.014961     infiniti   0.000007   0.000045  0.999888        clean
#  774955   0.014998     infiniti   0.000015   0.000045  0.999887        clean
#  275304   0.012065     infiniti   0.000006   0.000036  0.999927        clean
#  778374   0.014341     infiniti   0.000007   0.000043  0.999897        clean
#  1406118  0.017601     infiniti   0.000000   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1596362  0.122574     infiniti   0.000122   0.000365  0.992446      salvage
#  886734   0.017618     infiniti   0.000018   0.000053  0.999844        clean
#  368452   0.017860     infiniti   0.000009   0.000053  0.999840        clean
#  155826   0.014850     infiniti   0.000015   0.000044  0.999889        clean
#  290069   0.013304     infiniti   0.000013   0.000040  0.999911        clean
#
#          transmission       size       lat      long
#  Id
#  397885     automatic  full-size  0.000251 -0.000645
#  774955     automatic  full-size  0.000314 -0.000534
#  275304     automatic  full-size  0.000232 -0.000493
#  778374     automatic  full-size  0.000298 -0.000508
#  1406118    automatic  full-size  0.000329 -0.000680
#  ...              ...        ...       ...       ...
#  1596362    automatic  full-size  0.002467 -0.004498
#  886734     automatic  full-size  0.000381 -0.000738
#  368452     automatic  full-size  0.000443 -0.001059
#  155826        manual    compact  0.000275 -0.000709
#  290069     automatic  full-size  0.000238 -0.000523
#
#  [1850 rows x 10 columns],
#  'nissan':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1233191  0.069281       nissan   0.000069   0.000138  0.997591        clean
#  1253597  0.036757       nissan   0.000018   0.000110  0.999322        clean
#  267134   0.025622       nissan   0.000013   0.000051  0.999671        clean
#  1340703  0.012807       nissan   0.000006   0.000026  0.999918        clean
#  927955   0.017610       nissan   0.000009   0.000035  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  331828   0.014626       nissan   0.000015   0.000044  0.999893        clean
#  126564   0.018580       nissan   0.000000   0.000056  0.999827        clean
#  689765   0.035923       nissan   0.000036   0.000071  0.999352        clean
#  1071667  0.017662       nissan   0.000000   0.000053  0.999844        clean
#  452074   0.013664       nissan   0.000000   0.000041  0.999906        clean
#
#          transmission       size       lat      long
#  Id
#  1233191    automatic    compact  0.001022 -0.003286
#  1253597    automatic  full-size  0.000579 -0.001941
#  267134     automatic    compact  0.000510 -0.001055
#  1340703    automatic    compact  0.000262 -0.000717
#  927955     automatic    compact  0.000374 -0.000732
#  ...              ...        ...       ...       ...
#  331828     automatic  full-size  0.000299 -0.000671
#  126564        manual  full-size  0.000363 -0.000801
#  689765     automatic  full-size  0.000667 -0.002154
#  1071667    automatic  full-size  0.000318 -0.000735
#  452074         other  full-size  0.000283 -0.000556
#
#  [11648 rows x 10 columns],
#  'mercedes-benz':              year   manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1132407  0.015139  mercedes-benz   0.000000   0.000045  0.999885        clean
#  424855   0.024005  mercedes-benz   0.000000   0.000072  0.999711        clean
#  1441207  0.058306  mercedes-benz   0.000000   0.000174  0.998295        clean
#  512103   0.016449  mercedes-benz   0.000016   0.000049  0.999864        clean
#  1719335  0.015628  mercedes-benz   0.000008   0.000063  0.999878        clean
#  ...           ...            ...        ...        ...       ...          ...
#  503575   0.017648  mercedes-benz   0.000000   0.000035  0.999844        clean
#  651785   0.017574  mercedes-benz   0.000009   0.000053  0.999845        clean
#  768324   0.022749  mercedes-benz   0.000000   0.000068  0.999741        clean
#  136234   0.018191  mercedes-benz   0.000018   0.000055  0.999834        clean
#  1219869  0.208073  mercedes-benz   0.000000   0.000619  0.978057        clean
#
#          transmission       size       lat      long
#  Id
#  1132407    automatic  full-size  0.000211 -0.000622
#  424855     automatic  full-size  0.000362 -0.001075
#  1441207    automatic  full-size  0.001209 -0.002546
#  512103     automatic    compact  0.000292 -0.000800
#  1719335    automatic  full-size  0.000274 -0.000605
#  ...              ...        ...       ...       ...
#  503575     automatic    compact  0.000384 -0.000624
#  651785     automatic  full-size  0.000367 -0.001090
#  768324     automatic  full-size  0.000480 -0.000802
#  136234     automatic  full-size  0.000320 -0.000969
#  1219869    automatic  full-size  0.002703 -0.010125
#
#  [4623 rows x 10 columns],
#  'lincoln':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  666678   0.040253      lincoln   0.000041   0.000163  0.999186        clean
#  1452091  0.017715      lincoln   0.000018   0.000035  0.999843        clean
#  1048858  0.017592      lincoln   0.000000   0.000053  0.999845        clean
#  1093648  0.016906      lincoln   0.000017   0.000067  0.999857        clean
#  393701   0.015525      lincoln   0.000015   0.000062  0.999879        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1296390  0.008052      lincoln   0.000000   0.000032  0.999968         lien
#  1681663  0.023886      lincoln   0.000012   0.000095  0.999714        clean
#  899443   0.017671      lincoln   0.000018   0.000053  0.999844        clean
#  1195349  0.012738      lincoln   0.000013   0.000051  0.999919        clean
#  1431385  0.040488      lincoln   0.000040   0.000121  0.999178        clean
#
#          transmission       size       lat      long
#  Id
#  666678     automatic  full-size  0.000692 -0.002386
#  1452091    automatic    compact  0.000353 -0.000650
#  1048858    automatic  full-size  0.000341 -0.000795
#  1093648    automatic  full-size  0.000295 -0.000716
#  393701     automatic  full-size  0.000236 -0.000679
#  ...              ...        ...       ...       ...
#  1296390    automatic  full-size  0.000131 -0.000380
#  1681663    automatic  full-size  0.000407 -0.000927
#  899443     automatic   mid-size  0.000376 -0.000725
#  1195349    automatic  full-size  0.000178 -0.000524
#  1431385    automatic  full-size  0.000852 -0.001766
#
#  [1831 rows x 10 columns],
#  'jeep':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  684464   0.015735         jeep   0.000000   0.000047  0.999876        clean
#  1678487  0.013805         jeep   0.000007   0.000028  0.999905        clean
#  1564129  0.017601         jeep   0.000000   0.000053  0.999845        clean
#  1098309  0.105771         jeep   0.000000   0.000210  0.994379        clean
#  950783   0.017169         jeep   0.000017   0.000051  0.999852        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1500587  0.012172         jeep   0.000000   0.000036  0.999926        clean
#  1097865  0.017574         jeep   0.000000   0.000053  0.999845        clean
#  1568000  0.009610         jeep   0.000000   0.000029  0.999954        clean
#  1452620  0.014109         jeep   0.000014   0.000042  0.999900        clean
#  1380486  0.017548         jeep   0.000009   0.000035  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  684464     automatic  full-size  0.000264 -0.000911
#  1678487       manual    compact  0.000243 -0.000547
#  1564129    automatic  full-size  0.000366 -0.000806
#  1098309    automatic    compact  0.001906 -0.004320
#  950783     automatic  full-size  0.000353 -0.000620
#  ...              ...        ...       ...       ...
#  1500587        other  full-size  0.000286 -0.000742
#  1097865    automatic  full-size  0.000317 -0.000736
#  1568000       manual   mid-size  0.000208 -0.000380
#  1452620    automatic  full-size  0.000283 -0.000523
#  1380486       manual    compact  0.000378 -0.000625
#
#  [11157 rows x 10 columns],
#  'gmc':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  651711   0.011446          gmc   0.000000   0.000046  0.999934        clean
#  1588096  0.042143          gmc   0.000000   0.000126  0.999110        clean
#  966154   0.011200          gmc   0.000011   0.000045  0.999937        clean
#  905925   0.017557          gmc   0.000018   0.000070  0.999846        clean
#  450846   0.010594          gmc   0.000000   0.000032  0.999944        clean
#  ...           ...          ...        ...        ...       ...          ...
#  160554   0.017539          gmc   0.000000   0.000053  0.999846        clean
#  664887   0.021041          gmc   0.000000   0.000063  0.999778        clean
#  1410064  0.009308          gmc   0.000009   0.000037  0.999957        clean
#  1113896  0.036938          gmc   0.000000   0.000111  0.999316        clean
#  1364919  0.011072          gmc   0.000000   0.000033  0.999938        clean
#
#          transmission       size       lat      long
#  Id
#  651711     automatic  full-size  0.000223 -0.000694
#  1588096    automatic  full-size  0.000904 -0.001590
#  966154     automatic  full-size  0.000259 -0.000531
#  905925     automatic  full-size  0.000371 -0.000746
#  450846         other  full-size  0.000217 -0.000431
#  ...              ...        ...       ...       ...
#  160554     automatic  full-size  0.000305 -0.000760
#  664887     automatic  full-size  0.000357 -0.001231
#  1410064    automatic  full-size  0.000178 -0.000360
#  1113896    automatic  full-size  0.000506 -0.001527
#  1364919    automatic  full-size  0.000236 -0.000632
#
#  [10274 rows x 10 columns],
# ...
#  1500087  0.016348       toyota   0.000000   0.000049  0.999866        clean
#  197143   0.021591       toyota   0.000022   0.000043  0.999766        clean
#  600566   0.017592       toyota   0.000000   0.000053  0.999845        clean
#  36814    0.014862       toyota   0.000000   0.000044  0.999889        clean
#  ...           ...          ...        ...        ...       ...          ...
#  572203   0.012773       toyota   0.000000   0.000038  0.999918        clean
#  860598   0.016634       toyota   0.000008   0.000050  0.999861        clean
#  1285643  0.020896       toyota   0.000021   0.000062  0.999781        clean
#  1645519  0.011098       toyota   0.000006   0.000022  0.999938        clean
#  1076549  0.017513       toyota   0.000000   0.000053  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  500124     automatic  full-size  0.000267 -0.000892
#  1500087    automatic  full-size  0.000388 -0.000955
#  197143     automatic    compact  0.000530 -0.001323
#  600566     automatic  full-size  0.000399 -0.001076
#  36814      automatic  full-size  0.000292 -0.000571
#  ...              ...        ...       ...       ...
#  572203        manual   mid-size  0.000286 -0.000784
#  860598     automatic   mid-size  0.000327 -0.000869
#  1285643    automatic  full-size  0.000298 -0.001006
#  1645519    automatic   mid-size  0.000249 -0.000496
#  1076549    automatic  full-size  0.000316 -0.000737
#
#  [17202 rows x 10 columns],
#  'fiat':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1503379  0.045452         fiat   0.000000   0.000136  0.998962        clean
#  1225886  0.037935         fiat   0.000038   0.000075  0.999278        clean
#  1277772  0.017715         fiat   0.000009   0.000035  0.999843      rebuilt
#  938046   0.017697         fiat   0.000000   0.000035  0.999843        clean
#  322196   0.032447         fiat   0.000000   0.000097  0.999471        clean
#  ...           ...          ...        ...        ...       ...          ...
#  336232   0.022711         fiat   0.000023   0.000045  0.999742        clean
#  768537   0.018654         fiat   0.000019   0.000037  0.999826        clean
#  20364    0.033216         fiat   0.000033   0.000050  0.999447      rebuilt
#  792765   0.014727         fiat   0.000000   0.000030  0.999891        clean
#  61244    0.020252         fiat   0.000020   0.000060  0.999794        clean
#
#          transmission         size       lat      long
#  Id
#  1503379       manual  sub-compact  0.001093 -0.002700
#  1225886       manual      compact  0.000620 -0.001808
#  1277772    automatic      compact  0.000279 -0.000935
#  938046        manual      compact  0.000367 -0.000627
#  322196     automatic    full-size  0.000792 -0.001983
#  ...              ...          ...       ...       ...
#  336232     automatic      compact  0.000317 -0.000931
#  768537        manual      compact  0.000390 -0.000671
#  20364      automatic      compact  0.000574 -0.001402
#  792765        manual      compact  0.000299 -0.000561
#  61244      automatic    full-size  0.000494 -0.001237
#
#  [314 rows x 10 columns],
#  'lexus':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1195520  0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1388186  0.016584        lexus   0.000008   0.000050  0.999862        clean
#  708929   0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1284522  0.008382        lexus   0.000004   0.000034  0.999965        clean
#  1567156  0.006256        lexus   0.000006   0.000019  0.999980        clean
#  ...           ...          ...        ...        ...       ...          ...
#  514706   0.017100        lexus   0.000017   0.000068  0.999853        clean
#  1249626  0.022283        lexus   0.000022   0.000067  0.999751        clean
#  1675277  0.017662        lexus   0.000000   0.000053  0.999844        clean
#  283635   0.016176        lexus   0.000016   0.000048  0.999869        clean
#  946580   0.017349        lexus   0.000000   0.000052  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  1195520    automatic  full-size  0.000245 -0.000727
#  1388186    automatic  full-size  0.000305 -0.000631
#  708929     automatic  full-size  0.000297 -0.001036
#  1284522    automatic  full-size  0.000124 -0.000414
#  1567156    automatic   mid-size  0.000135 -0.000236
#  ...              ...        ...       ...       ...
#  514706     automatic  full-size  0.000304 -0.000833
#  1249626    automatic   mid-size  0.000338 -0.001085
#  1675277    automatic  full-size  0.000315 -0.000716
#  283635     automatic  full-size  0.000246 -0.000703
#  946580     automatic  full-size  0.000355 -0.000631
#
#  [3012 rows x 10 columns],
#  'honda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1099744  0.017662        honda   0.000018   0.000053  0.999844        clean
#  386522   0.033531        honda   0.000033   0.000100  0.999437        clean
#  1030588  0.010177        honda   0.000000   0.000020  0.999948        clean
#  1355767  0.029284        honda   0.000029   0.000058  0.999570        clean
#  608497   0.017680        honda   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1614746  0.074521        honda   0.000000   0.000222  0.997215        clean
#  1126982  0.069236        honda   0.000000   0.000206  0.997595        clean
#  64234    0.017574        honda   0.000000   0.000053  0.999845        clean
#  1684307  0.017583        honda   0.000009   0.000035  0.999845      rebuilt
#  1605370  0.012676        honda   0.000006   0.000025  0.999920        clean
#
#          transmission       size       lat      long
#  Id
#  1099744    automatic  full-size  0.000307 -0.000749
#  386522     automatic   mid-size  0.000723 -0.001340
#  1030588    automatic    compact  0.000223 -0.000525
#  1355767    automatic   mid-size  0.000647 -0.001064
#  608497        manual  full-size  0.000310 -0.001060
#  ...              ...        ...       ...       ...
#  1614746    automatic  full-size  0.001510 -0.002714
#  1126982    automatic  full-size  0.001044 -0.002974
#  64234          other  full-size  0.000399 -0.000647
#  1684307    automatic    compact  0.000305 -0.000685
#  1605370    automatic    compact  0.000272 -0.000481
#
#  [13143 rows x 10 columns],
#  'mercury':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1157283  0.017566      mercury   0.000009   0.000053  0.999845        clean
#  834053   0.007056      mercury   0.000004   0.000028  0.999975        clean
#  399248   0.011770      mercury   0.000006   0.000035  0.999931        clean
#  1490783  0.017293      mercury   0.000009   0.000070  0.999850        clean
#  587662   0.011811      mercury   0.000000   0.000035  0.999930        clean
#  ...           ...          ...        ...        ...       ...          ...
#  984418   0.010711      mercury   0.000011   0.000043  0.999942      rebuilt
#  1202222  0.014443      mercury   0.000007   0.000043  0.999895        clean
#  875215   0.017381      mercury   0.000009   0.000070  0.999849        clean
#  1614673  0.011790      mercury   0.000000   0.000047  0.999930        clean
#  1167053  0.019746      mercury   0.000000   0.000080  0.999805        clean
#
#          transmission       size       lat      long
#  Id
#  1157283    automatic  full-size  0.000267 -0.000759
#  834053     automatic   mid-size  0.000137 -0.000368
#  399248     automatic  full-size  0.000184 -0.000503
#  1490783    automatic  full-size  0.000426 -0.001074
#  587662     automatic  full-size  0.000265 -0.000726
#  ...              ...        ...       ...       ...
#  984418     automatic  full-size  0.000235 -0.000514
#  1202222    automatic  full-size  0.000331 -0.000782
#  875215        manual  full-size  0.000376 -0.000755
#  1614673    automatic  full-size  0.000241 -0.000431
#  1167053    automatic  full-size  0.000280 -0.000819
#
#  [1451 rows x 10 columns],
#  'audi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1096521  0.012702         audi   0.000000   0.000051  0.999919        clean
#  840911   0.006488         audi   0.000003   0.000019  0.999979        clean
#  1284719  0.264102         audi   0.000000   0.000785  0.964403        clean
#  748622   0.015722         audi   0.000016   0.000031  0.999876        clean
#  1473785  0.017550         audi   0.000018   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  330380   0.022126         audi   0.000000   0.000044  0.999755        clean
#  679075   0.021351         audi   0.000021   0.000064  0.999771        clean
#  1466507  0.017557         audi   0.000000   0.000053  0.999846        clean
#  222383   0.017758         audi   0.000000   0.000053  0.999842        clean
#  1579969  0.022294         audi   0.000000   0.000044  0.999751        clean
#
#          transmission       size       lat      long
#  Id
#  1096521    automatic  full-size  0.000229 -0.000549
#  840911     automatic  full-size  0.000131 -0.000340
#  1284719    automatic  full-size  0.003428 -0.012844
#  748622     automatic    compact  0.000297 -0.000948
#  1473785    automatic   mid-size  0.000428 -0.001074
#  ...              ...        ...       ...       ...
#  330380     automatic   mid-size  0.000468 -0.000780
#  679075     automatic  full-size  0.000362 -0.001246
#  1466507    automatic    compact  0.000358 -0.000652
#  222383     automatic  full-size  0.000316 -0.000696
#  1579969    automatic    compact  0.000478 -0.000846
#
#  [2232 rows x 10 columns],
#  'saturn':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1643997  0.016723       saturn   0.000000   0.000050  0.999860        clean
#  907300   0.011776       saturn   0.000006   0.000024  0.999931        clean
#  1464649  0.024218       saturn   0.000024   0.000072  0.999706        clean
#  1613311  0.032338       saturn   0.000032   0.000097  0.999476        clean
#  692353   0.011255       saturn   0.000000   0.000022  0.999936        clean
#  ...           ...          ...        ...        ...       ...          ...
#  587410   0.017522       saturn   0.000000   0.000053  0.999846        clean
#  121778   0.017714       saturn   0.000000   0.000035  0.999843        clean
#  892908   0.017618       saturn   0.000009   0.000053  0.999844        clean
#  278705   0.017583       saturn   0.000000   0.000053  0.999845        clean
#  786965   0.017566       saturn   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long
#  Id
#  1643997    automatic  full-size  0.000377 -0.000765
#  907300     automatic    compact  0.000253 -0.000492
#  1464649    automatic  full-size  0.000479 -0.000904
#  1613311    automatic  full-size  0.000678 -0.001226
#  692353     automatic    compact  0.000207 -0.000673
#  ...              ...        ...       ...       ...
#  587410        manual  full-size  0.000395 -0.001080
#  121778        manual   mid-size  0.000335 -0.001002
#  892908     automatic  full-size  0.000378 -0.000730
#  278705        manual  full-size  0.000317 -0.000705
#  786965     automatic  full-size  0.000360 -0.000683
#
#  [1345 rows x 10 columns],
#  'datsun':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  154867   0.082865       datsun   0.000084   0.000251  0.996555        clean
#  1034159  0.038011       datsun   0.000038   0.000115  0.999275        clean
#  127388   0.017355       datsun   0.000018   0.000053  0.999849        clean
#  1691790  0.017355       datsun   0.000000   0.000053  0.999849        clean
#  1209077  0.017372       datsun   0.000009   0.000053  0.999849        clean
#  ...           ...          ...        ...        ...       ...          ...
#  595616   0.017372       datsun   0.000009   0.000053  0.999848        clean
#  1073326  0.013304       datsun   0.000000   0.000040  0.999911        clean
#  285527   0.017293       datsun   0.000000   0.000053  0.999850        clean
#  854044   0.017320       datsun   0.000009   0.000053  0.999850        clean
#  588840   0.017364       datsun   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  154867        manual    compact  0.001670 -0.003106
#  1034159       manual    compact  0.000751 -0.001818
#  127388        manual    compact  0.000287 -0.001028
#  1691790       manual  full-size  0.000309 -0.000697
#  1209077       manual  full-size  0.000412 -0.001001
#  ...              ...        ...       ...       ...
#  595616        manual  full-size  0.000400 -0.001079
#  1073326    automatic  full-size  0.000243 -0.000581
#  285527        manual  full-size  0.000357 -0.000983
#  854044     automatic    compact  0.000336 -0.000919
#  588840        manual  full-size  0.000371 -0.001078
#
#  [79 rows x 10 columns],
#  'unknown':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  771920   0.014356      unknown   0.000007   0.000029  0.999897        clean
#  138219   0.017574      unknown   0.000000   0.000070  0.999845        clean
#  546294   0.015222      unknown   0.000008   0.000031  0.999884        clean
#  889246   0.012744      unknown   0.000000   0.000038  0.999919        clean
#  205327   0.039342      unknown   0.000039   0.000118  0.999224        clean
#  ...           ...          ...        ...        ...       ...          ...
#  349037   0.017609      unknown   0.000000   0.000053  0.999844        clean
#  1131359  0.017627      unknown   0.000000   0.000053  0.999844        clean
#  327284   0.055531      unknown   0.000056   0.000225  0.998454        clean
#  1302188  0.007224      unknown   0.000004   0.000022  0.999974        clean
#  1396770  0.017285      unknown   0.000000   0.000053  0.999850        clean
#
#          transmission       size       lat      long
#  Id
#  771920        manual    compact  0.000302 -0.000515
#  138219     automatic  full-size  0.000238 -0.000704
#  546294        manual    compact  0.000296 -0.000587
#  889246     automatic  full-size  0.000274 -0.000531
#  205327        manual  full-size  0.000917 -0.001897
#  ...              ...        ...       ...       ...
#  349037     automatic  full-size  0.000325 -0.001051
#  1131359    automatic  full-size  0.000245 -0.000725
#  327284        manual  full-size  0.001231 -0.002054
#  1302188       manual  full-size  0.000121 -0.000305
#  1396770    automatic  full-size  0.000338 -0.000693
#
#  [20048 rows x 10 columns]}

# %%
# Try optimal Linear Regression for submission
y_sub = {}
for i, df in X_sub_dec.items():
    x = df.drop(columns=['manufacturer','title_status','transmission','size'])
    y_sub[i] = lin_reg_dec[i].predict(x)

# %%
X_sub_dec
# Out:
# {'ferrari':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  873208   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  1615923  0.017548      ferrari   0.000000   0.000053  0.999846        clean
#  1245573  0.062069      ferrari   0.000062   0.000373  0.998067        clean
#  657050   0.017443      ferrari   0.000000   0.000053  0.999847        clean
#  682622   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#  1676954  0.997843      ferrari   0.000000   0.002976  0.049595        clean
#  576328   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#  930632   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  336544   0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  684874   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#  622772   0.017522      ferrari   0.000018   0.000070  0.999846      salvage
#  1690604  0.033438      ferrari   0.000034   0.000135  0.999440        clean
#  10603    0.074264      ferrari   0.000074   0.000296  0.997229        clean
#  659788   0.113560      ferrari   0.000056   0.000452  0.993506        clean
#  728801   0.017715      ferrari   0.000000   0.000053  0.999842        clean
#  1482578  0.359490      ferrari   0.000179   0.001072  0.932851        clean
#  495319   0.127177      ferrari   0.000127   0.000507  0.991852        clean
#  369481   0.060495      ferrari   0.000060   0.000181  0.998160        clean
#  683400   0.479265      ferrari   0.000476   0.001903  0.877185        clean
#  1125515  0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  627533   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#  629673   0.070927      ferrari   0.000000   0.000425  0.997472        clean
#  1159787  0.051496      ferrari   0.000051   0.000205  0.998671      rebuilt
#  44047    0.068867      ferrari   0.000034   0.000275  0.997615        clean
#  1014750  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  742494   0.153949      ferrari   0.000153   0.000613  0.988030        clean
#  1015452  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  825776   0.011901      ferrari  -0.000006   0.000047  0.999929      salvage
#  339032   0.073293      ferrari   0.000073   0.000220  0.997299        clean
#  228087   0.017434      ferrari   0.000000   0.000053  0.999848      rebuilt
#  630726   0.045068      ferrari   0.000045   0.000182  0.998980        clean
#  669317   0.074264      ferrari   0.000074   0.000296  0.997229        clean
#
#          transmission         size       lat      long
#  Id
#  873208     automatic    full-size  0.002119 -0.004230
#  1615923    automatic    full-size  0.000377 -0.000691
#  1245573       manual     mid-size  0.000943 -0.003033
#  657050        manual    full-size  0.000339 -0.001065
#  682622        manual      compact  0.001981 -0.006881
#  1676954       manual    full-size  0.017802 -0.039033
#  576328         other  sub-compact  0.002514 -0.006762
#  930632     automatic    full-size  0.002119 -0.004230
#  336544        manual    full-size  0.001957 -0.006105
#  684874     automatic    full-size  0.001249 -0.004308
#  622772        manual    full-size  0.000330 -0.001074
#  1690604       manual      compact  0.000602 -0.001329
#  10603      automatic    full-size  0.001249 -0.004308
#  659788     automatic     mid-size  0.002013 -0.006819
#  728801     automatic    full-size  0.000299 -0.001039
#  1482578        other    full-size  0.008711 -0.021882
#  495319     automatic    full-size  0.002118 -0.007096
#  369481     automatic    full-size  0.001490 -0.003723
#  683400     automatic    full-size  0.007997 -0.027983
#  1125515    automatic    full-size  0.001957 -0.006105
#  627533        manual    full-size  0.001243 -0.004252
#  629673     automatic    full-size  0.001200 -0.004154
#  1159787    automatic    full-size  0.000668 -0.002054
#  44047      automatic    full-size  0.001675 -0.004209
#  1014750    automatic      compact  0.000796 -0.001535
#  742494     automatic     mid-size  0.002803 -0.009340
#  1015452    automatic    full-size  0.000792 -0.001534
#  825776     automatic    full-size  0.000244 -0.000447
#  339032     automatic    full-size  0.001797 -0.004488
#  228087        manual    full-size  0.000267 -0.000799
#  630726        manual    full-size  0.000774 -0.002688
#  669317     automatic    full-size  0.001249 -0.004308  ,
#  'kia':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  144337   0.011551          kia   0.000011   0.000034  0.999933        clean
#  1158202  0.037935          kia   0.000000   0.000113  0.999279      rebuilt
#  539918   0.022257          kia   0.000011   0.000066  0.999752        clean
#  1223914  0.017662          kia   0.000000   0.000053  0.999844        clean
#  1532059  0.015848          kia   0.000016   0.000032  0.999874        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1106624  0.019163          kia   0.000000   0.000057  0.999816        clean
#  1219609  0.022623          kia   0.000022   0.000045  0.999743        clean
#  1340428  0.057504          kia   0.000057   0.000114  0.998339        clean
#  1263028  0.016756          kia   0.000017   0.000050  0.999859        clean
#  720330   0.022801          kia   0.000000   0.000068  0.999739        clean
#
#          transmission       size       lat      long
#  Id
#  144337     automatic   mid-size  0.000193 -0.000496
#  1158202    automatic  full-size  0.000485 -0.001517
#  539918     automatic  full-size  0.000398 -0.001039
#  1223914    automatic  full-size  0.000297 -0.000865
#  1532059    automatic    compact  0.000329 -0.000685
#  ...              ...        ...       ...       ...
#  1106624    automatic  full-size  0.000283 -0.000784
#  1219609    automatic    compact  0.000294 -0.001104
#  1340428    automatic    compact  0.001059 -0.003241
#  1263028    automatic  full-size  0.000248 -0.000796
#  720330     automatic  full-size  0.000384 -0.001322
#
#  [3629 rows x 10 columns],
#  'harley-davidson':              year     manufacturer  condition  cylinders  odometer  \
#  Id
#  1295554  0.017513  harley-davidson   0.000018   0.000053  0.999846
#  442879   0.448546  harley-davidson   0.000447   0.001340  0.893519
#  181606   0.017548  harley-davidson   0.000000   0.000053  0.999846
#  1010170  0.152648  harley-davidson   0.000152   0.000456  0.988259
#  310213   0.201971  harley-davidson   0.000101   0.000605  0.979302
#  ...           ...              ...        ...        ...       ...
#  782715   0.280042  harley-davidson   0.000278   0.000835  0.959906
#  1679923  0.017618  harley-davidson   0.000000   0.000035  0.999845
#  1604512  0.009118  harley-davidson   0.000005   0.000036  0.999958
#  494891   0.017592  harley-davidson   0.000009   0.000070  0.999845
#  1615057  0.017618  harley-davidson   0.000000   0.000053  0.999845
#
#          title_status transmission       size       lat      long
#  Id
#  1295554         lien       manual  full-size  0.000284 -0.000844
#  442879         clean       manual  full-size  0.009187 -0.018545
#  181606         clean       manual  full-size  0.000310 -0.000937
#  1010170        clean       manual  full-size  0.002562 -0.006000
#  310213         clean       manual  full-size  0.004760 -0.012334
#  ...              ...          ...        ...       ...       ...
#  782715         clean       manual  full-size  0.005688 -0.011120
#  1679923        clean    automatic    compact  0.000306 -0.000680
#  1604512        clean    automatic  full-size  0.000200 -0.000345
#  494891       rebuilt    automatic  full-size  0.000282 -0.000974
#  1615057        clean    automatic  full-size  0.000356 -0.000650
#
#  [138 rows x 10 columns],
#  'morgan':             year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  935779  0.017689       morgan   0.000018   0.000053  0.999843        clean
#  842649  0.989985       morgan   0.000984   0.002951  0.129834        clean
#
#         transmission       size       lat      long
#  Id
#  935779        other  full-size  0.000367 -0.000627
#  842649       manual  full-size  0.019673 -0.051725  ,
#  'mazda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  830219   0.065874        mazda   0.000000   0.000196  0.997821        clean
#  314758   0.088681        mazda   0.000088   0.000176  0.996052         lien
#  999201   0.017504        mazda  -0.000009   0.000053  0.999846        clean
#  421641   0.357951        mazda   0.000355   0.000710  0.933298        clean
#  1101173  0.044927        mazda   0.000045   0.000089  0.998988        clean
#  ...           ...          ...        ...        ...       ...          ...
#  317870   0.052952        mazda   0.000000   0.000158  0.998591        clean
#  860527   0.011758        mazda   0.000006   0.000035  0.999931        clean
#  287062   0.017609        mazda   0.000018   0.000053  0.999844        clean
#  1410661  0.021987        mazda   0.000000   0.000066  0.999758        clean
#  815566   0.017636        mazda   0.000000   0.000053  0.999844        clean
#
#          transmission       size       lat      long
#  Id
#  830219     automatic  full-size  0.001251 -0.003420
#  314758     automatic    compact  0.001922 -0.003498
#  999201        manual  full-size  0.000290 -0.000704
#  421641     automatic   mid-size  0.010853 -0.026590
#  1101173    automatic    compact  0.000675 -0.001820
#  ...              ...        ...       ...       ...
#  317870     automatic  full-size  0.001292 -0.003227
#  860527        manual   mid-size  0.000233 -0.000619
#  287062     automatic  full-size  0.000296 -0.001003
#  1410661    automatic  full-size  0.000409 -0.000870
#  815566     automatic  full-size  0.000358 -0.000664
#
#  [3462 rows x 10 columns],
#  'mini':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1565975  0.017583         mini   0.000009   0.000035  0.999845        clean
#  711505   0.031548         mini   0.000000   0.000063  0.999500        clean
#  231273   0.017662         mini   0.000000   0.000053  0.999844        clean
#  1160215  0.038242         mini   0.000038   0.000114  0.999267        clean
#  1529924  0.012609         mini   0.000006   0.000025  0.999920        clean
#  ...           ...          ...        ...        ...       ...          ...
#  691349   0.021114         mini   0.000021   0.000063  0.999776        clean
#  584522   0.017671         mini   0.000000   0.000053  0.999843        clean
#  1530742  0.042973         mini   0.000043   0.000128  0.999074        clean
#  1452433  0.024708         mini   0.000025   0.000049  0.999694        clean
#  109704   0.029453         mini   0.000029   0.000088  0.999565        clean
#
#          transmission         size       lat      long
#  Id
#  1565975       manual      compact  0.000365 -0.000822
#  711505     automatic      compact  0.000553 -0.001894
#  231273     automatic    full-size  0.000273 -0.000819
#  1160215    automatic    full-size  0.000531 -0.001562
#  1529924    automatic    full-size  0.000250 -0.000542
#  ...              ...          ...       ...       ...
#  691349     automatic    full-size  0.000385 -0.001256
#  584522        manual    full-size  0.000387 -0.001082
#  1530742       manual  sub-compact  0.000890 -0.001842
#  1452433       manual      compact  0.000500 -0.000921
#  109704     automatic    full-size  0.000446 -0.001302
#
#  [1040 rows x 10 columns],
#  'volvo':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  305757   0.017662        volvo   0.000018   0.000044  0.999844        clean
#  926352   0.010121        volvo   0.000005   0.000025  0.999949        clean
#  671502   0.016274        volvo   0.000008   0.000041  0.999867        clean
#  431731   0.018599        volvo   0.000009   0.000056  0.999827        clean
#  843681   0.007766        volvo   0.000004   0.000023  0.999970        clean
#  ...           ...          ...        ...        ...       ...          ...
#  118994   0.017583        volvo   0.000000   0.000053  0.999845        clean
#  1698378  0.025447        volvo   0.000025   0.000076  0.999676      rebuilt
#  1401417  0.012258        volvo   0.000006   0.000031  0.999925        clean
#  761453   0.018804        volvo   0.000019   0.000047  0.999823        clean
#  756304   0.017680        volvo   0.000000   0.000053  0.999843        clean
#
#          transmission         size       lat      long
#  Id
#  305757     automatic  sub-compact  0.000354 -0.000678
#  926352     automatic     mid-size  0.000218 -0.000429
#  671502     automatic     mid-size  0.000314 -0.000987
#  431731     automatic    full-size  0.000278 -0.000835
#  843681     automatic    full-size  0.000154 -0.000412
#  ...              ...          ...       ...       ...
#  118994     automatic    full-size  0.000267 -0.000740
#  1698378    automatic     mid-size  0.000453 -0.001016
#  1401417       manual     mid-size  0.000234 -0.000483
#  761453     automatic    full-size  0.000395 -0.000666
#  756304     automatic    full-size  0.000374 -0.000627
#
#  [1675 rows x 10 columns],
#  'subaru':             year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  764904  0.017601       subaru   0.000000   0.000053  0.999845        clean
#  330867  0.017513       subaru   0.000000   0.000053  0.999846        clean
#  608763  0.007673       subaru   0.000000   0.000015  0.999970        clean
#  769396  0.024563       subaru   0.000024   0.000049  0.999698        clean
#  938823  0.017610       subaru   0.000009   0.000035  0.999845        clean
#  ...          ...          ...        ...        ...       ...          ...
#  704741  0.058687       subaru   0.000000   0.000175  0.998270        clean
#  730006  0.022093       subaru   0.000022   0.000044  0.999755        clean
#  963343  0.011434       subaru   0.000000   0.000034  0.999934        clean
#  829242  0.011216       subaru   0.000000   0.000033  0.999937        clean
#  63033   0.017539       subaru  -0.000009   0.000035  0.999846        clean
#
#         transmission       size       lat      long
#  Id
#  764904    automatic  full-size  0.000372 -0.000633
#  330867    automatic  full-size  0.000513 -0.001182
#  608763    automatic   mid-size  0.000135 -0.000464
#  769396    automatic  full-size  0.000513 -0.000886
#  938823    automatic   mid-size  0.000363 -0.000632
#  ...             ...        ...       ...       ...
#  704741       manual  full-size  0.001124 -0.003534
#  730006       manual    compact  0.000428 -0.001330
#  963343    automatic  full-size  0.000266 -0.000524
#  829242        other  full-size  0.000224 -0.000586
#  63033     automatic    compact  0.000364 -0.000800
#
#  [4341 rows x 10 columns],
#  'buick':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1211117  0.011939        buick   0.000000   0.000036  0.999928        clean
#  947857   0.016358        buick   0.000000   0.000049  0.999866        clean
#  1113129  0.021282        buick   0.000011   0.000064  0.999773        clean
#  170062   0.019698        buick   0.000020   0.000059  0.999806        clean
#  1488852  0.017680        buick   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  511377   0.013507        buick   0.000013   0.000040  0.999909        clean
#  1289744  0.017618        buick   0.000000   0.000053  0.999844        clean
#  923478   0.017548        buick   0.000018   0.000053  0.999846        clean
#  121897   0.019108        buick   0.000000   0.000057  0.999817        clean
#  205239   0.017557        buick   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long
#  Id
#  1211117    automatic  full-size  0.000284 -0.000664
#  947857     automatic  full-size  0.000339 -0.000590
#  1113129    automatic  full-size  0.000292 -0.000878
#  170062     automatic  full-size  0.000400 -0.000716
#  1488852    automatic  full-size  0.000406 -0.001047
#  ...              ...        ...       ...       ...
#  511377     automatic  full-size  0.000238 -0.000657
#  1289744    automatic  full-size  0.000258 -0.000865
#  923478     automatic  full-size  0.000380 -0.000725
#  121897     automatic  full-size  0.000352 -0.001078
#  205239     automatic  full-size  0.000412 -0.000850
#
#  [3399 rows x 10 columns],
#  'cadillac':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  507587   0.071247     cadillac   0.000000   0.000212  0.997452        clean
#  2265     0.998960     cadillac   0.001007   0.003021  0.000000        clean
#  142638   0.038702     cadillac   0.000038   0.000077  0.999249        clean
#  1377147  0.017680     cadillac   0.000000   0.000053  0.999843        clean
#  1193213  0.020250     cadillac   0.000010   0.000081  0.999795      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  898890   0.012954     cadillac   0.000006   0.000039  0.999916         lien
#  501516   0.028257     cadillac   0.000000   0.000084  0.999600        clean
#  415087   0.066391     cadillac   0.000066   0.000264  0.997779        clean
#  1527196  0.017548     cadillac   0.000000   0.000053  0.999846        clean
#  1519119  0.017337     cadillac   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  507587     automatic  full-size  0.001257 -0.003451
#  2265       automatic  full-size  0.021250 -0.040215
#  142638     automatic   mid-size  0.000589 -0.001696
#  1377147    automatic  full-size  0.000383 -0.000628
#  1193213    automatic  full-size  0.000274 -0.000832
#  ...              ...        ...       ...       ...
#  898890     automatic  full-size  0.000289 -0.000554
#  501516     automatic   mid-size  0.000611 -0.000989
#  415087     automatic  full-size  0.002018 -0.004945
#  1527196    automatic  full-size  0.000349 -0.000757
#  1519119    automatic  full-size  0.000366 -0.000747
#
#  [3682 rows x 10 columns],
#  'bmw':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  629957   0.088878          bmw   0.000088   0.000176  0.996028        clean
#  370879   0.090656          bmw   0.000090   0.000270  0.995864        clean
#  670648   0.057473          bmw   0.000000   0.000114  0.998340        clean
#  1170904  0.019386          bmw   0.000000   0.000058  0.999812        clean
#  627499   0.020465          bmw   0.000010   0.000082  0.999790        clean
#  ...           ...          ...        ...        ...       ...          ...
#  762018   0.013881          bmw   0.000007   0.000042  0.999903        clean
#  412066   0.036764          bmw   0.000037   0.000110  0.999323        clean
#  266383   0.055885          bmw   0.000055   0.000111  0.998433      rebuilt
#  827094   0.025142          bmw   0.000025   0.000050  0.999683        clean
#  688556   0.009852          bmw   0.000005   0.000039  0.999951        clean
#
#          transmission       size       lat      long
#  Id
#  629957     automatic    compact  0.001506 -0.005216
#  370879     automatic  full-size  0.002213 -0.005539
#  670648     automatic    compact  0.001105 -0.003458
#  1170904    automatic  full-size  0.000263 -0.000795
#  627499     automatic  full-size  0.000376 -0.001240
#  ...              ...        ...       ...       ...
#  762018        manual   mid-size  0.000293 -0.000502
#  412066     automatic    compact  0.000697 -0.001548
#  266383     automatic   mid-size  0.001295 -0.002554
#  827094     automatic    compact  0.000500 -0.000956
#  688556     automatic  full-size  0.000185 -0.000596
#
#  [6302 rows x 10 columns],
#  'mitsubishi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  527762   0.017689   mitsubishi   0.000018   0.000053  0.999843        clean
#  1247933  0.017645   mitsubishi   0.000000   0.000053  0.999844      salvage
#  1675559  0.017594   mitsubishi   0.000018   0.000053  0.999845        clean
#  724442   0.023753   mitsubishi   0.000024   0.000071  0.999717        clean
#  1092376  0.017627   mitsubishi   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  957482   0.045476   mitsubishi   0.000045   0.000136  0.998964        clean
#  210130   0.030526   mitsubishi   0.000000   0.000091  0.999533        clean
#  1500155  0.074420   mitsubishi   0.000000   0.000221  0.997216        clean
#  658852   0.017513   mitsubishi   0.000000   0.000053  0.999846        clean
#  1304023  0.017522   mitsubishi   0.000000   0.000053  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  527762     automatic  full-size  0.000312 -0.000857
#  1247933    automatic  full-size  0.000230 -0.000861
#  1675559    automatic   mid-size  0.000311 -0.000707
#  724442     automatic  full-size  0.000462 -0.001455
#  1092376    automatic  full-size  0.000313 -0.000780
#  ...              ...        ...       ...       ...
#  957482        manual  full-size  0.000938 -0.001649
#  210130         other  full-size  0.000454 -0.001365
#  1500155    automatic  full-size  0.001705 -0.004393
#  658852        manual  full-size  0.000312 -0.001060
#  1304023    automatic  full-size  0.000288 -0.000736
#
#  [1678 rows x 10 columns],
#  'dodge':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  296855   0.017610        dodge   0.000000   0.000053  0.999845        clean
#  1239902  0.014573        dodge   0.000000   0.000029  0.999894        clean
#  1305765  0.017583        dodge   0.000000   0.000052  0.999845        clean
#  1234416  0.017706        dodge   0.000000   0.000053  0.999843        clean
#  491202   0.011105        dodge   0.000006   0.000056  0.999938        clean
#  ...           ...          ...        ...        ...       ...          ...
#  492086   0.013964        dodge   0.000007   0.000042  0.999902        clean
#  649565   0.016274        dodge   0.000016   0.000032  0.999867        clean
#  909774   0.024101        dodge   0.000000   0.000096  0.999709        clean
#  585898   0.017267        dodge   0.000000   0.000053  0.999850        clean
#  662527   0.017406        dodge  -0.000009   0.000052  0.999848      salvage
#
#          transmission       size       lat      long
#  Id
#  296855     automatic  full-size  0.000361 -0.000708
#  1239902    automatic    compact  0.000201 -0.000706
#  1305765    automatic  full-size  0.000286 -0.000732
#  1234416    automatic  full-size  0.000261 -0.000839
#  491202     automatic  full-size  0.000190 -0.000618
#  ...              ...        ...       ...       ...
#  492086     automatic  full-size  0.000232 -0.000778
#  649565     automatic   mid-size  0.000304 -0.000978
#  909774     automatic  full-size  0.000507 -0.001034
#  585898        manual   mid-size  0.000405 -0.001087
#  662527     automatic   mid-size  0.000284 -0.001018
#
#  [11237 rows x 10 columns],
#  'chrysler':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  16156    0.012402     chrysler   0.000006   0.000037  0.999923        clean
#  1442002  0.017601     chrysler   0.000000   0.000053  0.999845        clean
#  1636834  0.017610     chrysler   0.000018   0.000053  0.999845        clean
#  290057   0.016070     chrysler   0.000008   0.000048  0.999871        clean
#  1496219  0.068258     chrysler   0.000000   0.000203  0.997658        clean
#  ...           ...          ...        ...        ...       ...          ...
#  138193   0.012537     chrysler   0.000012   0.000025  0.999921        clean
#  230387   0.017610     chrysler   0.000000   0.000053  0.999845        clean
#  1110817  0.015437     chrysler   0.000015   0.000046  0.999881        clean
#  885711   0.018253     chrysler   0.000009   0.000054  0.999833        clean
#  373566   0.017423     chrysler   0.000017   0.000052  0.999848        clean
#
#          transmission       size       lat      long
#  Id
#  16156      automatic  full-size  0.000226 -0.000550
#  1442002    automatic  full-size  0.000366 -0.000769
#  1636834    automatic   mid-size  0.000383 -0.000782
#  290057     automatic  full-size  0.000285 -0.000630
#  1496219    automatic  full-size  0.001565 -0.004033
#  ...              ...        ...       ...       ...
#  138193     automatic    compact  0.000209 -0.000698
#  230387     automatic  full-size  0.000266 -0.000790
#  1110817    automatic  full-size  0.000228 -0.000637
#  885711     automatic  full-size  0.000391 -0.000759
#  373566     automatic   mid-size  0.000352 -0.000682
#
#  [4542 rows x 10 columns],
#  'land rover':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  208608   0.034637   land rover   0.000034   0.000138  0.999397        clean
#  608308   0.017645   land rover   0.000000   0.000053  0.999844        clean
#  1681805  0.019323   land rover   0.000019   0.000077  0.999813        clean
#  1538357  0.017697   land rover   0.000018   0.000053  0.999843        clean
#  1199177  0.017539   land rover   0.000000   0.000053  0.999846        clean
#  ...           ...          ...        ...        ...       ...          ...
#  369422   0.011005   land rover   0.000005   0.000033  0.999939        clean
#  398722   0.017610   land rover   0.000018   0.000070  0.999845        clean
#  667988   0.017225   land rover   0.000017   0.000069  0.999851        clean
#  949042   0.019610   land rover   0.000000   0.000059  0.999807        clean
#  1367703  0.008951   land rover   0.000000   0.000036  0.999960        clean
#
#          transmission       size       lat      long
#  Id
#  208608     automatic   mid-size  0.000845 -0.002115
#  608308     automatic  full-size  0.000323 -0.001069
#  1681805    automatic  full-size  0.000329 -0.000749
#  1538357    automatic  full-size  0.000308 -0.000936
#  1199177       manual  full-size  0.000241 -0.000726
#  ...              ...        ...       ...       ...
#  369422     automatic  full-size  0.000270 -0.000676
#  398722     automatic  full-size  0.000295 -0.000762
#  667988     automatic  full-size  0.000320 -0.001046
#  949042     automatic  full-size  0.000407 -0.000712
#  1367703    automatic  full-size  0.000195 -0.000521
#
#  [796 rows x 10 columns],
#  'ford':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  974298   0.012991         ford   0.000006   0.000052  0.999915        clean
#  1473203  0.016925         ford   0.000000   0.000053  0.999856      missing
#  972509   0.016491         ford   0.000016   0.000066  0.999864        clean
#  656907   0.116697         ford   0.000000   0.000347  0.993140        clean
#  525619   0.017645         ford   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  24233    0.012388         ford   0.000012   0.000037  0.999923        clean
#  1184470  0.017715         ford   0.000018   0.000053  0.999843        clean
#  1533790  0.007103         ford   0.000004   0.000028  0.999975        clean
#  1026234  0.017610         ford   0.000000   0.000053  0.999845        clean
#  1541257  0.019554         ford   0.000010   0.000078  0.999808        clean
#
#          transmission         size       lat      long
#  Id
#  974298     automatic    full-size  0.000309 -0.000585
#  1473203       manual    full-size  0.000430 -0.001078
#  972509     automatic    full-size  0.000361 -0.000759
#  656907     automatic  sub-compact  0.002186 -0.007076
#  525619        manual    full-size  0.000312 -0.000857
#  ...              ...          ...       ...       ...
#  24233      automatic    full-size  0.000219 -0.000498
#  1184470    automatic    full-size  0.000262 -0.000724
#  1533790    automatic    full-size  0.000116 -0.000379
#  1026234    automatic    full-size  0.000268 -0.000788
#  1541257    automatic    full-size  0.000341 -0.001036
#
#  [42919 rows x 10 columns],
#  'porche':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  636319   0.017609       porche   0.000009   0.000053  0.999844        clean
#  230466   0.007426       porche   0.000004   0.000022  0.999972        clean
#  1243223  0.015421       porche   0.000000   0.000046  0.999881        clean
#  1257255  0.017601       porche   0.000018   0.000070  0.999845        clean
#  270807   0.060100       porche   0.000060   0.000119  0.998189        clean
#  649219   0.015964       porche   0.000016   0.000048  0.999872        clean
#  998349   0.017636       porche   0.000000   0.000053  0.999844        clean
#  118563   0.014430       porche   0.000000   0.000043  0.999896        clean
#  1673513  0.017434       porche   0.000018   0.000035  0.999848        clean
#  460826   0.051582       porche   0.000051   0.000154  0.998666        clean
#  1122102  0.016593       porche   0.000017   0.000050  0.999862        clean
#  1283713  0.027125       porche   0.000027   0.000081  0.999631        clean
#  1427123  0.014430       porche   0.000000   0.000043  0.999896        clean
#  181352   0.017460       porche   0.000000   0.000053  0.999847        clean
#  49033    0.028328       porche   0.000028   0.000085  0.999598        clean
#  17490    0.009192       porche   0.000005   0.000028  0.999958        clean
#  1673500  0.017434       porche   0.000018   0.000035  0.999848        clean
#  735070   0.017662       porche   0.000000   0.000053  0.999843        clean
#  248741   0.021174       porche   0.000021   0.000084  0.999775        clean
#  374129   0.017557       porche   0.000000   0.000053  0.999845        clean
#  1610906  0.096163       porche   0.000096   0.000287  0.995357        clean
#
#          transmission       size       lat      long
#  Id
#  636319     automatic  full-size  0.000328 -0.001058
#  230466     automatic  full-size  0.000159 -0.000292
#  1243223    automatic  full-size  0.000244 -0.000818
#  1257255    automatic  full-size  0.000265 -0.000838
#  270807     automatic  full-size  0.001066 -0.002460
#  649219     automatic  full-size  0.000294 -0.000953
#  998349     automatic  full-size  0.000288 -0.000702
#  118563     automatic  full-size  0.000300 -0.000634
#  1673513       manual    compact  0.000311 -0.000724
#  460826     automatic    compact  0.001064 -0.002094
#  1122102    automatic  full-size  0.000237 -0.000673
#  1283713    automatic  full-size  0.000403 -0.001292
#  1427123    automatic  full-size  0.000300 -0.000634
#  181352        manual  full-size  0.000332 -0.000737
#  49033      automatic  full-size  0.000579 -0.001050
#  17490      automatic  full-size  0.000186 -0.000340
#  1673500       manual    compact  0.000311 -0.000724
#  735070     automatic  full-size  0.000298 -0.001030
#  248741     automatic   mid-size  0.000429 -0.000862
#  374129     automatic  full-size  0.000310 -0.000937
#  1610906       manual  full-size  0.001950 -0.003514  ,
#  'ram':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  634975   0.019917          ram   0.000020   0.000059  0.999801        clean
#  879412   0.017662          ram   0.000018   0.000070  0.999844        clean
#  1013552  0.017539          ram   0.000000   0.000053  0.999846        clean
#  1274584  0.037973          ram   0.000038   0.000113  0.999277        clean
#  1464669  0.009048          ram   0.000005   0.000027  0.999959        clean
#  ...           ...          ...        ...        ...       ...          ...
#  54116    0.201711          ram   0.000200   0.000600  0.979356        clean
#  1623008  0.014082          ram   0.000000   0.000042  0.999901        clean
#  1456520  0.086064          ram   0.000000   0.000256  0.996283        clean
#  1574376  0.020896          ram   0.000000   0.000062  0.999781        clean
#  1216327  0.994072          ram   0.000000   0.002978  0.089829        clean
#
#          transmission       size       lat      long
#  Id
#  634975     automatic  full-size  0.000359 -0.001180
#  879412     automatic  full-size  0.000378 -0.000734
#  1013552    automatic  full-size  0.000348 -0.000664
#  1274584    automatic  full-size  0.000551 -0.001863
#  1464669    automatic  full-size  0.000183 -0.000335
#  ...              ...        ...       ...       ...
#  54116      automatic  full-size  0.004911 -0.012269
#  1623008    automatic  full-size  0.000302 -0.000618
#  1456520    automatic  full-size  0.001727 -0.003170
#  1574376    automatic  full-size  0.000448 -0.000789
#  1216327       manual  full-size  0.023254 -0.056590
#
#  [8326 rows x 10 columns],
#  'chevrolet':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1051884  0.017451    chevrolet   0.000000   0.000053  0.999847        clean
#  1255387  0.017592    chevrolet   0.000000   0.000070  0.999845        clean
#  1388526  0.008329    chevrolet   0.000008   0.000033  0.999965        clean
#  746176   0.023666    chevrolet   0.000012   0.000096  0.999719        clean
#  1088447  0.027565    chevrolet   0.000000   0.000082  0.999619      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  482200   0.106388    chevrolet   0.000108   0.000431  0.994304        clean
#  765689   0.013254    chevrolet   0.000013   0.000040  0.999912        clean
#  1302371  0.008391    chevrolet   0.000004   0.000034  0.999965        clean
#  1700280  0.019752    chevrolet   0.000000   0.000078  0.999805        clean
#  53108    0.020658    chevrolet   0.000000   0.000082  0.999786        clean
#
#          transmission       size       lat      long
#  Id
#  1051884    automatic  full-size  0.000337 -0.000824
#  1255387    automatic  full-size  0.000264 -0.000862
#  1388526    automatic  full-size  0.000153 -0.000318
#  746176     automatic  full-size  0.000409 -0.001425
#  1088447    automatic  full-size  0.000495 -0.001187
#  ...              ...        ...       ...       ...
#  482200     automatic  full-size  0.001886 -0.006167
#  765689     automatic  full-size  0.000275 -0.000464
#  1302371    automatic  full-size  0.000137 -0.000352
#  1700280    automatic  full-size  0.000348 -0.000808
#  53108      automatic  full-size  0.000352 -0.000799
#
#  [38596 rows x 10 columns],
#  'infiniti':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  397885   0.014961     infiniti   0.000007   0.000045  0.999888        clean
#  774955   0.014998     infiniti   0.000015   0.000045  0.999887        clean
#  275304   0.012065     infiniti   0.000006   0.000036  0.999927        clean
#  778374   0.014341     infiniti   0.000007   0.000043  0.999897        clean
#  1406118  0.017601     infiniti   0.000000   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1596362  0.122574     infiniti   0.000122   0.000365  0.992446      salvage
#  886734   0.017618     infiniti   0.000018   0.000053  0.999844        clean
#  368452   0.017860     infiniti   0.000009   0.000053  0.999840        clean
#  155826   0.014850     infiniti   0.000015   0.000044  0.999889        clean
#  290069   0.013304     infiniti   0.000013   0.000040  0.999911        clean
#
#          transmission       size       lat      long
#  Id
#  397885     automatic  full-size  0.000251 -0.000645
#  774955     automatic  full-size  0.000314 -0.000534
#  275304     automatic  full-size  0.000232 -0.000493
#  778374     automatic  full-size  0.000298 -0.000508
#  1406118    automatic  full-size  0.000329 -0.000680
#  ...              ...        ...       ...       ...
#  1596362    automatic  full-size  0.002467 -0.004498
#  886734     automatic  full-size  0.000381 -0.000738
#  368452     automatic  full-size  0.000443 -0.001059
#  155826        manual    compact  0.000275 -0.000709
#  290069     automatic  full-size  0.000238 -0.000523
#
#  [1850 rows x 10 columns],
#  'nissan':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1233191  0.069281       nissan   0.000069   0.000138  0.997591        clean
#  1253597  0.036757       nissan   0.000018   0.000110  0.999322        clean
#  267134   0.025622       nissan   0.000013   0.000051  0.999671        clean
#  1340703  0.012807       nissan   0.000006   0.000026  0.999918        clean
#  927955   0.017610       nissan   0.000009   0.000035  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  331828   0.014626       nissan   0.000015   0.000044  0.999893        clean
#  126564   0.018580       nissan   0.000000   0.000056  0.999827        clean
#  689765   0.035923       nissan   0.000036   0.000071  0.999352        clean
#  1071667  0.017662       nissan   0.000000   0.000053  0.999844        clean
#  452074   0.013664       nissan   0.000000   0.000041  0.999906        clean
#
#          transmission       size       lat      long
#  Id
#  1233191    automatic    compact  0.001022 -0.003286
#  1253597    automatic  full-size  0.000579 -0.001941
#  267134     automatic    compact  0.000510 -0.001055
#  1340703    automatic    compact  0.000262 -0.000717
#  927955     automatic    compact  0.000374 -0.000732
#  ...              ...        ...       ...       ...
#  331828     automatic  full-size  0.000299 -0.000671
#  126564        manual  full-size  0.000363 -0.000801
#  689765     automatic  full-size  0.000667 -0.002154
#  1071667    automatic  full-size  0.000318 -0.000735
#  452074         other  full-size  0.000283 -0.000556
#
#  [11648 rows x 10 columns],
#  'mercedes-benz':              year   manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1132407  0.015139  mercedes-benz   0.000000   0.000045  0.999885        clean
#  424855   0.024005  mercedes-benz   0.000000   0.000072  0.999711        clean
#  1441207  0.058306  mercedes-benz   0.000000   0.000174  0.998295        clean
#  512103   0.016449  mercedes-benz   0.000016   0.000049  0.999864        clean
#  1719335  0.015628  mercedes-benz   0.000008   0.000063  0.999878        clean
#  ...           ...            ...        ...        ...       ...          ...
#  503575   0.017648  mercedes-benz   0.000000   0.000035  0.999844        clean
#  651785   0.017574  mercedes-benz   0.000009   0.000053  0.999845        clean
#  768324   0.022749  mercedes-benz   0.000000   0.000068  0.999741        clean
#  136234   0.018191  mercedes-benz   0.000018   0.000055  0.999834        clean
#  1219869  0.208073  mercedes-benz   0.000000   0.000619  0.978057        clean
#
#          transmission       size       lat      long
#  Id
#  1132407    automatic  full-size  0.000211 -0.000622
#  424855     automatic  full-size  0.000362 -0.001075
#  1441207    automatic  full-size  0.001209 -0.002546
#  512103     automatic    compact  0.000292 -0.000800
#  1719335    automatic  full-size  0.000274 -0.000605
#  ...              ...        ...       ...       ...
#  503575     automatic    compact  0.000384 -0.000624
#  651785     automatic  full-size  0.000367 -0.001090
#  768324     automatic  full-size  0.000480 -0.000802
#  136234     automatic  full-size  0.000320 -0.000969
#  1219869    automatic  full-size  0.002703 -0.010125
#
#  [4623 rows x 10 columns],
#  'lincoln':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  666678   0.040253      lincoln   0.000041   0.000163  0.999186        clean
#  1452091  0.017715      lincoln   0.000018   0.000035  0.999843        clean
#  1048858  0.017592      lincoln   0.000000   0.000053  0.999845        clean
#  1093648  0.016906      lincoln   0.000017   0.000067  0.999857        clean
#  393701   0.015525      lincoln   0.000015   0.000062  0.999879        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1296390  0.008052      lincoln   0.000000   0.000032  0.999968         lien
#  1681663  0.023886      lincoln   0.000012   0.000095  0.999714        clean
#  899443   0.017671      lincoln   0.000018   0.000053  0.999844        clean
#  1195349  0.012738      lincoln   0.000013   0.000051  0.999919        clean
#  1431385  0.040488      lincoln   0.000040   0.000121  0.999178        clean
#
#          transmission       size       lat      long
#  Id
#  666678     automatic  full-size  0.000692 -0.002386
#  1452091    automatic    compact  0.000353 -0.000650
#  1048858    automatic  full-size  0.000341 -0.000795
#  1093648    automatic  full-size  0.000295 -0.000716
#  393701     automatic  full-size  0.000236 -0.000679
#  ...              ...        ...       ...       ...
#  1296390    automatic  full-size  0.000131 -0.000380
#  1681663    automatic  full-size  0.000407 -0.000927
#  899443     automatic   mid-size  0.000376 -0.000725
#  1195349    automatic  full-size  0.000178 -0.000524
#  1431385    automatic  full-size  0.000852 -0.001766
#
#  [1831 rows x 10 columns],
#  'jeep':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  684464   0.015735         jeep   0.000000   0.000047  0.999876        clean
#  1678487  0.013805         jeep   0.000007   0.000028  0.999905        clean
#  1564129  0.017601         jeep   0.000000   0.000053  0.999845        clean
#  1098309  0.105771         jeep   0.000000   0.000210  0.994379        clean
#  950783   0.017169         jeep   0.000017   0.000051  0.999852        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1500587  0.012172         jeep   0.000000   0.000036  0.999926        clean
#  1097865  0.017574         jeep   0.000000   0.000053  0.999845        clean
#  1568000  0.009610         jeep   0.000000   0.000029  0.999954        clean
#  1452620  0.014109         jeep   0.000014   0.000042  0.999900        clean
#  1380486  0.017548         jeep   0.000009   0.000035  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  684464     automatic  full-size  0.000264 -0.000911
#  1678487       manual    compact  0.000243 -0.000547
#  1564129    automatic  full-size  0.000366 -0.000806
#  1098309    automatic    compact  0.001906 -0.004320
#  950783     automatic  full-size  0.000353 -0.000620
#  ...              ...        ...       ...       ...
#  1500587        other  full-size  0.000286 -0.000742
#  1097865    automatic  full-size  0.000317 -0.000736
#  1568000       manual   mid-size  0.000208 -0.000380
#  1452620    automatic  full-size  0.000283 -0.000523
#  1380486       manual    compact  0.000378 -0.000625
#
#  [11157 rows x 10 columns],
#  'gmc':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  651711   0.011446          gmc   0.000000   0.000046  0.999934        clean
#  1588096  0.042143          gmc   0.000000   0.000126  0.999110        clean
#  966154   0.011200          gmc   0.000011   0.000045  0.999937        clean
#  905925   0.017557          gmc   0.000018   0.000070  0.999846        clean
#  450846   0.010594          gmc   0.000000   0.000032  0.999944        clean
#  ...           ...          ...        ...        ...       ...          ...
#  160554   0.017539          gmc   0.000000   0.000053  0.999846        clean
#  664887   0.021041          gmc   0.000000   0.000063  0.999778        clean
#  1410064  0.009308          gmc   0.000009   0.000037  0.999957        clean
#  1113896  0.036938          gmc   0.000000   0.000111  0.999316        clean
#  1364919  0.011072          gmc   0.000000   0.000033  0.999938        clean
#
#          transmission       size       lat      long
#  Id
#  651711     automatic  full-size  0.000223 -0.000694
#  1588096    automatic  full-size  0.000904 -0.001590
#  966154     automatic  full-size  0.000259 -0.000531
#  905925     automatic  full-size  0.000371 -0.000746
#  450846         other  full-size  0.000217 -0.000431
#  ...              ...        ...       ...       ...
#  160554     automatic  full-size  0.000305 -0.000760
#  664887     automatic  full-size  0.000357 -0.001231
#  1410064    automatic  full-size  0.000178 -0.000360
#  1113896    automatic  full-size  0.000506 -0.001527
#  1364919    automatic  full-size  0.000236 -0.000632
#
#  [10274 rows x 10 columns],
# ...
#  1500087  0.016348       toyota   0.000000   0.000049  0.999866        clean
#  197143   0.021591       toyota   0.000022   0.000043  0.999766        clean
#  600566   0.017592       toyota   0.000000   0.000053  0.999845        clean
#  36814    0.014862       toyota   0.000000   0.000044  0.999889        clean
#  ...           ...          ...        ...        ...       ...          ...
#  572203   0.012773       toyota   0.000000   0.000038  0.999918        clean
#  860598   0.016634       toyota   0.000008   0.000050  0.999861        clean
#  1285643  0.020896       toyota   0.000021   0.000062  0.999781        clean
#  1645519  0.011098       toyota   0.000006   0.000022  0.999938        clean
#  1076549  0.017513       toyota   0.000000   0.000053  0.999846        clean
#
#          transmission       size       lat      long
#  Id
#  500124     automatic  full-size  0.000267 -0.000892
#  1500087    automatic  full-size  0.000388 -0.000955
#  197143     automatic    compact  0.000530 -0.001323
#  600566     automatic  full-size  0.000399 -0.001076
#  36814      automatic  full-size  0.000292 -0.000571
#  ...              ...        ...       ...       ...
#  572203        manual   mid-size  0.000286 -0.000784
#  860598     automatic   mid-size  0.000327 -0.000869
#  1285643    automatic  full-size  0.000298 -0.001006
#  1645519    automatic   mid-size  0.000249 -0.000496
#  1076549    automatic  full-size  0.000316 -0.000737
#
#  [17202 rows x 10 columns],
#  'fiat':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1503379  0.045452         fiat   0.000000   0.000136  0.998962        clean
#  1225886  0.037935         fiat   0.000038   0.000075  0.999278        clean
#  1277772  0.017715         fiat   0.000009   0.000035  0.999843      rebuilt
#  938046   0.017697         fiat   0.000000   0.000035  0.999843        clean
#  322196   0.032447         fiat   0.000000   0.000097  0.999471        clean
#  ...           ...          ...        ...        ...       ...          ...
#  336232   0.022711         fiat   0.000023   0.000045  0.999742        clean
#  768537   0.018654         fiat   0.000019   0.000037  0.999826        clean
#  20364    0.033216         fiat   0.000033   0.000050  0.999447      rebuilt
#  792765   0.014727         fiat   0.000000   0.000030  0.999891        clean
#  61244    0.020252         fiat   0.000020   0.000060  0.999794        clean
#
#          transmission         size       lat      long
#  Id
#  1503379       manual  sub-compact  0.001093 -0.002700
#  1225886       manual      compact  0.000620 -0.001808
#  1277772    automatic      compact  0.000279 -0.000935
#  938046        manual      compact  0.000367 -0.000627
#  322196     automatic    full-size  0.000792 -0.001983
#  ...              ...          ...       ...       ...
#  336232     automatic      compact  0.000317 -0.000931
#  768537        manual      compact  0.000390 -0.000671
#  20364      automatic      compact  0.000574 -0.001402
#  792765        manual      compact  0.000299 -0.000561
#  61244      automatic    full-size  0.000494 -0.001237
#
#  [314 rows x 10 columns],
#  'lexus':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1195520  0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1388186  0.016584        lexus   0.000008   0.000050  0.999862        clean
#  708929   0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1284522  0.008382        lexus   0.000004   0.000034  0.999965        clean
#  1567156  0.006256        lexus   0.000006   0.000019  0.999980        clean
#  ...           ...          ...        ...        ...       ...          ...
#  514706   0.017100        lexus   0.000017   0.000068  0.999853        clean
#  1249626  0.022283        lexus   0.000022   0.000067  0.999751        clean
#  1675277  0.017662        lexus   0.000000   0.000053  0.999844        clean
#  283635   0.016176        lexus   0.000016   0.000048  0.999869        clean
#  946580   0.017349        lexus   0.000000   0.000052  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  1195520    automatic  full-size  0.000245 -0.000727
#  1388186    automatic  full-size  0.000305 -0.000631
#  708929     automatic  full-size  0.000297 -0.001036
#  1284522    automatic  full-size  0.000124 -0.000414
#  1567156    automatic   mid-size  0.000135 -0.000236
#  ...              ...        ...       ...       ...
#  514706     automatic  full-size  0.000304 -0.000833
#  1249626    automatic   mid-size  0.000338 -0.001085
#  1675277    automatic  full-size  0.000315 -0.000716
#  283635     automatic  full-size  0.000246 -0.000703
#  946580     automatic  full-size  0.000355 -0.000631
#
#  [3012 rows x 10 columns],
#  'honda':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1099744  0.017662        honda   0.000018   0.000053  0.999844        clean
#  386522   0.033531        honda   0.000033   0.000100  0.999437        clean
#  1030588  0.010177        honda   0.000000   0.000020  0.999948        clean
#  1355767  0.029284        honda   0.000029   0.000058  0.999570        clean
#  608497   0.017680        honda   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1614746  0.074521        honda   0.000000   0.000222  0.997215        clean
#  1126982  0.069236        honda   0.000000   0.000206  0.997595        clean
#  64234    0.017574        honda   0.000000   0.000053  0.999845        clean
#  1684307  0.017583        honda   0.000009   0.000035  0.999845      rebuilt
#  1605370  0.012676        honda   0.000006   0.000025  0.999920        clean
#
#          transmission       size       lat      long
#  Id
#  1099744    automatic  full-size  0.000307 -0.000749
#  386522     automatic   mid-size  0.000723 -0.001340
#  1030588    automatic    compact  0.000223 -0.000525
#  1355767    automatic   mid-size  0.000647 -0.001064
#  608497        manual  full-size  0.000310 -0.001060
#  ...              ...        ...       ...       ...
#  1614746    automatic  full-size  0.001510 -0.002714
#  1126982    automatic  full-size  0.001044 -0.002974
#  64234          other  full-size  0.000399 -0.000647
#  1684307    automatic    compact  0.000305 -0.000685
#  1605370    automatic    compact  0.000272 -0.000481
#
#  [13143 rows x 10 columns],
#  'mercury':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1157283  0.017566      mercury   0.000009   0.000053  0.999845        clean
#  834053   0.007056      mercury   0.000004   0.000028  0.999975        clean
#  399248   0.011770      mercury   0.000006   0.000035  0.999931        clean
#  1490783  0.017293      mercury   0.000009   0.000070  0.999850        clean
#  587662   0.011811      mercury   0.000000   0.000035  0.999930        clean
#  ...           ...          ...        ...        ...       ...          ...
#  984418   0.010711      mercury   0.000011   0.000043  0.999942      rebuilt
#  1202222  0.014443      mercury   0.000007   0.000043  0.999895        clean
#  875215   0.017381      mercury   0.000009   0.000070  0.999849        clean
#  1614673  0.011790      mercury   0.000000   0.000047  0.999930        clean
#  1167053  0.019746      mercury   0.000000   0.000080  0.999805        clean
#
#          transmission       size       lat      long
#  Id
#  1157283    automatic  full-size  0.000267 -0.000759
#  834053     automatic   mid-size  0.000137 -0.000368
#  399248     automatic  full-size  0.000184 -0.000503
#  1490783    automatic  full-size  0.000426 -0.001074
#  587662     automatic  full-size  0.000265 -0.000726
#  ...              ...        ...       ...       ...
#  984418     automatic  full-size  0.000235 -0.000514
#  1202222    automatic  full-size  0.000331 -0.000782
#  875215        manual  full-size  0.000376 -0.000755
#  1614673    automatic  full-size  0.000241 -0.000431
#  1167053    automatic  full-size  0.000280 -0.000819
#
#  [1451 rows x 10 columns],
#  'audi':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1096521  0.012702         audi   0.000000   0.000051  0.999919        clean
#  840911   0.006488         audi   0.000003   0.000019  0.999979        clean
#  1284719  0.264102         audi   0.000000   0.000785  0.964403        clean
#  748622   0.015722         audi   0.000016   0.000031  0.999876        clean
#  1473785  0.017550         audi   0.000018   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  330380   0.022126         audi   0.000000   0.000044  0.999755        clean
#  679075   0.021351         audi   0.000021   0.000064  0.999771        clean
#  1466507  0.017557         audi   0.000000   0.000053  0.999846        clean
#  222383   0.017758         audi   0.000000   0.000053  0.999842        clean
#  1579969  0.022294         audi   0.000000   0.000044  0.999751        clean
#
#          transmission       size       lat      long
#  Id
#  1096521    automatic  full-size  0.000229 -0.000549
#  840911     automatic  full-size  0.000131 -0.000340
#  1284719    automatic  full-size  0.003428 -0.012844
#  748622     automatic    compact  0.000297 -0.000948
#  1473785    automatic   mid-size  0.000428 -0.001074
#  ...              ...        ...       ...       ...
#  330380     automatic   mid-size  0.000468 -0.000780
#  679075     automatic  full-size  0.000362 -0.001246
#  1466507    automatic    compact  0.000358 -0.000652
#  222383     automatic  full-size  0.000316 -0.000696
#  1579969    automatic    compact  0.000478 -0.000846
#
#  [2232 rows x 10 columns],
#  'saturn':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1643997  0.016723       saturn   0.000000   0.000050  0.999860        clean
#  907300   0.011776       saturn   0.000006   0.000024  0.999931        clean
#  1464649  0.024218       saturn   0.000024   0.000072  0.999706        clean
#  1613311  0.032338       saturn   0.000032   0.000097  0.999476        clean
#  692353   0.011255       saturn   0.000000   0.000022  0.999936        clean
#  ...           ...          ...        ...        ...       ...          ...
#  587410   0.017522       saturn   0.000000   0.000053  0.999846        clean
#  121778   0.017714       saturn   0.000000   0.000035  0.999843        clean
#  892908   0.017618       saturn   0.000009   0.000053  0.999844        clean
#  278705   0.017583       saturn   0.000000   0.000053  0.999845        clean
#  786965   0.017566       saturn   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long
#  Id
#  1643997    automatic  full-size  0.000377 -0.000765
#  907300     automatic    compact  0.000253 -0.000492
#  1464649    automatic  full-size  0.000479 -0.000904
#  1613311    automatic  full-size  0.000678 -0.001226
#  692353     automatic    compact  0.000207 -0.000673
#  ...              ...        ...       ...       ...
#  587410        manual  full-size  0.000395 -0.001080
#  121778        manual   mid-size  0.000335 -0.001002
#  892908     automatic  full-size  0.000378 -0.000730
#  278705        manual  full-size  0.000317 -0.000705
#  786965     automatic  full-size  0.000360 -0.000683
#
#  [1345 rows x 10 columns],
#  'datsun':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  154867   0.082865       datsun   0.000084   0.000251  0.996555        clean
#  1034159  0.038011       datsun   0.000038   0.000115  0.999275        clean
#  127388   0.017355       datsun   0.000018   0.000053  0.999849        clean
#  1691790  0.017355       datsun   0.000000   0.000053  0.999849        clean
#  1209077  0.017372       datsun   0.000009   0.000053  0.999849        clean
#  ...           ...          ...        ...        ...       ...          ...
#  595616   0.017372       datsun   0.000009   0.000053  0.999848        clean
#  1073326  0.013304       datsun   0.000000   0.000040  0.999911        clean
#  285527   0.017293       datsun   0.000000   0.000053  0.999850        clean
#  854044   0.017320       datsun   0.000009   0.000053  0.999850        clean
#  588840   0.017364       datsun   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long
#  Id
#  154867        manual    compact  0.001670 -0.003106
#  1034159       manual    compact  0.000751 -0.001818
#  127388        manual    compact  0.000287 -0.001028
#  1691790       manual  full-size  0.000309 -0.000697
#  1209077       manual  full-size  0.000412 -0.001001
#  ...              ...        ...       ...       ...
#  595616        manual  full-size  0.000400 -0.001079
#  1073326    automatic  full-size  0.000243 -0.000581
#  285527        manual  full-size  0.000357 -0.000983
#  854044     automatic    compact  0.000336 -0.000919
#  588840        manual  full-size  0.000371 -0.001078
#
#  [79 rows x 10 columns],
#  'unknown':              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  771920   0.014356      unknown   0.000007   0.000029  0.999897        clean
#  138219   0.017574      unknown   0.000000   0.000070  0.999845        clean
#  546294   0.015222      unknown   0.000008   0.000031  0.999884        clean
#  889246   0.012744      unknown   0.000000   0.000038  0.999919        clean
#  205327   0.039342      unknown   0.000039   0.000118  0.999224        clean
#  ...           ...          ...        ...        ...       ...          ...
#  349037   0.017609      unknown   0.000000   0.000053  0.999844        clean
#  1131359  0.017627      unknown   0.000000   0.000053  0.999844        clean
#  327284   0.055531      unknown   0.000056   0.000225  0.998454        clean
#  1302188  0.007224      unknown   0.000004   0.000022  0.999974        clean
#  1396770  0.017285      unknown   0.000000   0.000053  0.999850        clean
#
#          transmission       size       lat      long
#  Id
#  771920        manual    compact  0.000302 -0.000515
#  138219     automatic  full-size  0.000238 -0.000704
#  546294        manual    compact  0.000296 -0.000587
#  889246     automatic  full-size  0.000274 -0.000531
#  205327        manual  full-size  0.000917 -0.001897
#  ...              ...        ...       ...       ...
#  349037     automatic  full-size  0.000325 -0.001051
#  1131359    automatic  full-size  0.000245 -0.000725
#  327284        manual  full-size  0.001231 -0.002054
#  1302188       manual  full-size  0.000121 -0.000305
#  1396770    automatic  full-size  0.000338 -0.000693
#
#  [20048 rows x 10 columns]}

# %%
for i, df in X_sub_dec.items():
    df['price'] = abs(y_sub[i])

# %%
list(X_sub_dec.values())
# Out:
# [             year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  873208   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  1615923  0.017548      ferrari   0.000000   0.000053  0.999846        clean
#  1245573  0.062069      ferrari   0.000062   0.000373  0.998067        clean
#  657050   0.017443      ferrari   0.000000   0.000053  0.999847        clean
#  682622   0.116723      ferrari   0.000117   0.000467  0.993139        clean
#  1676954  0.997843      ferrari   0.000000   0.002976  0.049595        clean
#  576328   0.110840      ferrari   0.000000   0.000331  0.993812        clean
#  930632   0.099008      ferrari   0.000000   0.000396  0.995075      salvage
#  336544   0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  684874   0.074264      ferrari   0.000000   0.000296  0.997229        clean
#  622772   0.017522      ferrari   0.000018   0.000070  0.999846      salvage
#  1690604  0.033438      ferrari   0.000034   0.000135  0.999440        clean
#  10603    0.074264      ferrari   0.000074   0.000296  0.997229        clean
#  659788   0.113560      ferrari   0.000056   0.000452  0.993506        clean
#  728801   0.017715      ferrari   0.000000   0.000053  0.999842        clean
#  1482578  0.359490      ferrari   0.000179   0.001072  0.932851        clean
#  495319   0.127177      ferrari   0.000127   0.000507  0.991852        clean
#  369481   0.060495      ferrari   0.000060   0.000181  0.998160        clean
#  683400   0.479265      ferrari   0.000476   0.001903  0.877185        clean
#  1125515  0.152945      ferrari   0.000152   0.000608  0.988214      rebuilt
#  627533   0.070377      ferrari   0.000070   0.000211  0.997511        clean
#  629673   0.070927      ferrari   0.000000   0.000425  0.997472        clean
#  1159787  0.051496      ferrari   0.000051   0.000205  0.998671      rebuilt
#  44047    0.068867      ferrari   0.000034   0.000275  0.997615        clean
#  1014750  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  742494   0.153949      ferrari   0.000153   0.000613  0.988030        clean
#  1015452  0.040807      ferrari   0.000000   0.000162  0.999166        clean
#  825776   0.011901      ferrari  -0.000006   0.000047  0.999929      salvage
#  339032   0.073293      ferrari   0.000073   0.000220  0.997299        clean
#  228087   0.017434      ferrari   0.000000   0.000053  0.999848      rebuilt
#  630726   0.045068      ferrari   0.000045   0.000182  0.998980        clean
#  669317   0.074264      ferrari   0.000074   0.000296  0.997229        clean
#
#          transmission         size       lat      long          price
#  Id
#  873208     automatic    full-size  0.002119 -0.004230   76044.795264
#  1615923    automatic    full-size  0.000377 -0.000691   66710.236176
#  1245573       manual     mid-size  0.000943 -0.003033   76569.640631
#  657050        manual    full-size  0.000339 -0.001065   71232.047960
#  682622        manual      compact  0.001981 -0.006881  130875.054506
#  1676954       manual    full-size  0.017802 -0.039033  463898.867668
#  576328         other  sub-compact  0.002514 -0.006762  118374.953498
#  930632     automatic    full-size  0.002119 -0.004230   76044.795264
#  336544        manual    full-size  0.001957 -0.006105  103799.227364
#  684874     automatic    full-size  0.001249 -0.004308   84366.620187
#  622772        manual    full-size  0.000330 -0.001074   74424.330107
#  1690604       manual      compact  0.000602 -0.001329   75081.109075
#  10603      automatic    full-size  0.001249 -0.004308  106222.403240
#  659788     automatic     mid-size  0.002013 -0.006819  115283.217484
#  728801     automatic    full-size  0.000299 -0.001039   70341.139850
#  1482578        other    full-size  0.008711 -0.021882  266584.072124
#  495319     automatic    full-size  0.002118 -0.007096  130742.121972
#  369481     automatic    full-size  0.001490 -0.003723  113796.241487
#  683400     automatic    full-size  0.007997 -0.027983  266377.275716
#  1125515    automatic    full-size  0.001957 -0.006105  103799.227364
#  627533        manual    full-size  0.001243 -0.004252  114914.574047
#  629673     automatic    full-size  0.001200 -0.004154   68119.904471
#  1159787    automatic    full-size  0.000668 -0.002054   78550.521749
#  44047      automatic    full-size  0.001675 -0.004209  102134.548024
#  1014750    automatic      compact  0.000796 -0.001535   65412.585169
#  742494     automatic     mid-size  0.002803 -0.009340  156378.510425
#  1015452    automatic    full-size  0.000792 -0.001534   65361.869542
#  825776     automatic    full-size  0.000244 -0.000447   61911.779472
#  339032     automatic    full-size  0.001797 -0.004488  123875.311795
#  228087        manual    full-size  0.000267 -0.000799   66839.951139
#  630726        manual    full-size  0.000774 -0.002688   90668.348929
#  669317     automatic    full-size  0.001249 -0.004308  106222.403240  ,
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  144337   0.011551          kia   0.000011   0.000034  0.999933        clean
#  1158202  0.037935          kia   0.000000   0.000113  0.999279      rebuilt
#  539918   0.022257          kia   0.000011   0.000066  0.999752        clean
#  1223914  0.017662          kia   0.000000   0.000053  0.999844        clean
#  1532059  0.015848          kia   0.000016   0.000032  0.999874        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1106624  0.019163          kia   0.000000   0.000057  0.999816        clean
#  1219609  0.022623          kia   0.000022   0.000045  0.999743        clean
#  1340428  0.057504          kia   0.000057   0.000114  0.998339        clean
#  1263028  0.016756          kia   0.000017   0.000050  0.999859        clean
#  720330   0.022801          kia   0.000000   0.000068  0.999739        clean
#
#          transmission       size       lat      long         price
#  Id
#  144337     automatic   mid-size  0.000193 -0.000496   7665.610541
#  1158202    automatic  full-size  0.000485 -0.001517   9083.733075
#  539918     automatic  full-size  0.000398 -0.001039   8378.135545
#  1223914    automatic  full-size  0.000297 -0.000865   8087.500640
#  1532059    automatic    compact  0.000329 -0.000685   7926.334714
#  ...              ...        ...       ...       ...           ...
#  1106624    automatic  full-size  0.000283 -0.000784   8073.235038
#  1219609    automatic    compact  0.000294 -0.001104   8291.045424
#  1340428    automatic    compact  0.001059 -0.003241  10741.145214
#  1263028    automatic  full-size  0.000248 -0.000796   8007.316360
#  720330     automatic  full-size  0.000384 -0.001322   8527.829701
#
#  [3629 rows x 11 columns],
#               year     manufacturer  condition  cylinders  odometer  \
#  Id
#  1295554  0.017513  harley-davidson   0.000018   0.000053  0.999846
#  442879   0.448546  harley-davidson   0.000447   0.001340  0.893519
#  181606   0.017548  harley-davidson   0.000000   0.000053  0.999846
#  1010170  0.152648  harley-davidson   0.000152   0.000456  0.988259
#  310213   0.201971  harley-davidson   0.000101   0.000605  0.979302
#  ...           ...              ...        ...        ...       ...
#  782715   0.280042  harley-davidson   0.000278   0.000835  0.959906
#  1679923  0.017618  harley-davidson   0.000000   0.000035  0.999845
#  1604512  0.009118  harley-davidson   0.000005   0.000036  0.999958
#  494891   0.017592  harley-davidson   0.000009   0.000070  0.999845
#  1615057  0.017618  harley-davidson   0.000000   0.000053  0.999845
#
#          title_status transmission       size       lat      long         price
#  Id
#  1295554         lien       manual  full-size  0.000284 -0.000844   9579.007092
#  442879         clean       manual  full-size  0.009187 -0.018545   9937.423490
#  181606         clean       manual  full-size  0.000310 -0.000937   9695.702791
#  1010170        clean       manual  full-size  0.002562 -0.006000   9823.694894
#  310213         clean       manual  full-size  0.004760 -0.012334  11333.577673
#  ...              ...          ...        ...       ...       ...           ...
#  782715         clean       manual  full-size  0.005688 -0.011120   9330.451731
#  1679923        clean    automatic    compact  0.000306 -0.000680   5389.710030
#  1604512        clean    automatic  full-size  0.000200 -0.000345  11652.246444
#  494891       rebuilt    automatic  full-size  0.000282 -0.000974  13829.907945
#  1615057        clean    automatic  full-size  0.000356 -0.000650   9592.094673
#
#  [138 rows x 11 columns],
#              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  935779  0.017689       morgan   0.000018   0.000053  0.999843        clean
#  842649  0.989985       morgan   0.000984   0.002951  0.129834        clean
#
#         transmission       size       lat      long         price
#  Id
#  935779        other  full-size  0.000367 -0.000627  4.102943e+04
#  842649       manual  full-size  0.019673 -0.051725  2.703356e+06  ,
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  830219   0.065874        mazda   0.000000   0.000196  0.997821        clean
#  314758   0.088681        mazda   0.000088   0.000176  0.996052         lien
#  999201   0.017504        mazda  -0.000009   0.000053  0.999846        clean
#  421641   0.357951        mazda   0.000355   0.000710  0.933298        clean
#  1101173  0.044927        mazda   0.000045   0.000089  0.998988        clean
#  ...           ...          ...        ...        ...       ...          ...
#  317870   0.052952        mazda   0.000000   0.000158  0.998591        clean
#  860527   0.011758        mazda   0.000006   0.000035  0.999931        clean
#  287062   0.017609        mazda   0.000018   0.000053  0.999844        clean
#  1410661  0.021987        mazda   0.000000   0.000066  0.999758        clean
#  815566   0.017636        mazda   0.000000   0.000053  0.999844        clean
#
#          transmission       size       lat      long         price
#  Id
#  830219     automatic  full-size  0.001251 -0.003420  10222.011643
#  314758     automatic    compact  0.001922 -0.003498  11490.794670
#  999201        manual  full-size  0.000290 -0.000704   6226.023134
#  421641     automatic   mid-size  0.010853 -0.026590  34439.845540
#  1101173    automatic    compact  0.000675 -0.001820   8186.429833
#  ...              ...        ...       ...       ...           ...
#  317870     automatic  full-size  0.001292 -0.003227   9561.620945
#  860527        manual   mid-size  0.000233 -0.000619   5867.595113
#  287062     automatic  full-size  0.000296 -0.001003   6359.124979
#  1410661    automatic  full-size  0.000409 -0.000870   6577.466887
#  815566     automatic  full-size  0.000358 -0.000664   6244.375673
#
#  [3462 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1565975  0.017583         mini   0.000009   0.000035  0.999845        clean
#  711505   0.031548         mini   0.000000   0.000063  0.999500        clean
#  231273   0.017662         mini   0.000000   0.000053  0.999844        clean
#  1160215  0.038242         mini   0.000038   0.000114  0.999267        clean
#  1529924  0.012609         mini   0.000006   0.000025  0.999920        clean
#  ...           ...          ...        ...        ...       ...          ...
#  691349   0.021114         mini   0.000021   0.000063  0.999776        clean
#  584522   0.017671         mini   0.000000   0.000053  0.999843        clean
#  1530742  0.042973         mini   0.000043   0.000128  0.999074        clean
#  1452433  0.024708         mini   0.000025   0.000049  0.999694        clean
#  109704   0.029453         mini   0.000029   0.000088  0.999565        clean
#
#          transmission         size       lat      long        price
#  Id
#  1565975       manual      compact  0.000365 -0.000822  7442.631629
#  711505     automatic      compact  0.000553 -0.001894  8901.841579
#  231273     automatic    full-size  0.000273 -0.000819  7380.557053
#  1160215    automatic    full-size  0.000531 -0.001562  9117.703073
#  1529924    automatic    full-size  0.000250 -0.000542  6911.389910
#  ...              ...          ...       ...       ...          ...
#  691349     automatic    full-size  0.000385 -0.001256  7707.508216
#  584522        manual    full-size  0.000387 -0.001082  7523.944972
#  1530742       manual  sub-compact  0.000890 -0.001842  9834.414541
#  1452433       manual      compact  0.000500 -0.000921  8068.783088
#  109704     automatic    full-size  0.000446 -0.001302  8374.957643
#
#  [1040 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  305757   0.017662        volvo   0.000018   0.000044  0.999844        clean
#  926352   0.010121        volvo   0.000005   0.000025  0.999949        clean
#  671502   0.016274        volvo   0.000008   0.000041  0.999867        clean
#  431731   0.018599        volvo   0.000009   0.000056  0.999827        clean
#  843681   0.007766        volvo   0.000004   0.000023  0.999970        clean
#  ...           ...          ...        ...        ...       ...          ...
#  118994   0.017583        volvo   0.000000   0.000053  0.999845        clean
#  1698378  0.025447        volvo   0.000025   0.000076  0.999676      rebuilt
#  1401417  0.012258        volvo   0.000006   0.000031  0.999925        clean
#  761453   0.018804        volvo   0.000019   0.000047  0.999823        clean
#  756304   0.017680        volvo   0.000000   0.000053  0.999843        clean
#
#          transmission         size       lat      long         price
#  Id
#  305757     automatic  sub-compact  0.000354 -0.000678   8971.891379
#  926352     automatic     mid-size  0.000218 -0.000429   8012.654337
#  671502     automatic     mid-size  0.000314 -0.000987   9198.132552
#  431731     automatic    full-size  0.000278 -0.000835   9453.738633
#  843681     automatic    full-size  0.000154 -0.000412   7894.942625
#  ...              ...          ...       ...       ...           ...
#  118994     automatic    full-size  0.000267 -0.000740   9189.283283
#  1698378    automatic     mid-size  0.000453 -0.001016  10280.623026
#  1401417       manual     mid-size  0.000234 -0.000483   8281.602350
#  761453     automatic    full-size  0.000395 -0.000666   9026.928075
#  756304     automatic    full-size  0.000374 -0.000627   8924.361995
#
#  [1675 rows x 11 columns],
#              year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  764904  0.017601       subaru   0.000000   0.000053  0.999845        clean
#  330867  0.017513       subaru   0.000000   0.000053  0.999846        clean
#  608763  0.007673       subaru   0.000000   0.000015  0.999970        clean
#  769396  0.024563       subaru   0.000024   0.000049  0.999698        clean
#  938823  0.017610       subaru   0.000009   0.000035  0.999845        clean
#  ...          ...          ...        ...        ...       ...          ...
#  704741  0.058687       subaru   0.000000   0.000175  0.998270        clean
#  730006  0.022093       subaru   0.000022   0.000044  0.999755        clean
#  963343  0.011434       subaru   0.000000   0.000034  0.999934        clean
#  829242  0.011216       subaru   0.000000   0.000033  0.999937        clean
#  63033   0.017539       subaru  -0.000009   0.000035  0.999846        clean
#
#         transmission       size       lat      long         price
#  Id
#  764904    automatic  full-size  0.000372 -0.000633   9238.599211
#  330867    automatic  full-size  0.000513 -0.001182   9458.492159
#  608763    automatic   mid-size  0.000135 -0.000464   8393.990056
#  769396    automatic  full-size  0.000513 -0.000886   9705.863093
#  938823    automatic   mid-size  0.000363 -0.000632   9148.408762
#  ...             ...        ...       ...       ...           ...
#  704741       manual  full-size  0.001124 -0.003534  12823.929089
#  730006       manual    compact  0.000428 -0.001330   9615.572707
#  963343    automatic  full-size  0.000266 -0.000524   8766.319021
#  829242        other  full-size  0.000224 -0.000586   8738.855995
#  63033     automatic    compact  0.000364 -0.000800   9165.629719
#
#  [4341 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1211117  0.011939        buick   0.000000   0.000036  0.999928        clean
#  947857   0.016358        buick   0.000000   0.000049  0.999866        clean
#  1113129  0.021282        buick   0.000011   0.000064  0.999773        clean
#  170062   0.019698        buick   0.000020   0.000059  0.999806        clean
#  1488852  0.017680        buick   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  511377   0.013507        buick   0.000013   0.000040  0.999909        clean
#  1289744  0.017618        buick   0.000000   0.000053  0.999844        clean
#  923478   0.017548        buick   0.000018   0.000053  0.999846        clean
#  121897   0.019108        buick   0.000000   0.000057  0.999817        clean
#  205239   0.017557        buick   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long        price
#  Id
#  1211117    automatic  full-size  0.000284 -0.000664  6322.169023
#  947857     automatic  full-size  0.000339 -0.000590  6442.202823
#  1113129    automatic  full-size  0.000292 -0.000878  6804.307177
#  170062     automatic  full-size  0.000400 -0.000716  6906.595467
#  1488852    automatic  full-size  0.000406 -0.001047  6812.849763
#  ...              ...        ...       ...       ...          ...
#  511377     automatic  full-size  0.000238 -0.000657  6474.164505
#  1289744    automatic  full-size  0.000258 -0.000865  6543.273457
#  923478     automatic  full-size  0.000380 -0.000725  6812.860860
#  121897     automatic  full-size  0.000352 -0.001078  6805.051394
#  205239     automatic  full-size  0.000412 -0.000850  6700.391412
#
#  [3399 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  507587   0.071247     cadillac   0.000000   0.000212  0.997452        clean
#  2265     0.998960     cadillac   0.001007   0.003021  0.000000        clean
#  142638   0.038702     cadillac   0.000038   0.000077  0.999249        clean
#  1377147  0.017680     cadillac   0.000000   0.000053  0.999843        clean
#  1193213  0.020250     cadillac   0.000010   0.000081  0.999795      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  898890   0.012954     cadillac   0.000006   0.000039  0.999916         lien
#  501516   0.028257     cadillac   0.000000   0.000084  0.999600        clean
#  415087   0.066391     cadillac   0.000066   0.000264  0.997779        clean
#  1527196  0.017548     cadillac   0.000000   0.000053  0.999846        clean
#  1519119  0.017337     cadillac   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long         price
#  Id
#  507587     automatic  full-size  0.001257 -0.003451  26890.336980
#  2265       automatic  full-size  0.021250 -0.040215  12137.034507
#  142638     automatic   mid-size  0.000589 -0.001696  23145.633360
#  1377147    automatic  full-size  0.000383 -0.000628  15146.808538
#  1193213    automatic  full-size  0.000274 -0.000832  16464.640934
#  ...              ...        ...       ...       ...           ...
#  898890     automatic  full-size  0.000289 -0.000554  14668.284472
#  501516     automatic   mid-size  0.000611 -0.000989  16977.389926
#  415087     automatic  full-size  0.002018 -0.004945  25065.783757
#  1527196    automatic  full-size  0.000349 -0.000757  15441.213101
#  1519119    automatic  full-size  0.000366 -0.000747  15279.030727
#
#  [3682 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  629957   0.088878          bmw   0.000088   0.000176  0.996028        clean
#  370879   0.090656          bmw   0.000090   0.000270  0.995864        clean
#  670648   0.057473          bmw   0.000000   0.000114  0.998340        clean
#  1170904  0.019386          bmw   0.000000   0.000058  0.999812        clean
#  627499   0.020465          bmw   0.000010   0.000082  0.999790        clean
#  ...           ...          ...        ...        ...       ...          ...
#  762018   0.013881          bmw   0.000007   0.000042  0.999903        clean
#  412066   0.036764          bmw   0.000037   0.000110  0.999323        clean
#  266383   0.055885          bmw   0.000055   0.000111  0.998433      rebuilt
#  827094   0.025142          bmw   0.000025   0.000050  0.999683        clean
#  688556   0.009852          bmw   0.000005   0.000039  0.999951        clean
#
#          transmission       size       lat      long          price
#  Id
#  629957     automatic    compact  0.001506 -0.005216   80618.372051
#  370879     automatic  full-size  0.002213 -0.005539   93795.092995
#  670648     automatic    compact  0.001105 -0.003458  139124.718687
#  1170904    automatic  full-size  0.000263 -0.000795  166344.876557
#  627499     automatic  full-size  0.000376 -0.001240  169382.316414
#  ...              ...        ...       ...       ...            ...
#  762018        manual   mid-size  0.000293 -0.000502  173971.785382
#  412066     automatic    compact  0.000697 -0.001548  137210.678681
#  266383     automatic   mid-size  0.001295 -0.002554  119426.507184
#  827094     automatic    compact  0.000500 -0.000956  155369.706845
#  688556     automatic  full-size  0.000185 -0.000596  182407.273530
#
#  [6302 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  527762   0.017689   mitsubishi   0.000018   0.000053  0.999843        clean
#  1247933  0.017645   mitsubishi   0.000000   0.000053  0.999844      salvage
#  1675559  0.017594   mitsubishi   0.000018   0.000053  0.999845        clean
#  724442   0.023753   mitsubishi   0.000024   0.000071  0.999717        clean
#  1092376  0.017627   mitsubishi   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  957482   0.045476   mitsubishi   0.000045   0.000136  0.998964        clean
#  210130   0.030526   mitsubishi   0.000000   0.000091  0.999533        clean
#  1500155  0.074420   mitsubishi   0.000000   0.000221  0.997216        clean
#  658852   0.017513   mitsubishi   0.000000   0.000053  0.999846        clean
#  1304023  0.017522   mitsubishi   0.000000   0.000053  0.999846        clean
#
#          transmission       size       lat      long          price
#  Id
#  527762     automatic  full-size  0.000312 -0.000857  340079.123387
#  1247933    automatic  full-size  0.000230 -0.000861  340642.808915
#  1675559    automatic   mid-size  0.000311 -0.000707  336321.634284
#  724442     automatic  full-size  0.000462 -0.001455  336254.558313
#  1092376    automatic  full-size  0.000313 -0.000780  338125.685762
#  ...              ...        ...       ...       ...            ...
#  957482        manual  full-size  0.000938 -0.001649  273546.521072
#  210130         other  full-size  0.000454 -0.001365  313772.584094
#  1500155    automatic  full-size  0.001705 -0.004393  236989.528743
#  658852        manual  full-size  0.000312 -0.001060  342482.932995
#  1304023    automatic  full-size  0.000288 -0.000736  334886.359845
#
#  [1678 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  296855   0.017610        dodge   0.000000   0.000053  0.999845        clean
#  1239902  0.014573        dodge   0.000000   0.000029  0.999894        clean
#  1305765  0.017583        dodge   0.000000   0.000052  0.999845        clean
#  1234416  0.017706        dodge   0.000000   0.000053  0.999843        clean
#  491202   0.011105        dodge   0.000006   0.000056  0.999938        clean
#  ...           ...          ...        ...        ...       ...          ...
#  492086   0.013964        dodge   0.000007   0.000042  0.999902        clean
#  649565   0.016274        dodge   0.000016   0.000032  0.999867        clean
#  909774   0.024101        dodge   0.000000   0.000096  0.999709        clean
#  585898   0.017267        dodge   0.000000   0.000053  0.999850        clean
#  662527   0.017406        dodge  -0.000009   0.000052  0.999848      salvage
#
#          transmission       size       lat      long          price
#  Id
#  296855     automatic  full-size  0.000361 -0.000708  183046.879673
#  1239902    automatic    compact  0.000201 -0.000706  192218.176678
#  1305765    automatic  full-size  0.000286 -0.000732  187218.503743
#  1234416    automatic  full-size  0.000261 -0.000839  189685.061885
#  491202     automatic  full-size  0.000190 -0.000618  192106.274173
#  ...              ...        ...       ...       ...            ...
#  492086     automatic  full-size  0.000232 -0.000778  190457.058873
#  649565     automatic   mid-size  0.000304 -0.000978  186583.810560
#  909774     automatic  full-size  0.000507 -0.001034  177209.917949
#  585898        manual   mid-size  0.000405 -0.001087  184994.713875
#  662527     automatic   mid-size  0.000284 -0.001018  192003.145100
#
#  [11237 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  16156    0.012402     chrysler   0.000006   0.000037  0.999923        clean
#  1442002  0.017601     chrysler   0.000000   0.000053  0.999845        clean
#  1636834  0.017610     chrysler   0.000018   0.000053  0.999845        clean
#  290057   0.016070     chrysler   0.000008   0.000048  0.999871        clean
#  1496219  0.068258     chrysler   0.000000   0.000203  0.997658        clean
#  ...           ...          ...        ...        ...       ...          ...
#  138193   0.012537     chrysler   0.000012   0.000025  0.999921        clean
#  230387   0.017610     chrysler   0.000000   0.000053  0.999845        clean
#  1110817  0.015437     chrysler   0.000015   0.000046  0.999881        clean
#  885711   0.018253     chrysler   0.000009   0.000054  0.999833        clean
#  373566   0.017423     chrysler   0.000017   0.000052  0.999848        clean
#
#          transmission       size       lat      long          price
#  Id
#  16156      automatic  full-size  0.000226 -0.000550  210604.867254
#  1442002    automatic  full-size  0.000366 -0.000769  200734.275403
#  1636834    automatic   mid-size  0.000383 -0.000782  195886.480176
#  290057     automatic  full-size  0.000285 -0.000630  204816.919903
#  1496219    automatic  full-size  0.001565 -0.004033  138457.130892
#  ...              ...        ...       ...       ...            ...
#  138193     automatic    compact  0.000209 -0.000698  213588.952278
#  230387     automatic  full-size  0.000266 -0.000790  211633.507658
#  1110817    automatic  full-size  0.000228 -0.000637  209805.648510
#  885711     automatic  full-size  0.000391 -0.000759  195873.775173
#  373566     automatic   mid-size  0.000352 -0.000682  196847.934377
#
#  [4542 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  208608   0.034637   land rover   0.000034   0.000138  0.999397        clean
#  608308   0.017645   land rover   0.000000   0.000053  0.999844        clean
#  1681805  0.019323   land rover   0.000019   0.000077  0.999813        clean
#  1538357  0.017697   land rover   0.000018   0.000053  0.999843        clean
#  1199177  0.017539   land rover   0.000000   0.000053  0.999846        clean
#  ...           ...          ...        ...        ...       ...          ...
#  369422   0.011005   land rover   0.000005   0.000033  0.999939        clean
#  398722   0.017610   land rover   0.000018   0.000070  0.999845        clean
#  667988   0.017225   land rover   0.000017   0.000069  0.999851        clean
#  949042   0.019610   land rover   0.000000   0.000059  0.999807        clean
#  1367703  0.008951   land rover   0.000000   0.000036  0.999960        clean
#
#          transmission       size       lat      long         price
#  Id
#  208608     automatic   mid-size  0.000845 -0.002115  21969.137805
#  608308     automatic  full-size  0.000323 -0.001069  17279.243004
#  1681805    automatic  full-size  0.000329 -0.000749  17071.108397
#  1538357    automatic  full-size  0.000308 -0.000936  17204.494270
#  1199177       manual  full-size  0.000241 -0.000726  16587.673365
#  ...              ...        ...       ...       ...           ...
#  369422     automatic  full-size  0.000270 -0.000676  15963.057562
#  398722     automatic  full-size  0.000295 -0.000762  16795.406793
#  667988     automatic  full-size  0.000320 -0.001046  17180.494693
#  949042     automatic  full-size  0.000407 -0.000712  17333.672810
#  1367703    automatic  full-size  0.000195 -0.000521  15197.289010
#
#  [796 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  974298   0.012991         ford   0.000006   0.000052  0.999915        clean
#  1473203  0.016925         ford   0.000000   0.000053  0.999856      missing
#  972509   0.016491         ford   0.000016   0.000066  0.999864        clean
#  656907   0.116697         ford   0.000000   0.000347  0.993140        clean
#  525619   0.017645         ford   0.000018   0.000053  0.999844        clean
#  ...           ...          ...        ...        ...       ...          ...
#  24233    0.012388         ford   0.000012   0.000037  0.999923        clean
#  1184470  0.017715         ford   0.000018   0.000053  0.999843        clean
#  1533790  0.007103         ford   0.000004   0.000028  0.999975        clean
#  1026234  0.017610         ford   0.000000   0.000053  0.999845        clean
#  1541257  0.019554         ford   0.000010   0.000078  0.999808        clean
#
#          transmission         size       lat      long         price
#  Id
#  974298     automatic    full-size  0.000309 -0.000585  59349.416609
#  1473203       manual    full-size  0.000430 -0.001078  61402.503792
#  972509     automatic    full-size  0.000361 -0.000759  59306.243838
#  656907     automatic  sub-compact  0.002186 -0.007076  93132.172745
#  525619        manual    full-size  0.000312 -0.000857  61473.184207
#  ...              ...          ...       ...       ...           ...
#  24233      automatic    full-size  0.000219 -0.000498  60274.284010
#  1184470    automatic    full-size  0.000262 -0.000724  62151.096169
#  1533790    automatic    full-size  0.000116 -0.000379  59804.027514
#  1026234    automatic    full-size  0.000268 -0.000788  64156.495773
#  1541257    automatic    full-size  0.000341 -0.001036  62464.858553
#
#  [42919 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  636319   0.017609       porche   0.000009   0.000053  0.999844        clean
#  230466   0.007426       porche   0.000004   0.000022  0.999972        clean
#  1243223  0.015421       porche   0.000000   0.000046  0.999881        clean
#  1257255  0.017601       porche   0.000018   0.000070  0.999845        clean
#  270807   0.060100       porche   0.000060   0.000119  0.998189        clean
#  649219   0.015964       porche   0.000016   0.000048  0.999872        clean
#  998349   0.017636       porche   0.000000   0.000053  0.999844        clean
#  118563   0.014430       porche   0.000000   0.000043  0.999896        clean
#  1673513  0.017434       porche   0.000018   0.000035  0.999848        clean
#  460826   0.051582       porche   0.000051   0.000154  0.998666        clean
#  1122102  0.016593       porche   0.000017   0.000050  0.999862        clean
#  1283713  0.027125       porche   0.000027   0.000081  0.999631        clean
#  1427123  0.014430       porche   0.000000   0.000043  0.999896        clean
#  181352   0.017460       porche   0.000000   0.000053  0.999847        clean
#  49033    0.028328       porche   0.000028   0.000085  0.999598        clean
#  17490    0.009192       porche   0.000005   0.000028  0.999958        clean
#  1673500  0.017434       porche   0.000018   0.000035  0.999848        clean
#  735070   0.017662       porche   0.000000   0.000053  0.999843        clean
#  248741   0.021174       porche   0.000021   0.000084  0.999775        clean
#  374129   0.017557       porche   0.000000   0.000053  0.999845        clean
#  1610906  0.096163       porche   0.000096   0.000287  0.995357        clean
#
#          transmission       size       lat      long         price
#  Id
#  636319     automatic  full-size  0.000328 -0.001058  16138.771587
#  230466     automatic  full-size  0.000159 -0.000292   1521.899310
#  1243223    automatic  full-size  0.000244 -0.000818  15375.814117
#  1257255    automatic  full-size  0.000265 -0.000838  12576.338117
#  270807     automatic  full-size  0.001066 -0.002460  56402.429245
#  649219     automatic  full-size  0.000294 -0.000953  13870.140076
#  998349     automatic  full-size  0.000288 -0.000702  14845.296644
#  118563     automatic  full-size  0.000300 -0.000634   8567.995296
#  1673513       manual    compact  0.000311 -0.000724  16079.434660
#  460826     automatic    compact  0.001064 -0.002094  29325.349483
#  1122102    automatic  full-size  0.000237 -0.000673  14683.218236
#  1283713    automatic  full-size  0.000403 -0.001292  27110.064713
#  1427123    automatic  full-size  0.000300 -0.000634   8567.995296
#  181352        manual  full-size  0.000332 -0.000737  12361.595210
#  49033      automatic  full-size  0.000579 -0.001050  15818.223609
#  17490      automatic  full-size  0.000186 -0.000340   3227.072510
#  1673500       manual    compact  0.000311 -0.000724  16079.434660
#  735070     automatic  full-size  0.000298 -0.001030  18180.401940
#  248741     automatic   mid-size  0.000429 -0.000862   7819.631839
#  374129     automatic  full-size  0.000310 -0.000937  16183.619221
#  1610906       manual  full-size  0.001950 -0.003514  38507.520227  ,
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  634975   0.019917          ram   0.000020   0.000059  0.999801        clean
#  879412   0.017662          ram   0.000018   0.000070  0.999844        clean
#  1013552  0.017539          ram   0.000000   0.000053  0.999846        clean
#  1274584  0.037973          ram   0.000038   0.000113  0.999277        clean
#  1464669  0.009048          ram   0.000005   0.000027  0.999959        clean
#  ...           ...          ...        ...        ...       ...          ...
#  54116    0.201711          ram   0.000200   0.000600  0.979356        clean
#  1623008  0.014082          ram   0.000000   0.000042  0.999901        clean
#  1456520  0.086064          ram   0.000000   0.000256  0.996283        clean
#  1574376  0.020896          ram   0.000000   0.000062  0.999781        clean
#  1216327  0.994072          ram   0.000000   0.002978  0.089829        clean
#
#          transmission       size       lat      long          price
#  Id
#  634975     automatic  full-size  0.000359 -0.001180  123896.387225
#  879412     automatic  full-size  0.000378 -0.000734  125732.890354
#  1013552    automatic  full-size  0.000348 -0.000664  127893.096408
#  1274584    automatic  full-size  0.000551 -0.001863  114841.326700
#  1464669    automatic  full-size  0.000183 -0.000335  131008.260290
#  ...              ...        ...       ...       ...            ...
#  54116      automatic  full-size  0.004911 -0.012269   36245.410666
#  1623008    automatic  full-size  0.000302 -0.000618  129072.955087
#  1456520    automatic  full-size  0.001727 -0.003170  102315.669705
#  1574376    automatic  full-size  0.000448 -0.000789  126762.156987
#  1216327       manual  full-size  0.023254 -0.056590   57285.545684
#
#  [8326 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1051884  0.017451    chevrolet   0.000000   0.000053  0.999847        clean
#  1255387  0.017592    chevrolet   0.000000   0.000070  0.999845        clean
#  1388526  0.008329    chevrolet   0.000008   0.000033  0.999965        clean
#  746176   0.023666    chevrolet   0.000012   0.000096  0.999719        clean
#  1088447  0.027565    chevrolet   0.000000   0.000082  0.999619      rebuilt
#  ...           ...          ...        ...        ...       ...          ...
#  482200   0.106388    chevrolet   0.000108   0.000431  0.994304        clean
#  765689   0.013254    chevrolet   0.000013   0.000040  0.999912        clean
#  1302371  0.008391    chevrolet   0.000004   0.000034  0.999965        clean
#  1700280  0.019752    chevrolet   0.000000   0.000078  0.999805        clean
#  53108    0.020658    chevrolet   0.000000   0.000082  0.999786        clean
#
#          transmission       size       lat      long          price
#  Id
#  1051884    automatic  full-size  0.000337 -0.000824  202675.619095
#  1255387    automatic  full-size  0.000264 -0.000862  204066.536314
#  1388526    automatic  full-size  0.000153 -0.000318  207753.420430
#  746176     automatic  full-size  0.000409 -0.001425  198278.211703
#  1088447    automatic  full-size  0.000495 -0.001187  196110.890527
#  ...              ...        ...       ...       ...            ...
#  482200     automatic  full-size  0.001886 -0.006167  134565.690845
#  765689     automatic  full-size  0.000275 -0.000464  202884.082072
#  1302371    automatic  full-size  0.000137 -0.000352  208589.997648
#  1700280    automatic  full-size  0.000348 -0.000808  202292.466807
#  53108      automatic  full-size  0.000352 -0.000799  201813.300144
#
#  [38596 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  397885   0.014961     infiniti   0.000007   0.000045  0.999888        clean
#  774955   0.014998     infiniti   0.000015   0.000045  0.999887        clean
#  275304   0.012065     infiniti   0.000006   0.000036  0.999927        clean
#  778374   0.014341     infiniti   0.000007   0.000043  0.999897        clean
#  1406118  0.017601     infiniti   0.000000   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1596362  0.122574     infiniti   0.000122   0.000365  0.992446      salvage
#  886734   0.017618     infiniti   0.000018   0.000053  0.999844        clean
#  368452   0.017860     infiniti   0.000009   0.000053  0.999840        clean
#  155826   0.014850     infiniti   0.000015   0.000044  0.999889        clean
#  290069   0.013304     infiniti   0.000013   0.000040  0.999911        clean
#
#          transmission       size       lat      long         price
#  Id
#  397885     automatic  full-size  0.000251 -0.000645   9376.775430
#  774955     automatic  full-size  0.000314 -0.000534   9386.651525
#  275304     automatic  full-size  0.000232 -0.000493   8902.555134
#  778374     automatic  full-size  0.000298 -0.000508   9268.891090
#  1406118    automatic  full-size  0.000329 -0.000680   9797.484311
#  ...              ...        ...       ...       ...           ...
#  1596362    automatic  full-size  0.002467 -0.004498  26167.922135
#  886734     automatic  full-size  0.000381 -0.000738   9859.750684
#  368452     automatic  full-size  0.000443 -0.001059  10013.564222
#  155826        manual    compact  0.000275 -0.000709   9399.046393
#  290069     automatic  full-size  0.000238 -0.000523   9100.205123
#
#  [1850 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1233191  0.069281       nissan   0.000069   0.000138  0.997591        clean
#  1253597  0.036757       nissan   0.000018   0.000110  0.999322        clean
#  267134   0.025622       nissan   0.000013   0.000051  0.999671        clean
#  1340703  0.012807       nissan   0.000006   0.000026  0.999918        clean
#  927955   0.017610       nissan   0.000009   0.000035  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  331828   0.014626       nissan   0.000015   0.000044  0.999893        clean
#  126564   0.018580       nissan   0.000000   0.000056  0.999827        clean
#  689765   0.035923       nissan   0.000036   0.000071  0.999352        clean
#  1071667  0.017662       nissan   0.000000   0.000053  0.999844        clean
#  452074   0.013664       nissan   0.000000   0.000041  0.999906        clean
#
#          transmission       size       lat      long         price
#  Id
#  1233191    automatic    compact  0.001022 -0.003286  23278.711546
#  1253597    automatic  full-size  0.000579 -0.001941  25735.821421
#  267134     automatic    compact  0.000510 -0.001055  25559.734800
#  1340703    automatic    compact  0.000262 -0.000717  26433.049462
#  927955     automatic    compact  0.000374 -0.000732  26046.547587
#  ...              ...        ...       ...       ...           ...
#  331828     automatic  full-size  0.000299 -0.000671  26512.998392
#  126564        manual  full-size  0.000363 -0.000801  26305.527782
#  689765     automatic  full-size  0.000667 -0.002154  25289.789678
#  1071667    automatic  full-size  0.000318 -0.000735  26340.004232
#  452074         other  full-size  0.000283 -0.000556  26502.450184
#
#  [11648 rows x 11 columns],
#               year   manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1132407  0.015139  mercedes-benz   0.000000   0.000045  0.999885        clean
#  424855   0.024005  mercedes-benz   0.000000   0.000072  0.999711        clean
#  1441207  0.058306  mercedes-benz   0.000000   0.000174  0.998295        clean
#  512103   0.016449  mercedes-benz   0.000016   0.000049  0.999864        clean
#  1719335  0.015628  mercedes-benz   0.000008   0.000063  0.999878        clean
#  ...           ...            ...        ...        ...       ...          ...
#  503575   0.017648  mercedes-benz   0.000000   0.000035  0.999844        clean
#  651785   0.017574  mercedes-benz   0.000009   0.000053  0.999845        clean
#  768324   0.022749  mercedes-benz   0.000000   0.000068  0.999741        clean
#  136234   0.018191  mercedes-benz   0.000018   0.000055  0.999834        clean
#  1219869  0.208073  mercedes-benz   0.000000   0.000619  0.978057        clean
#
#          transmission       size       lat      long          price
#  Id
#  1132407    automatic  full-size  0.000211 -0.000622  188774.642546
#  424855     automatic  full-size  0.000362 -0.001075  176431.069587
#  1441207    automatic  full-size  0.001209 -0.002546  153023.458194
#  512103     automatic    compact  0.000292 -0.000800  194237.008680
#  1719335    automatic  full-size  0.000274 -0.000605  193067.951326
#  ...              ...        ...       ...       ...            ...
#  503575     automatic    compact  0.000384 -0.000624  199509.094580
#  651785     automatic  full-size  0.000367 -0.001090  187179.271414
#  768324     automatic  full-size  0.000480 -0.000802  192300.747666
#  136234     automatic  full-size  0.000320 -0.000969  190327.508147
#  1219869    automatic  full-size  0.002703 -0.010125  105129.629645
#
#  [4623 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  666678   0.040253      lincoln   0.000041   0.000163  0.999186        clean
#  1452091  0.017715      lincoln   0.000018   0.000035  0.999843        clean
#  1048858  0.017592      lincoln   0.000000   0.000053  0.999845        clean
#  1093648  0.016906      lincoln   0.000017   0.000067  0.999857        clean
#  393701   0.015525      lincoln   0.000015   0.000062  0.999879        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1296390  0.008052      lincoln   0.000000   0.000032  0.999968         lien
#  1681663  0.023886      lincoln   0.000012   0.000095  0.999714        clean
#  899443   0.017671      lincoln   0.000018   0.000053  0.999844        clean
#  1195349  0.012738      lincoln   0.000013   0.000051  0.999919        clean
#  1431385  0.040488      lincoln   0.000040   0.000121  0.999178        clean
#
#          transmission       size       lat      long         price
#  Id
# ...
#  1285643    automatic  full-size  0.000298 -0.001006  62612.383612
#  1645519    automatic   mid-size  0.000249 -0.000496  64072.663508
#  1076549    automatic  full-size  0.000316 -0.000737  63675.245169
#
#  [17202 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1503379  0.045452         fiat   0.000000   0.000136  0.998962        clean
#  1225886  0.037935         fiat   0.000038   0.000075  0.999278        clean
#  1277772  0.017715         fiat   0.000009   0.000035  0.999843      rebuilt
#  938046   0.017697         fiat   0.000000   0.000035  0.999843        clean
#  322196   0.032447         fiat   0.000000   0.000097  0.999471        clean
#  ...           ...          ...        ...        ...       ...          ...
#  336232   0.022711         fiat   0.000023   0.000045  0.999742        clean
#  768537   0.018654         fiat   0.000019   0.000037  0.999826        clean
#  20364    0.033216         fiat   0.000033   0.000050  0.999447      rebuilt
#  792765   0.014727         fiat   0.000000   0.000030  0.999891        clean
#  61244    0.020252         fiat   0.000020   0.000060  0.999794        clean
#
#          transmission         size       lat      long        price
#  Id
#  1503379       manual  sub-compact  0.001093 -0.002700  8755.936501
#  1225886       manual      compact  0.000620 -0.001808  7951.807976
#  1277772    automatic      compact  0.000279 -0.000935  7197.714388
#  938046        manual      compact  0.000367 -0.000627  7267.139546
#  322196     automatic    full-size  0.000792 -0.001983  8162.045227
#  ...              ...          ...       ...       ...          ...
#  336232     automatic      compact  0.000317 -0.000931  7212.354565
#  768537        manual      compact  0.000390 -0.000671  7318.264036
#  20364      automatic      compact  0.000574 -0.001402  7912.038823
#  792765        manual      compact  0.000299 -0.000561  7136.263379
#  61244      automatic    full-size  0.000494 -0.001237  7543.153328
#
#  [314 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1195520  0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1388186  0.016584        lexus   0.000008   0.000050  0.999862        clean
#  708929   0.017618        lexus   0.000000   0.000053  0.999844        clean
#  1284522  0.008382        lexus   0.000004   0.000034  0.999965        clean
#  1567156  0.006256        lexus   0.000006   0.000019  0.999980        clean
#  ...           ...          ...        ...        ...       ...          ...
#  514706   0.017100        lexus   0.000017   0.000068  0.999853        clean
#  1249626  0.022283        lexus   0.000022   0.000067  0.999751        clean
#  1675277  0.017662        lexus   0.000000   0.000053  0.999844        clean
#  283635   0.016176        lexus   0.000016   0.000048  0.999869        clean
#  946580   0.017349        lexus   0.000000   0.000052  0.999849        clean
#
#          transmission       size       lat      long         price
#  Id
#  1195520    automatic  full-size  0.000245 -0.000727  10519.456419
#  1388186    automatic  full-size  0.000305 -0.000631  10387.602534
#  708929     automatic  full-size  0.000297 -0.001036  10675.890825
#  1284522    automatic  full-size  0.000124 -0.000414   9152.707706
#  1567156    automatic   mid-size  0.000135 -0.000236   8837.795426
#  ...              ...        ...       ...       ...           ...
#  514706     automatic  full-size  0.000304 -0.000833  10468.810054
#  1249626    automatic   mid-size  0.000338 -0.001085  11171.236502
#  1675277    automatic  full-size  0.000315 -0.000716  10601.117034
#  283635     automatic  full-size  0.000246 -0.000703  10252.023577
#  946580     automatic  full-size  0.000355 -0.000631  10581.871357
#
#  [3012 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1099744  0.017662        honda   0.000018   0.000053  0.999844        clean
#  386522   0.033531        honda   0.000033   0.000100  0.999437        clean
#  1030588  0.010177        honda   0.000000   0.000020  0.999948        clean
#  1355767  0.029284        honda   0.000029   0.000058  0.999570        clean
#  608497   0.017680        honda   0.000000   0.000053  0.999843        clean
#  ...           ...          ...        ...        ...       ...          ...
#  1614746  0.074521        honda   0.000000   0.000222  0.997215        clean
#  1126982  0.069236        honda   0.000000   0.000206  0.997595        clean
#  64234    0.017574        honda   0.000000   0.000053  0.999845        clean
#  1684307  0.017583        honda   0.000009   0.000035  0.999845      rebuilt
#  1605370  0.012676        honda   0.000006   0.000025  0.999920        clean
#
#          transmission       size       lat      long          price
#  Id
#  1099744    automatic  full-size  0.000307 -0.000749   15396.635128
#  386522     automatic   mid-size  0.000723 -0.001340   42456.235089
#  1030588    automatic    compact  0.000223 -0.000525    9614.543043
#  1355767    automatic   mid-size  0.000647 -0.001064   26698.870391
#  608497        manual  full-size  0.000310 -0.001060    8503.894987
#  ...              ...        ...       ...       ...            ...
#  1614746    automatic  full-size  0.001510 -0.002714  101604.563626
#  1126982    automatic  full-size  0.001044 -0.002974  111131.843254
#  64234          other  full-size  0.000399 -0.000647    4705.471002
#  1684307    automatic    compact  0.000305 -0.000685    8376.167628
#  1605370    automatic    compact  0.000272 -0.000481    3267.858907
#
#  [13143 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1157283  0.017566      mercury   0.000009   0.000053  0.999845        clean
#  834053   0.007056      mercury   0.000004   0.000028  0.999975        clean
#  399248   0.011770      mercury   0.000006   0.000035  0.999931        clean
#  1490783  0.017293      mercury   0.000009   0.000070  0.999850        clean
#  587662   0.011811      mercury   0.000000   0.000035  0.999930        clean
#  ...           ...          ...        ...        ...       ...          ...
#  984418   0.010711      mercury   0.000011   0.000043  0.999942      rebuilt
#  1202222  0.014443      mercury   0.000007   0.000043  0.999895        clean
#  875215   0.017381      mercury   0.000009   0.000070  0.999849        clean
#  1614673  0.011790      mercury   0.000000   0.000047  0.999930        clean
#  1167053  0.019746      mercury   0.000000   0.000080  0.999805        clean
#
#          transmission       size       lat      long        price
#  Id
#  1157283    automatic  full-size  0.000267 -0.000759  3873.608300
#  834053     automatic   mid-size  0.000137 -0.000368  3534.012678
#  399248     automatic  full-size  0.000184 -0.000503  3670.062098
#  1490783    automatic  full-size  0.000426 -0.001074  3997.126536
#  587662     automatic  full-size  0.000265 -0.000726  3689.325160
#  ...              ...        ...       ...       ...          ...
#  984418     automatic  full-size  0.000235 -0.000514  3715.342685
#  1202222    automatic  full-size  0.000331 -0.000782  3817.146193
#  875215        manual  full-size  0.000376 -0.000755  3984.669615
#  1614673    automatic  full-size  0.000241 -0.000431  3723.648549
#  1167053    automatic  full-size  0.000280 -0.000819  3975.526774
#
#  [1451 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1096521  0.012702         audi   0.000000   0.000051  0.999919        clean
#  840911   0.006488         audi   0.000003   0.000019  0.999979        clean
#  1284719  0.264102         audi   0.000000   0.000785  0.964403        clean
#  748622   0.015722         audi   0.000016   0.000031  0.999876        clean
#  1473785  0.017550         audi   0.000018   0.000053  0.999845        clean
#  ...           ...          ...        ...        ...       ...          ...
#  330380   0.022126         audi   0.000000   0.000044  0.999755        clean
#  679075   0.021351         audi   0.000021   0.000064  0.999771        clean
#  1466507  0.017557         audi   0.000000   0.000053  0.999846        clean
#  222383   0.017758         audi   0.000000   0.000053  0.999842        clean
#  1579969  0.022294         audi   0.000000   0.000044  0.999751        clean
#
#          transmission       size       lat      long         price
#  Id
#  1096521    automatic  full-size  0.000229 -0.000549   9542.985611
#  840911     automatic  full-size  0.000131 -0.000340   8055.601159
#  1284719    automatic  full-size  0.003428 -0.012844  58616.620476
#  748622     automatic    compact  0.000297 -0.000948  10005.222085
#  1473785    automatic   mid-size  0.000428 -0.001074  10547.993841
#  ...              ...        ...       ...       ...           ...
#  330380     automatic   mid-size  0.000468 -0.000780  11165.564438
#  679075     automatic  full-size  0.000362 -0.001246  11406.829931
#  1466507    automatic    compact  0.000358 -0.000652  10423.975778
#  222383     automatic  full-size  0.000316 -0.000696  10498.998604
#  1579969    automatic    compact  0.000478 -0.000846  11231.807424
#
#  [2232 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  1643997  0.016723       saturn   0.000000   0.000050  0.999860        clean
#  907300   0.011776       saturn   0.000006   0.000024  0.999931        clean
#  1464649  0.024218       saturn   0.000024   0.000072  0.999706        clean
#  1613311  0.032338       saturn   0.000032   0.000097  0.999476        clean
#  692353   0.011255       saturn   0.000000   0.000022  0.999936        clean
#  ...           ...          ...        ...        ...       ...          ...
#  587410   0.017522       saturn   0.000000   0.000053  0.999846        clean
#  121778   0.017714       saturn   0.000000   0.000035  0.999843        clean
#  892908   0.017618       saturn   0.000009   0.000053  0.999844        clean
#  278705   0.017583       saturn   0.000000   0.000053  0.999845        clean
#  786965   0.017566       saturn   0.000000   0.000053  0.999845        clean
#
#          transmission       size       lat      long        price
#  Id
#  1643997    automatic  full-size  0.000377 -0.000765  3093.179293
#  907300     automatic    compact  0.000253 -0.000492  2945.482138
#  1464649    automatic  full-size  0.000479 -0.000904  3426.586139
#  1613311    automatic  full-size  0.000678 -0.001226  3691.118428
#  692353     automatic    compact  0.000207 -0.000673  2906.261009
#  ...              ...        ...       ...       ...          ...
#  587410        manual  full-size  0.000395 -0.001080  3112.870284
#  121778        manual   mid-size  0.000335 -0.001002  3072.752990
#  892908     automatic  full-size  0.000378 -0.000730  3162.205805
#  278705        manual  full-size  0.000317 -0.000705  3128.657467
#  786965     automatic  full-size  0.000360 -0.000683  3123.658966
#
#  [1345 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  154867   0.082865       datsun   0.000084   0.000251  0.996555        clean
#  1034159  0.038011       datsun   0.000038   0.000115  0.999275        clean
#  127388   0.017355       datsun   0.000018   0.000053  0.999849        clean
#  1691790  0.017355       datsun   0.000000   0.000053  0.999849        clean
#  1209077  0.017372       datsun   0.000009   0.000053  0.999849        clean
#  ...           ...          ...        ...        ...       ...          ...
#  595616   0.017372       datsun   0.000009   0.000053  0.999848        clean
#  1073326  0.013304       datsun   0.000000   0.000040  0.999911        clean
#  285527   0.017293       datsun   0.000000   0.000053  0.999850        clean
#  854044   0.017320       datsun   0.000009   0.000053  0.999850        clean
#  588840   0.017364       datsun   0.000000   0.000053  0.999849        clean
#
#          transmission       size       lat      long         price
#  Id
#  154867        manual    compact  0.001670 -0.003106  12240.368430
#  1034159       manual    compact  0.000751 -0.001818  11321.060223
#  127388        manual    compact  0.000287 -0.001028   9794.849484
#  1691790       manual  full-size  0.000309 -0.000697   4660.906186
#  1209077       manual  full-size  0.000412 -0.001001   7856.690991
#  ...              ...        ...       ...       ...           ...
#  595616        manual  full-size  0.000400 -0.001079   8320.871461
#  1073326    automatic  full-size  0.000243 -0.000581   5272.157957
#  285527        manual  full-size  0.000357 -0.000983   6284.125585
#  854044     automatic    compact  0.000336 -0.000919   7517.170425
#  588840        manual  full-size  0.000371 -0.001078   6771.540649
#
#  [79 rows x 11 columns],
#               year manufacturer  condition  cylinders  odometer title_status  \
#  Id
#  771920   0.014356      unknown   0.000007   0.000029  0.999897        clean
#  138219   0.017574      unknown   0.000000   0.000070  0.999845        clean
#  546294   0.015222      unknown   0.000008   0.000031  0.999884        clean
#  889246   0.012744      unknown   0.000000   0.000038  0.999919        clean
#  205327   0.039342      unknown   0.000039   0.000118  0.999224        clean
#  ...           ...          ...        ...        ...       ...          ...
#  349037   0.017609      unknown   0.000000   0.000053  0.999844        clean
#  1131359  0.017627      unknown   0.000000   0.000053  0.999844        clean
#  327284   0.055531      unknown   0.000056   0.000225  0.998454        clean
#  1302188  0.007224      unknown   0.000004   0.000022  0.999974        clean
#  1396770  0.017285      unknown   0.000000   0.000053  0.999850        clean
#
#          transmission       size       lat      long          price
#  Id
#  771920        manual    compact  0.000302 -0.000515  157903.767447
#  138219     automatic  full-size  0.000238 -0.000704  159329.852022
#  546294        manual    compact  0.000296 -0.000587  157376.803024
#  889246     automatic  full-size  0.000274 -0.000531  160380.023617
#  205327        manual  full-size  0.000917 -0.001897  142454.112669
#  ...              ...        ...       ...       ...            ...
#  349037     automatic  full-size  0.000325 -0.001051  157532.715542
#  1131359    automatic  full-size  0.000245 -0.000725  157771.673326
#  327284        manual  full-size  0.001231 -0.002054  137278.362214
#  1302188       manual  full-size  0.000121 -0.000305  163727.457492
#  1396770    automatic  full-size  0.000338 -0.000693  157777.878044
#
#  [20048 rows x 11 columns]]

# %%
y_sub = pd.concat(list(X_sub_dec.values()),axis=0)['price']

# %%
y_sub.shape
# Out:
# (253073,)

# %%
y_sub.to_csv('../cars-competition/data/lin_reg_by_manufacturer.csv', header=True, index=True)

# %%
# Prepare for submission
sub30 = submission
sub30['price'] = y_sub.astype('int')
sub30 = sub30['price']
sub30.to_csv('../cars-competition/data/lin_reg_by_manufacturer.csv', header=True, index=True)

# %%
y_sub
