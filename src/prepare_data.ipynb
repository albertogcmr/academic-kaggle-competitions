# %%
from clean_data import clean_data, prepare_data
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import normalize

# %%
data = pd.read_csv('../cars-competition/data/cars_train.csv', index_col='Id')
data.head()
# Out:
#                city    year manufacturer                     make  condition  \
# Id
# 559327    baltimore  2006.0          NaN                 Scion tc  excellent
# 1429566  carbondale  2018.0        dodge              charger sxt        NaN
# 931606        thumb  1997.0         ford  f 250 2 wheel dr pickup       fair
# 1265412      laredo  2003.0          ram                      NaN        NaN
# 1133731       ocala  2000.0        dodge                     1500        NaN
#
#            cylinders fuel  odometer title_status transmission  ...  \
# Id                                                             ...
# 559327   4 cylinders  gas  190000.0        clean    automatic  ...
# 1429566          NaN  gas       NaN        clean    automatic  ...
# 931606           NaN  gas       NaN        clean    automatic  ...
# 1265412  8 cylinders  gas       NaN        clean    automatic  ...
# 1133731          NaN  gas       NaN        clean    automatic  ...
#
#         paint_color        lat       long county_fips     county_name  \
# Id
# 559327         blue  39.287000 -76.647600     24510.0  Baltimore City
# 1429566         NaN  37.720000 -89.215800     17077.0         Jackson
# 931606        white  43.483300 -83.383500     26157.0         Tuscola
# 1265412         NaN  27.850069 -99.668883     48479.0            Webb
# 1133731         NaN  29.165000 -81.539900     12069.0            Lake
#
#          state_fips  state_code state_name  weather  price
# Id
# 559327         24.0          MD   Maryland     56.0   3200
# 1429566        17.0          IL   Illinois     48.0  30620
# 931606         26.0          MI   Michigan     45.0   1800
# 1265412        48.0          TX      Texas     67.0   4500
# 1133731        12.0          FL    Florida     65.0   1400
#
# [5 rows x 23 columns]

# %%
train = clean_data(data)
train.head()
# Out:
# Cleaning cylinders...
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['cylinders'][data_frame['cylinders']=='other'] = median
# Cleaning condition...
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['condition'][data_frame['condition'].isnull()] = 'unknown'
# Cleaning odometer...
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['year'][((data_frame['year']<1900) | (data_frame['year'].isnull()))] = year_avg
# Cleaning drive...
# Cleaning size...
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['drive'][data_frame['drive'].isnull()]='fwd'
# Cleaning manufacturer...
# Cleaning fuel...
# Cleaning transmission...
# Cleaning title status...
# Data cleaning complete!
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['manufacturer'][data_frame['manufacturer'].isnull()] = 'unknown'
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['fuel'][data_frame['fuel'].isnull()]='other'
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['transmission'][data_frame['transmission'].isnull()]='other'
# /home/felipe/Documents/coding/academic-kaggle-competitions/src/clean_data.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['title_status'][data_frame['title_status'].isnull()]='clean'
#                city    year manufacturer                     make  condition  \
# Id
# 559327    baltimore  2006.0      unknown                 Scion tc          2
# 1429566  carbondale  2018.0        dodge              charger sxt          0
# 931606        thumb  1997.0         ford  f 250 2 wheel dr pickup          0
# 1265412      laredo  2003.0          ram                      NaN          0
# 1133731       ocala  2000.0        dodge                     1500          0
#
#          cylinders fuel       odometer title_status transmission  ...  \
# Id                                                                ...
# 559327           4  gas  190000.000000        clean    automatic  ...
# 1429566          6  gas  113584.991571        clean    automatic  ...
# 931606           6  gas  113584.991571        clean    automatic  ...
# 1265412          8  gas  113584.991571        clean    automatic  ...
# 1133731          6  gas  113584.991571        clean    automatic  ...
#
#                lat       long county_fips     county_name  state_fips  \
# Id
# 559327   39.287000 -76.647600     24510.0  Baltimore City        24.0
# 1429566  37.720000 -89.215800     17077.0         Jackson        17.0
# 931606   43.483300 -83.383500     26157.0         Tuscola        26.0
# 1265412  27.850069 -99.668883     48479.0            Webb        48.0
# 1133731  29.165000 -81.539900     12069.0            Lake        12.0
#
#          state_code  state_name weather  price decade
# Id
# 559327           MD    Maryland    56.0   3200  200.0
# 1429566          IL    Illinois    48.0  30620  201.0
# 931606           MI    Michigan    45.0   1800  199.0
# 1265412          TX       Texas    67.0   4500  200.0
# 1133731          FL     Florida    65.0   1400  200.0
#
# [5 rows x 24 columns]

# %%
# Select only relevant columns
train = train[['year','manufacturer','condition','cylinders','fuel','odometer','title_status','transmission','drive','size','price']]

# %%
train.dtypes
# Out:
# year            float64
# manufacturer     object
# condition         int64
# cylinders         int64
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# drive            object
# size             object
# price             int64
# dtype: object

# %%
# Getting dummies for categorical columns
train = pd.get_dummies(train,drop_first=True)

# %%
# Get X and y
X = train.drop(columns='price')
y = train['price']

# %%
# Feature reduction
pca = PCA(n_components = 40)
X_new = pca.fit_transform(X)

# %%
pd.DataFrame(X_new)
# Out:
#                    0          1         2         3         4         5   \
# 0        76415.008411   1.998800  2.285007  1.191960 -0.099854  0.321351
# 1           -0.000141  13.124266 -0.199016 -1.057089 -0.211036  0.099359
# 2            0.000085  -7.872017  0.135497 -0.931607 -0.207106 -0.431458
# 3            0.000021  -1.905981 -1.837615 -0.953508 -0.262405  0.500095
# 4            0.000052  -4.871265  0.121437 -0.948306 -0.297413  0.083603
# ...               ...        ...       ...       ...       ...       ...
# 469987  124462.008421   1.464724 -0.143388 -0.823583  0.520126 -0.980063
# 469988  -73068.991687  10.353331 -0.188195  0.864620 -0.784637 -0.008308
# 469989   38178.008308  11.514739 -2.253396  1.031317 -0.078292 -0.115303
# 469990  -78556.991688  10.333166  2.057632  1.123872 -0.014512  0.363331
# 469991  -36922.991656   7.735390 -0.122146 -0.071766 -0.522266  0.037933
#
#               6         7         8         9   ...        30        31  \
# 0       0.250586  0.282138  0.228801  0.085054  ...  0.024372 -0.013279
# 1      -0.009945  0.212206 -0.223439 -0.004829  ...  0.007861 -0.006470
# 2       0.604551 -0.441833 -0.250050  0.058381  ...  0.000834 -0.008951
# 3       0.356211  0.320651 -0.017432  0.065288  ... -0.009829 -0.031187
# 4       0.003075  0.188087 -0.201826  0.167383  ...  0.000908 -0.012897
# ...          ...       ...       ...       ...  ...       ...       ...
# 469987  0.234747 -0.413298  0.551228  0.262088  ...  0.004886  0.018595
# 469988 -0.004537  0.092822 -0.118973 -0.028026  ... -0.034783 -0.033224
# 469989 -0.009903  0.337599  0.781236  0.233828  ... -0.000707  0.012180
# 469990  0.288333 -0.003910  0.030040  0.068471  ... -0.010214 -0.042276
# 469991 -0.002527  0.113929 -0.170372  0.019762  ...  0.003056 -0.048662
#
#               32        33        34        35        36        37        38  \
# 0       0.005330  0.007512 -0.016540  0.004281 -0.007001  0.003772 -0.002538
# 1       0.001169  0.000943 -0.017085 -0.004969 -0.009903 -0.006704 -0.004029
# 2      -0.010037 -0.010609 -0.003496  0.003717  0.001055 -0.003453  0.001158
# 3      -0.017373 -0.032785 -0.022506 -0.002881 -0.009492 -0.021919  0.001521
# 4      -0.008303 -0.011602 -0.007511 -0.002120 -0.008388 -0.008289 -0.001061
# ...          ...       ...       ...       ...       ...       ...       ...
# 469987  0.002640  0.006619 -0.023811 -0.012106 -0.001820  0.006860 -0.000411
# 469988 -0.030030 -0.035921 -0.019359 -0.036995 -0.031040 -0.031773 -0.005208
# 469989 -0.003096 -0.000704 -0.048311 -0.023381 -0.007331 -0.005252  0.001484
# 469990 -0.011283 -0.023504 -0.018584 -0.025728 -0.034214 -0.020759 -0.007093
# 469991  0.000554 -0.016741 -0.013031 -0.029539 -0.039126 -0.025397 -0.008616
#
#               39
# 0      -0.013451
# 1      -0.005910
# 2      -0.004655
# 3      -0.011836
# 4      -0.007710
# ...          ...
# 469987  0.003362
# 469988 -0.008909
# 469989  0.001851
# 469990 -0.018593
# 469991 -0.014681
#
# [469992 rows x 40 columns]

# %%
# Split train and test
X_train, X_test, y_train, y_test = train_test_split(X_new,y,test_size=0.2)

# %%
# Linear Regression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict
y_pred = lin_reg.predict(X_test)

# %%
# Check error
mean_squared_error(y_test, y_pred)
# Out:
# 38518176350566.41

# %%
# Predict for submission Linear Regression
submission = pd.read_csv('../cars-competition/data/cars_test.csv', index_col='Id')
submission = clean_data(submission)
# Out:
# Cleaning cylinders...
# Cleaning condition...
# Cleaning odometer...
# Cleaning drive...
# Cleaning size...
# Cleaning manufacturer...
# Cleaning fuel...
# Cleaning transmission...
# Cleaning title status...
# Data cleaning complete!

# %%
def prepare_data(data_frame):
    # Select only relevant columns
    data_frame = data_frame[['year','manufacturer','condition','cylinders','fuel','odometer','title_status','transmission','drive','size']]
    # Getting dummies for categorical columns
    data_frame = pd.get_dummies(data_frame,drop_first=True)
    # Get X and y
    X = data_frame
    return X
submission = prepare_data(submission)

# %%
X_sub = pca.transform(submission)

# %%
sub = pd.read_csv('../cars-competition/data/cars_test.csv', index_col='Id')
y_sub = lin_reg.predict(X_sub)
sub['price'] = y_sub

# %%
sub['price']
# Out:
# Id
# 974298     -18313.645526
# 1051884    406511.771876
# 684464     -74397.857659
# 1255387    120145.164314
# 1195520     94735.332372
#                ...
# 53108       73670.791361
# 1541257    -70444.728673
# 585898     458679.394483
# 1076549    238683.260036
# 662527     309390.010990
# Name: price, Length: 253073, dtype: float64

# %%
# KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=1000)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=1000, p=2,
#                     weights='uniform')

# %%
# Predict
y_pred = neigh.predict(X_test)

# %%
# Check error
mean_squared_error(y_test, y_pred)
# Out:
# 139934395492439.38

# %%
# Random Forrest
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
regr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b8936f18237f> in <module>
#       1 # Random Forrest
#       2 regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
# ----> 3 regr.fit(X_train,y_train)
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1155             sample_weight=sample_weight,
#    1156             check_input=check_input,
# -> 1157             X_idx_sorted=X_idx_sorted)
#    1158         return self
#    1159
#
# ~/miniconda3/envs/lab/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:
